# %%
import entity_formatter
from entity_tagger import entity_tagger as tagger
import requests
import json
import pandas as pd
import boto3
import traceback
import json

# %%
import uuid
uuid.uuid4()
# Out:
# UUID('bf706312-a96e-4c89-b1d0-8d234fbd2ac4')

# %%
import numpy as np
import spacy
import nltk
from nltk.parse import CoreNLPParser
import en_core_web_sm
nlp = spacy.load("en_core_web_sm")
from nltk.tag.stanford import StanfordNERTagger
from nltk.tokenize import word_tokenize  
sner_tagger = StanfordNERTagger('taging_data/english.all.3class.distsim.crf.ser.gz',
               'taging_data/stanford-ner.jar',
               encoding='utf-8')

# %%
## MOST IMPORTANT
exp_id = "exp03" #unique for each experiment

# %%
ssm = boto3.client("ssm")
s3 = boto3.client("s3")
root_url = ssm.get_parameter(Name=f"/account/root-url")["Parameter"]["Value"]
apikey = ssm.get_parameter(Name="/account/internal-api-key")["Parameter"]["Value"]
v1_url = f"https://remember.{root_url}"
v2_url = f"https://rememberv2.{root_url}/latest"
acc_owner = ssm.get_parameter(Name="/account/owner")["Parameter"]["Value"].upper()
headers = {"x-api-key": apikey, "Authorization": apikey}

# %%
temp_tagged = []
temp_untagged = []
page_blobs = []

# %%
def rememberv2_query(index={}, filters={}):
    url = f"{v2_url}/query"
    results = {}
    try:
        payload = {
            "Index": index,
            "Filter": filters
        }
        results = json.loads(requests.post(url=url, data=json.dumps(payload), headers=headers).text)["Results"]
    except:
        print(traceback.format_exc())    
    return results


def rememberv2_read(objectid):
    url = f"{v2_url}/read"
    results = {}
    try:
        payload = {
            "ObjectId": objectid,
        }
        results = json.loads(requests.post(url=url, data=json.dumps(payload), headers=headers).text)["Results"]
    except:
        print(traceback.format_exc())
    return results



def remember_recall(rid, datapoint):
    url = f"{v1_url}/recall?_remember_id={rid}&_datapoint={datapoint}"
    res = {}
    try:
        res = json.loads(requests.get(url=url).text)["datapoints"][0]["data"]
    except:
        print(traceback.format_exc())
    return res
    
# def make_text_blob(word_ocr):
#     text_list = []
    
#     for i in word_ocr["Words"]:
#         text_list.append(i["text"])
#     #print("\n\n\nBefore Sending it off: " , text_list)
#     return text_list

def remember_write(datapoint):
    resp_dict = {}
    url = f"{v2_url}/write"
    try:
        resp = requests.post(
            url=url, data=json.dumps(datapoint), headers=headers
        )
        resp_dict = resp.json()
    except:
        print(traceback.format_exc())
    return resp_dict


def create_datapoint(Type, Fields, TransactionId, Attributes=None):
    datapoint = {
        "Type": Type,
        "Fields": Fields,
        "TransactionId": TransactionId,
    }
    if Attributes != None:
        datapoint["Attributes"] = Attributes
    return remember_write(datapoint)


def remember_memorize(data, rid, datapoint, metadata={}):
    url = f"{v1_url}/memoorize"
    try:
        metadata.update({
            "_remember_id": rid,
            "_datapoint": datapoint
        })
        payload = {
            "data": data,
            "metadata": metadata 
        }
        resp = requests.post(
                url=url, data=json.dumps(payload), headers=headers)
    except:
        print(traceback.format_exc())
    return resp
def do_sner_tag(text):
    text = text.replace("/","-")
    text = text.replace("[]","")
    tagged_list = sner_tagger.tag(word_tokenize(text))
    return tagged_list
def do_spacy_tag(text):
    text = text.replace("/","-")
    

def aggregate_formatted_entities(docid):
    temp_dict = {}
    try:
        recall_txn = rememberv2_read(docid)[0]
        txnid = recall_txn["TransactionId"]
        file_pages = recall_txn["Pages"]
        start = file_pages[0]
        doc_pages = list(range(1, len(file_pages)+1))
        page_ocrs_ids = {x['ParentIndex']:x['ObjectId'] for x in rememberv2_query({'PageOcr::TransactionId': txnid}, {'ParentIndex': file_pages})}
        results = {}
        formatted_doc = {}
        count = 0
        for page in sorted(page_ocrs_ids.keys()):
            try:
                
                print("Going on a count: ", count)
                count = count+1
                words_ocr = rememberv2_query({'Parent': page_ocrs_ids[page]})
                parsed_words = tagger.parse_words(words_ocr[0]['Words'])
                page_blobs.append(tagger.make_blob(parsed_words))
                tagged = tagger.handler({'body': json.dumps(words_ocr[0])}, {})
                find_untagged_words(parsed_words,tagged)
                formatted = entity_formatter.format_entities(json.loads(tagged['body'])['entities'], page-start+1)['body']
                results[page] = formatted
                create_datapoint("PageTaggedEntitiesExp", {"Entities": formatted, "FilePageIndex": page, "ExpId": exp_id}, txnid ,{"PageTaggedEntitiesExp::DocumentId": docid})
                for key in formatted.keys():
                    if key in formatted_doc:
                        formatted_doc[key] = formatted_doc[key] + formatted[key]
                    else:
                        formatted_doc[key] = formatted[key]
            except:
                print(traceback.format_exc())
                pass
        return formatted_doc
    except:
        print(traceback.format_exc())
        pass
def find_untagged_words(untagged,tagged):
    temp_tagged.append(tagged)
    temp_untagged.append(untagged)

def get_bucket_key(path):
    bucket = path.split('/')[2]
    key = path.replace(f'S3://{bucket}/', '')
    return bucket, key


def get_object(path, s3):
    bucket, key = get_bucket_key(path)
    res = s3.get_object(
        Bucket=bucket,
        Key=key
    )['Body'].read().decode('utf-8')
    return res


def put_object(path, s3, data):
    bucket, key = get_bucket_key(path)
    s3.put_object(
        Bucket=bucket,
        Body=json.dumps(data),
        Key=key
    )
def get_tagged_words(tagged):
    list_of_tagged_word_ids = []
    for page in tagged:
        rip_a_page = json.loads(page["body"])
        for entity in rip_a_page["entities"]:
            list_of_tagged_word_ids.append(entity["word_id"])
    return list_of_tagged_word_ids    
    
def get_untagged_words(untagged,list_of_tagged_word_ids):
    list_of_untagged_word_ids = []
    list_of_untagged_entities = []
    for page in untagged:
        for entity in page:
            list_of_untagged_word_ids.append(entity["word_id"])
    l3 = [x for x in list_of_untagged_word_ids if x not in list_of_tagged_word_ids]
    for word in l3:
        for page in untagged:
            for entity in page:
                if entity["word_id"] == word:
                    list_of_untagged_entities.append(entity)
    return list_of_untagged_entities,l3
    
def memorize_results_update_inplace(docid):
    formatted_doc = aggregate_formatted_entities(docid)
    current_path = remember_recall(docid, '_aggregated_formatted_entities_path')
    new_path = current_path.replace("FormattedEntities", f"FormattedEntities{exp_id}")
    put_object(new_path, s3, formatted_doc)
    return new_path

# %%
df = pd.read_csv("1003_rid_new.csv",names=["rid"])

# %%
temp = df.head(1)

# %%
#temp[f"{exp_id}_path"] = temp.apply(lambda row: memorize_results_update_inplace(row["rid"]), axis = 1)

# %%
aws_json = aggregate_formatted_entities("bd5ff6ce-f0cf-4b16-8e75-5a25b09b6ad6")
# Out:
# Going on a count:  0
# failed to format Unknown string format: 09:23:25 pDT
# failed to format time data '09:23:25 pDT' does not match format '%m/%d/%Y'
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/dateutil/parser/_parser.py:1218: UnknownTimezoneWarning: tzname PDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# failed to format Unknown string format: 7/05 rev.6/09
# failed to format time data '7/05 rev.6/09' does not match format '%m/%d/%Y'
# Match:  434-06-8836
# Match:  438-39-1513
# =====================ENTITIES INFO========================
# [{'entity_id': '8e69a177-89e6-4159-8e42-e46e66506ffa', 'text': 'Yellowstone', 'entity_score': 0.9902280569076538, 'entity_type': 'ORGANIZATION', 'string_index': 0}, {'entity_id': '8e69a177-89e6-4159-8e42-e46e66506ffa', 'text': 'Bank', 'entity_score': 0.9902280569076538, 'entity_type': 'ORGANIZATION', 'string_index': 12}, {'entity_id': 'd3bea1a6-c519-4727-a4e9-b2827d238fcd', 'text': 'LOAN', 'entity_score': 0.47207576036453247, 'entity_type': 'OTHER', 'string_index': 922}, {'entity_id': 'd3bea1a6-c519-4727-a4e9-b2827d238fcd', 'text': '#', 'entity_score': 0.47207576036453247, 'entity_type': 'OTHER', 'string_index': 927}, {'entity_id': 'eb98846d-6017-46dc-9d68-c2b81cc5f7cc', 'text': '1180303', 'entity_score': 0.8419227600097656, 'entity_type': 'OTHER', 'string_index': 930}, {'entity_id': '0b2d4897-dc4c-4ef5-8813-bbc08b5f99da', 'text': 'Borrower', 'entity_score': 0.7616485357284546, 'entity_type': 'ORGANIZATION', 'string_index': 1058}, {'entity_id': 'd06e1132-070c-45e3-ac6f-4b7c479f6256', 'text': 'Co', 'entity_score': 0.5539014339447021, 'entity_type': 'ORGANIZATION', 'string_index': 1071}, {'entity_id': '02bc33bb-0a26-4ccc-8f08-ddb56766d19c', 'text': 'each', 'entity_score': 0.6596502065658569, 'entity_type': 'QUANTITY', 'string_index': 1083}, {'entity_id': 'e4f68a1e-f268-4a8f-aa9b-c9bdb8ec09e8', 'text': 'M', 'entity_score': 0.992927610874176, 'entity_type': 'PERSON', 'string_index': 1185}, {'entity_id': 'e4f68a1e-f268-4a8f-aa9b-c9bdb8ec09e8', 'text': 'Jolunson', 'entity_score': 0.992927610874176, 'entity_type': 'PERSON', 'string_index': 1187}, {'entity_id': '388770cd-2f6d-49d9-b7c0-65dfbf37d937', 'text': '31912018', 'entity_score': 0.9042136669158936, 'entity_type': 'OTHER', 'string_index': 1197}, {'entity_id': '653c2805-b40c-4dfe-af30-46e8ce2f7843', 'text': '09:23:25', 'entity_score': 0.9613386988639832, 'entity_type': 'DATE', 'string_index': 1208}, {'entity_id': '653c2805-b40c-4dfe-af30-46e8ce2f7843', 'text': 'pDT', 'entity_score': 0.9613386988639832, 'entity_type': 'DATE', 'string_index': 1217}, {'entity_id': '0afc7dfc-2dba-4cc0-9c91-e340d190c0fb', 'text': 'VAddoria', 'entity_score': 0.8062213063240051, 'entity_type': 'PERSON', 'string_index': 1224}, {'entity_id': '0afc7dfc-2dba-4cc0-9c91-e340d190c0fb', 'text': 'Switly', 'entity_score': 0.8062213063240051, 'entity_type': 'PERSON', 'string_index': 1233}, {'entity_id': '0afc7dfc-2dba-4cc0-9c91-e340d190c0fb', 'text': 'Jelunson', 'entity_score': 0.8062213063240051, 'entity_type': 'PERSON', 'string_index': 1240}, {'entity_id': 'fc863dba-67a8-48db-868d-d03eb5d29644', 'text': '3/19/2018', 'entity_score': 0.9924353957176208, 'entity_type': 'DATE', 'string_index': 1250}, {'entity_id': '930d0e7f-bf45-4d90-8f3d-9ef10e5e40f2', 'text': '09:30:08', 'entity_score': 0.9322439432144165, 'entity_type': 'DATE', 'string_index': 1262}, {'entity_id': '930d0e7f-bf45-4d90-8f3d-9ef10e5e40f2', 'text': 'PDT', 'entity_score': 0.9322439432144165, 'entity_type': 'DATE', 'string_index': 1271}, {'entity_id': 'cb1a143a-cc5d-4c35-9891-2a150d6987d5', 'text': '1180303', 'entity_score': 0.9066234827041626, 'entity_type': 'OTHER', 'string_index': 1480}, {'entity_id': '7cd2232c-9d65-4f5d-bb6f-d791ed8cc236', 'text': '$', 'entity_score': 0.9923630356788635, 'entity_type': 'QUANTITY', 'string_index': 1572}, {'entity_id': '7cd2232c-9d65-4f5d-bb6f-d791ed8cc236', 'text': '164,700.00', 'entity_score': 0.9923630356788635, 'entity_type': 'QUANTITY', 'string_index': 1574}, {'entity_id': '7cd2232c-9d65-4f5d-bb6f-d791ed8cc236', 'text': '4375', 'entity_score': 0.9923630356788635, 'entity_type': 'QUANTITY', 'string_index': 1585}, {'entity_id': '7cd2232c-9d65-4f5d-bb6f-d791ed8cc236', 'text': '%', 'entity_score': 0.9923630356788635, 'entity_type': 'QUANTITY', 'string_index': 1590}, {'entity_id': '214710b2-d95f-461f-a63a-65be42984498', 'text': '360', 'entity_score': 0.8899042010307312, 'entity_type': 'QUANTITY', 'string_index': 1594}, {'entity_id': '22698403-675a-44c5-85f4-c30ec97e30b9', 'text': '29', 'entity_score': 0.5768851637840 ...
# =====================ENDED========================
# successfully tagged entities: {'entities': [{'entity_id': '8e69a177-89e6-4159-8e42-e46e66506ffa', 'text': 'Yellowstone', 'entity_score': 0.9902280569076538, 'entity_type': 'ORGANIZATION', 'word_id': 'word_1_1', 'bounding_box': [1139, 84, 1329, 109], 'confidence': 0.91}, {'entity_id': '8e69a177-89e6-4159-8e42-e46e66506ffa', 'text': 'Bank', 'entity_score': 0.9902280569076538, 'entity_type': 'ORGANIZATION', 'word_id': 'word_1_2', 'bounding_box': [1342, 84, 1420, 109], 'confidence': 0.92}, {'entity_id': 'd3bea1a6-c519-4727-a4e9-b2827d238fcd', 'text': 'LOAN', 'entity_score': 0.47207576036453247, 'entity_type': 'OTHER', 'word_id': 'word_1_147', 'bounding_box': [2135, 124, 2223, 149], 'confidence': 0.91}, {'entity_id': 'd3bea1a6-c519-4727-a4e9-b2827d238fcd', 'text': '#:', 'entity_score': 0.47207576036453247, 'entity_type': 'OTHER', 'word_id': 'word_1_148', 'bounding_box': [2234, 124, 2261, 149], 'confidence': 0.91}, {'entity_id': 'eb98846d-6017-46dc-9d68-c2b81cc5f7cc', 'text': '1180303', 'entity_score': 0.8419227600097656, 'entity_type': 'OTHER', 'word_id': 'word_1_149', 'bounding_box': [2275, 124, 2401, 149], 'confidence': 0.96}, {'entity_id': '0b2d4897-dc4c-4ef5-8813-bbc08b5f99da', 'text': 'Borrower', 'entity_score': 0.7616485357284546, 'entity_type': 'ORGANIZATION', 'word_id': 'word_1_173', 'bounding_box': [639, 443, 754, 466], 'confidence': 0.92}, {'entity_id': 'd06e1132-070c-45e3-ac6f-4b7c479f6256', 'text': 'Co-Borrower', 'entity_score': 0.5539014339447021, 'entity_type': 'ORGANIZATION', 'word_id': 'word_1_175', 'bounding_box': [820, 443, 983, 466], 'confidence': 0.92}, {'entity_id': '02bc33bb-0a26-4ccc-8f08-ddb56766d19c', 'text': 'each', 'entity_score': 0.6596502065658569, 'entity_type': 'QUANTITY', 'word_id': 'word_1_176', 'bounding_box': [991, 444, 1052, 466], 'confidence': 0.92}, {'entity_id': 'e4f68a1e-f268-4a8f-aa9b-c9bdb8ec09e8', 'text': 'M', 'entity_score': 0.992927610874176, 'entity_type': 'PERSON', 'word_id': 'word_1_196', 'bounding_box': [297, 495, 332, 529], 'confidence': 0.74}, {'entity_id': 'e4f68a1e-f268-4a8f-aa9b-c9bdb8ec09e8', 'text': 'Jolunson.', 'entity_score': 0.992927610874176, 'entity_type': 'PERSON', 'word_id': 'word_1_197', 'bounding_box': [349, 491, 479, 537], 'confidence': 0.57}, {'entity_id': '388770cd-2f6d-49d9-b7c0-65dfbf37d937', 'text': '31912018', 'entity_score': 0.9042136669158936, 'entity_type': 'OTHER', 'word_id': 'word_1_198', 'bounding_box': [905, 517, 1037, 540], 'confidence': 0.45}, {'entity_id': '653c2805-b40c-4dfe-af30-46e8ce2f7843', 'text': '09:23:25', 'entity_score': 0.9613386988639832, 'entity_type': 'DATE', 'word_id': 'word_1_200', 'bounding_box': [1064, 517, 1182, 540], 'confidence': 0.73}, {'entity_id': '653c2805-b40c-4dfe-af30-46e8ce2f7843', 'text': 'pDT', 'entity_score': 0.9613386988639832, 'entity_type': 'DATE', 'word_id': 'word_1_201', 'bounding_box': [1193, 517, 1251, 540], 'confidence': 0.0}, {'entity_id': '0afc7dfc-2dba-4cc0-9c91-e340d190c0fb', 'text': 'Switly', 'entity_score': 0.8062213063240051, 'entity_type': 'PERSON', 'word_id': 'word_1_204', 'bounding_box': [1458, 491, 1544, 537], 'confidence': 0.13}, {'entity_id': '0afc7dfc-2dba-4cc0-9c91-e340d190c0fb', 'text': 'Jelunson,', 'entity_score': 0.8062213063240051, 'entity_type': 'PERSON', 'word_id': 'word_1_205', 'bounding_box': [1560, 491, 1690, 538], 'confidence': 0.25}, {'entity_id': 'fc863dba-67a8-48db-868d-d03eb5d29644', 'text': '3/19/2018', 'entity_score': 0.9924353957176208, 'entity_type': 'DATE', 'word_id': 'word_1_206', 'bounding_box': [2056, 517, 2187, 540], 'confidence': 0.89}, {'entity_id': '930d0e7f-bf45-4d90-8f3d-9ef10e5e40f2', 'text': '09:30:08', 'entity_score': 0.9322439432144165, 'entity_type': 'DATE', 'word_id': 'word_1_208', 'bounding_box': [2214, 517, 2332, 540], 'confidence': 0.92}, {'entity_id': '930d0e7f-bf45-4d90-8f3d-9ef10e5e40f2', 'text': 'PDT', 'entity_score': 0.9322439432144165, 'entity_type': 'DATE', 'word_id': 'word_1_209', 'bounding_box': [2343, 517, 2401, 540], 'confidence': 0.92}, {'entity_id' ...
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/dateutil/parser/_parser.py:1218: UnknownTimezoneWarning: tzname PST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# failed to format Unknown string format: 7/05 rev.6/09
# failed to format time data '7/05 rev.6/09' does not match format '%m/%d/%Y'
# failed to format Unknown string format: 7/05 rev.6/09
# failed to format time data '7/05 rev.6/09' does not match format '%m/%d/%Y'
# Going on a count:  1
# =====================ENTITIES INFO========================
# [{'entity_id': 'fbc4bf8a-e1b9-4718-b8a5-922c9ae2c3e4', 'text': 'Borrower', 'entity_score': 0.8734652400016785, 'entity_type': 'ORGANIZATION', 'string_index': 0}, {'entity_id': 'fbc4bf8a-e1b9-4718-b8a5-922c9ae2c3e4', 'text': 'Yellowstone', 'entity_score': 0.8734652400016785, 'entity_type': 'ORGANIZATION', 'string_index': 9}, {'entity_id': 'fbc4bf8a-e1b9-4718-b8a5-922c9ae2c3e4', 'text': 'Bank', 'entity_score': 0.8734652400016785, 'entity_type': 'ORGANIZATION', 'string_index': 21}, {'entity_id': 'fbc4bf8a-e1b9-4718-b8a5-922c9ae2c3e4', 'text': 'IV.', 'entity_score': 0.8734652400016785, 'entity_type': 'ORGANIZATION', 'string_index': 26}, {'entity_id': '41feece0-9df7-4064-b2af-c4db0cd769ae', 'text': '1180303', 'entity_score': 0.5023931860923767, 'entity_type': 'LOCATION', 'string_index': 61}, {'entity_id': '24898a12-bc46-478e-8ad7-8ca15fba2317', 'text': '$', 'entity_score': 0.9998103380203247, 'entity_type': 'QUANTITY', 'string_index': 819}, {'entity_id': '24898a12-bc46-478e-8ad7-8ca15fba2317', 'text': '3,727.66', 'entity_score': 0.9998103380203247, 'entity_type': 'QUANTITY', 'string_index': 821}, {'entity_id': '6cab51fe-908c-474d-bee7-8bd7934d82e0', 'text': '$', 'entity_score': 0.9989977478981018, 'entity_type': 'QUANTITY', 'string_index': 832}, {'entity_id': '6cab51fe-908c-474d-bee7-8bd7934d82e0', 'text': '3,727.66', 'entity_score': 0.9989977478981018, 'entity_type': 'QUANTITY', 'string_index': 834}, {'entity_id': '8548511f-4fd6-4ac3-a0f9-2a531a19f63a', 'text': '700.00', 'entity_score': 0.6537825465202332, 'entity_type': 'QUANTITY', 'string_index': 880}, {'entity_id': '858a0950-388f-47a8-9663-942ac2547315', 'text': '$', 'entity_score': 0.9988178610801697, 'entity_type': 'QUANTITY', 'string_index': 889}, {'entity_id': '858a0950-388f-47a8-9663-942ac2547315', 'text': '822.32', 'entity_score': 0.9988178610801697, 'entity_type': 'QUANTITY', 'string_index': 891}, {'entity_id': '4240f037-05b7-43a6-9967-a2c436610e5c', 'text': '50.08', 'entity_score': 0.9978299736976624, 'entity_type': 'QUANTITY', 'string_index': 958}, {'entity_id': '956b2c94-bcd6-4444-99bc-c459ead7cffe', 'text': '200.00', 'entity_score': 0.9980912804603577, 'entity_type': 'QUANTITY', 'string_index': 1004}, {'entity_id': '15756fb4-4d2a-4f72-a023-023fac2ceb1b', 'text': 'Homeowner', 'entity_score': 0.6116047501564026, 'entity_type': 'ORGANIZATION', 'string_index': 1073}, {'entity_id': '2462c64b-31d7-4e9a-88f8-4c33c17e773f', 'text': '0.00', 'entity_score': 0.9932965636253357, 'entity_type': 'QUANTITY', 'string_index': 1150}, {'entity_id': '68ef65c9-79cb-44d6-bad5-05ec114e3095', 'text': '$', 'entity_score': 0.9972246885299683, 'entity_type': 'QUANTITY', 'string_index': 1161}, {'entity_id': '68ef65c9-79cb-44d6-bad5-05ec114e3095', 'text': '3,727.66', 'entity_score': 0.9972246885299683, 'entity_type': 'QUANTITY', 'string_index': 1163}, {'entity_id': '60f6bd37-ca0b-4b68-ae30-dc8f1a17f6c4', 'text': '$', 'entity_score': 0.9970924258232117, 'entity_type': 'QUANTITY', 'string_index': 1174}, {'entity_id': '60f6bd37-ca0b-4b68-ae30-dc8f1a17f6c4', 'text': '$', 'entity_score': 0.9970924258232117, 'entity_type': 'QUANTITY', 'string_index': 1176}, {'entity_id': '60f6bd37-ca0b-4b68-ae30-dc8f1a17f6c4', 'text': '3,727.66', 'entity_score': 0.9970924258232117, 'entity_type': 'QUANTITY', 'string_index': 1178}, {'entity_id': '2ce1ca21-4a1f-463c-bf04-f8ddaddae096', 'text': '$', 'entity_score': 0.9995635151863098, 'entity_type': 'QUANTITY', 'string_index': 1195}, {'entity_id': '2ce1ca21-4a1f-463c-bf04-f8ddaddae096', 'text': '700.00', 'entity_score': 0.9995635151863098, 'entity_type': 'QUANTITY', 'string_index': 1197}, {'entity_id': '800e8af3-ef64-49eb-bb91-9fadc4b23a1f', 'text': 'S', 'entity_score': 0.8990028500556946, 'entity_type': 'QUANTITY', 'string_index': 1205}, {'entity_id': '800e8af3-ef64-49eb-bb91-9fadc4b23a1f', 'text': '1,072.40', 'entity_score': 0.8990028500556946, 'entity_type': 'QUANTITY', 'string_index': 1207}, {'entity_id': '23b5530f-b90a-4898-875f-d1863c8cf3b5', 'text': 'B', 'entity_s ...
# =====================ENDED========================
# successfully tagged entities: {'entities': [{'entity_id': 'fbc4bf8a-e1b9-4718-b8a5-922c9ae2c3e4', 'text': 'Borrower', 'entity_score': 0.8734652400016785, 'entity_type': 'ORGANIZATION', 'word_id': 'word_2_1', 'bounding_box': [519, 166, 663, 191], 'confidence': 0.91}, {'entity_id': 'fbc4bf8a-e1b9-4718-b8a5-922c9ae2c3e4', 'text': 'Yellowstone', 'entity_score': 0.8734652400016785, 'entity_type': 'ORGANIZATION', 'word_id': 'word_2_2', 'bounding_box': [1139, 84, 1329, 109], 'confidence': 0.91}, {'entity_id': 'fbc4bf8a-e1b9-4718-b8a5-922c9ae2c3e4', 'text': 'Bank', 'entity_score': 0.8734652400016785, 'entity_type': 'ORGANIZATION', 'word_id': 'word_2_3', 'bounding_box': [1342, 84, 1420, 109], 'confidence': 0.92}, {'entity_id': 'fbc4bf8a-e1b9-4718-b8a5-922c9ae2c3e4', 'text': 'IV.', 'entity_score': 0.8734652400016785, 'entity_type': 'ORGANIZATION', 'word_id': 'word_2_4', 'bounding_box': [1020, 166, 1054, 190], 'confidence': 0.89}, {'entity_id': '41feece0-9df7-4064-b2af-c4db0cd769ae', 'text': '1180303', 'entity_score': 0.5023931860923767, 'entity_type': 'LOCATION', 'word_id': 'word_2_9', 'bounding_box': [2275, 124, 2401, 149], 'confidence': 0.96}, {'entity_id': '24898a12-bc46-478e-8ad7-8ca15fba2317', 'text': '$', 'entity_score': 0.9998103380203247, 'entity_type': 'QUANTITY', 'word_id': 'word_2_155', 'bounding_box': [466, 1015, 480, 1041], 'confidence': 0.74}, {'entity_id': '24898a12-bc46-478e-8ad7-8ca15fba2317', 'text': '3,727.66', 'entity_score': 0.9998103380203247, 'entity_type': 'QUANTITY', 'word_id': 'word_2_156', 'bounding_box': [653, 1012, 765, 1038], 'confidence': 0.9}, {'entity_id': '6cab51fe-908c-474d-bee7-8bd7934d82e0', 'text': '$', 'entity_score': 0.9989977478981018, 'entity_type': 'QUANTITY', 'word_id': 'word_2_158', 'bounding_box': [1115, 1015, 1130, 1041], 'confidence': 0.87}, {'entity_id': '6cab51fe-908c-474d-bee7-8bd7934d82e0', 'text': '3,727.66', 'entity_score': 0.9989977478981018, 'entity_type': 'QUANTITY', 'word_id': 'word_2_159', 'bounding_box': [1303, 1012, 1415, 1038], 'confidence': 0.92}, {'entity_id': '8548511f-4fd6-4ac3-a0f9-2a531a19f63a', 'text': '700.00', 'entity_score': 0.6537825465202332, 'entity_type': 'QUANTITY', 'word_id': 'word_2_167', 'bounding_box': [1978, 1070, 2065, 1092], 'confidence': 0.61}, {'entity_id': '858a0950-388f-47a8-9663-942ac2547315', 'text': '$', 'entity_score': 0.9988178610801697, 'entity_type': 'QUANTITY', 'word_id': 'word_2_169', 'bounding_box': [2090, 1069, 2105, 1095], 'confidence': 0.83}, {'entity_id': '858a0950-388f-47a8-9663-942ac2547315', 'text': '822.32', 'entity_score': 0.9988178610801697, 'entity_type': 'QUANTITY', 'word_id': 'word_2_170', 'bounding_box': [2305, 1070, 2392, 1092], 'confidence': 0.92}, {'entity_id': '4240f037-05b7-43a6-9967-a2c436610e5c', 'text': '50.08', 'entity_score': 0.9978299736976624, 'entity_type': 'QUANTITY', 'word_id': 'word_2_179', 'bounding_box': [2322, 1179, 2392, 1201], 'confidence': 0.92}, {'entity_id': '956b2c94-bcd6-4444-99bc-c459ead7cffe', 'text': '200.00', 'entity_score': 0.9980912804603577, 'entity_type': 'QUANTITY', 'word_id': 'word_2_185', 'bounding_box': [2305, 1234, 2392, 1256], 'confidence': 0.91}, {'entity_id': '15756fb4-4d2a-4f72-a023-023fac2ceb1b', 'text': 'Homeowner', 'entity_score': 0.6116047501564026, 'entity_type': 'ORGANIZATION', 'word_id': 'word_2_194', 'bounding_box': [1441, 1341, 1591, 1363], 'confidence': 0.91}, {'entity_id': '2462c64b-31d7-4e9a-88f8-4c33c17e773f', 'text': '0.00', 'entity_score': 0.9932965636253357, 'entity_type': 'QUANTITY', 'word_id': 'word_2_206', 'bounding_box': [2338, 1394, 2392, 1416], 'confidence': 0.92}, {'entity_id': '68ef65c9-79cb-44d6-bad5-05ec114e3095', 'text': '$', 'entity_score': 0.9972246885299683, 'entity_type': 'QUANTITY', 'word_id': 'word_2_208', 'bounding_box': [466, 1448, 480, 1474], 'confidence': 0.9}, {'entity_id': '68ef65c9-79cb-44d6-bad5-05ec114e3095', 'text': '3,727.66', 'entity_score': 0.9972246885299683, 'entity_type': 'QUANTITY', 'word_id': 'word_2_209', 'bounding_box': [653, 1449,  ...
# Going on a count:  2
# failed to format Unknown string format: 7/05 rev.6/09
# failed to format time data '7/05 rev.6/09' does not match format '%m/%d/%Y'
# failed to format Unknown string format: 7/05 rev.6/09
# failed to format time data '7/05 rev.6/09' does not match format '%m/%d/%Y'
# =====================ENTITIES INFO========================
# [{'entity_id': '1cf9ec7a-decc-42cb-9231-d5be8ac5c2d5', 'text': 'Yellowstone', 'entity_score': 0.8284072279930115, 'entity_type': 'ORGANIZATION', 'string_index': 0}, {'entity_id': '1cf9ec7a-decc-42cb-9231-d5be8ac5c2d5', 'text': 'Bank', 'entity_score': 0.8284072279930115, 'entity_type': 'ORGANIZATION', 'string_index': 12}, {'entity_id': '1cf9ec7a-decc-42cb-9231-d5be8ac5c2d5', 'text': 'VI.', 'entity_score': 0.8284072279930115, 'entity_type': 'ORGANIZATION', 'string_index': 17}, {'entity_id': '1cf9ec7a-decc-42cb-9231-d5be8ac5c2d5', 'text': 'ASSETS', 'entity_score': 0.8284072279930115, 'entity_type': 'ORGANIZATION', 'string_index': 21}, {'entity_id': 'aa8434db-d007-4f3e-b155-00ddab5c41a2', 'text': '1180303', 'entity_score': 0.6352875828742981, 'entity_type': 'OTHER', 'string_index': 59}, {'entity_id': 'aa8434db-d007-4f3e-b155-00ddab5c41a2', 'text': 'Acct.no', 'entity_score': 0.6352875828742981, 'entity_type': 'OTHER', 'string_index': 67}, {'entity_id': 'b6118a94-1d55-49c9-aa8b-d54175e2f8b4', 'text': '$', 'entity_score': 0.9865849614143372, 'entity_type': 'QUANTITY', 'string_index': 85}, {'entity_id': 'b6118a94-1d55-49c9-aa8b-d54175e2f8b4', 'text': '2,700.00', 'entity_score': 0.9865849614143372, 'entity_type': 'QUANTITY', 'string_index': 87}, {'entity_id': '6a4317e4-8767-467d-8690-804f59f73114', 'text': 'Union', 'entity_score': 0.803857147693634, 'entity_type': 'ORGANIZATION', 'string_index': 187}, {'entity_id': 'f89667e7-551c-4676-ada1-f5bcd4dae3b6', 'text': 'FIN', 'entity_score': 0.9042515754699707, 'entity_type': 'ORGANIZATION', 'string_index': 202}, {'entity_id': 'f89667e7-551c-4676-ada1-f5bcd4dae3b6', 'text': 'SVCS', 'entity_score': 0.9042515754699707, 'entity_type': 'ORGANIZATION', 'string_index': 206}, {'entity_id': 'f89667e7-551c-4676-ada1-f5bcd4dae3b6', 'text': 'LLC', 'entity_score': 0.9042515754699707, 'entity_type': 'ORGANIZATION', 'string_index': 211}, {'entity_id': '68f066a4-33b2-4ebd-8e81-7a7db88420d6', 'text': '146.00', 'entity_score': 0.8945065140724182, 'entity_type': 'QUANTITY', 'string_index': 215}, {'entity_id': 'cd3b2845-3191-47c0-b1d6-7d92524030b6', 'text': 'JD', 'entity_score': 0.5717811584472656, 'entity_type': 'LOCATION', 'string_index': 234}, {'entity_id': '649511d7-51f3-4424-ae28-30d6d5528ff6', 'text': 'Bank', 'entity_score': 0.5155511498451233, 'entity_type': 'ORGANIZATION', 'string_index': 237}, {'entity_id': 'b5018ccd-5fec-4ad0-98a7-e9ea0b1a66a5', 'text': 'Kinder,', 'entity_score': 0.8013015389442444, 'entity_type': 'LOCATION', 'string_index': 242}, {'entity_id': 'b5018ccd-5fec-4ad0-98a7-e9ea0b1a66a5', 'text': 'LA', 'entity_score': 0.8013015389442444, 'entity_type': 'LOCATION', 'string_index': 250}, {'entity_id': 'd7dedbbc-376c-42a7-91ba-dfaae759fe90', 'text': '601149948367', 'entity_score': 0.8499548435211182, 'entity_type': 'OTHER', 'string_index': 262}, {'entity_id': 'ccc5fc28-88eb-4780-95ce-5cac6f2700a2', 'text': 'Acct.no', 'entity_score': 0.4471327066421509, 'entity_type': 'OTHER', 'string_index': 275}, {'entity_id': '5e790cd4-2deb-4155-9a75-8b4bfa1c813b', 'text': '$', 'entity_score': 0.9869682192802429, 'entity_type': 'QUANTITY', 'string_index': 293}, {'entity_id': '5e790cd4-2deb-4155-9a75-8b4bfa1c813b', 'text': '800.00', 'entity_score': 0.9869682192802429, 'entity_type': 'QUANTITY', 'string_index': 295}, {'entity_id': '39c12130-9d86-4b2d-bb4a-5d9b59597ce4', 'text': '55.00', 'entity_score': 0.6695772409439087, 'entity_type': 'QUANTITY', 'string_index': 402}, {'entity_id': '35375ce5-cbc4-46a5-843f-33226ea2cebe', 'text': '5,559.00', 'entity_score': 0.6704828143119812, 'entity_type': 'QUANTITY', 'string_index': 408}, {'entity_id': '71dfe3fa-25f4-424e-ad08-69a87f287670', 'text': '102', 'entity_score': 0.7663636207580566, 'entity_type': 'OTHER', 'string_index': 431}, {'entity_id': '71dfe3fa-25f4-424e-ad08-69a87f287670', 'text': 'PO', 'entity_score': 0.7663636207580566, 'entity_type': 'OTHER', 'string_index': 435}, {'entity_id': '71dfe3fa-25f4-424e-ad08-69a87f287670', 'text': 'BOX', 'entity_score': 0.76 ...
# =====================ENDED========================
# successfully tagged entities: {'entities': [{'entity_id': '1cf9ec7a-decc-42cb-9231-d5be8ac5c2d5', 'text': 'Yellowstone', 'entity_score': 0.8284072279930115, 'entity_type': 'ORGANIZATION', 'word_id': 'word_3_1', 'bounding_box': [1139, 84, 1329, 109], 'confidence': 0.91}, {'entity_id': '1cf9ec7a-decc-42cb-9231-d5be8ac5c2d5', 'text': 'Bank', 'entity_score': 0.8284072279930115, 'entity_type': 'ORGANIZATION', 'word_id': 'word_3_2', 'bounding_box': [1342, 84, 1420, 109], 'confidence': 0.92}, {'entity_id': '1cf9ec7a-decc-42cb-9231-d5be8ac5c2d5', 'text': 'VI.', 'entity_score': 0.8284072279930115, 'entity_type': 'ORGANIZATION', 'word_id': 'word_3_3', 'bounding_box': [981, 165, 1020, 190], 'confidence': 0.89}, {'entity_id': '1cf9ec7a-decc-42cb-9231-d5be8ac5c2d5', 'text': 'ASSETS', 'entity_score': 0.8284072279930115, 'entity_type': 'ORGANIZATION', 'word_id': 'word_3_4', 'bounding_box': [1028, 164, 1159, 190], 'confidence': 0.91}, {'entity_id': 'aa8434db-d007-4f3e-b155-00ddab5c41a2', 'text': '1180303', 'entity_score': 0.6352875828742981, 'entity_type': 'OTHER', 'word_id': 'word_3_10', 'bounding_box': [2275, 124, 2397, 149], 'confidence': 0.96}, {'entity_id': 'aa8434db-d007-4f3e-b155-00ddab5c41a2', 'text': 'Acct.no.', 'entity_score': 0.6352875828742981, 'entity_type': 'OTHER', 'word_id': 'word_3_65', 'bounding_box': [153, 214, 260, 237], 'confidence': 0.78}, {'entity_id': 'b6118a94-1d55-49c9-aa8b-d54175e2f8b4', 'text': '$', 'entity_score': 0.9865849614143372, 'entity_type': 'QUANTITY', 'word_id': 'word_3_67', 'bounding_box': [715, 213, 730, 239], 'confidence': 0.86}, {'entity_id': 'b6118a94-1d55-49c9-aa8b-d54175e2f8b4', 'text': '2,700.00|', 'entity_score': 0.9865849614143372, 'entity_type': 'QUANTITY', 'word_id': 'word_3_68', 'bounding_box': [908, 216, 1020, 241], 'confidence': 0.84}, {'entity_id': '6a4317e4-8767-467d-8690-804f59f73114', 'text': 'Union', 'entity_score': 0.803857147693634, 'entity_type': 'ORGANIZATION', 'word_id': 'word_3_86', 'bounding_box': [714, 264, 787, 286], 'confidence': 0.91}, {'entity_id': 'f89667e7-551c-4676-ada1-f5bcd4dae3b6', 'text': 'FIN', 'entity_score': 0.9042515754699707, 'entity_type': 'ORGANIZATION', 'word_id': 'word_3_88', 'bounding_box': [1202, 258, 1245, 280], 'confidence': 0.86}, {'entity_id': 'f89667e7-551c-4676-ada1-f5bcd4dae3b6', 'text': 'SVCS', 'entity_score': 0.9042515754699707, 'entity_type': 'ORGANIZATION', 'word_id': 'word_3_89', 'bounding_box': [1256, 258, 1333, 280], 'confidence': 0.89}, {'entity_id': 'f89667e7-551c-4676-ada1-f5bcd4dae3b6', 'text': 'LLC', 'entity_score': 0.9042515754699707, 'entity_type': 'ORGANIZATION', 'word_id': 'word_3_90', 'bounding_box': [1345, 258, 1398, 280], 'confidence': 0.89}, {'entity_id': '68f066a4-33b2-4ebd-8e81-7a7db88420d6', 'text': '146.00', 'entity_score': 0.8945065140724182, 'entity_type': 'QUANTITY', 'word_id': 'word_3_91', 'bounding_box': [1970, 252, 2056, 292], 'confidence': 0.93}, {'entity_id': 'cd3b2845-3191-47c0-b1d6-7d92524030b6', 'text': 'JD', 'entity_score': 0.5717811584472656, 'entity_type': 'LOCATION', 'word_id': 'word_3_94', 'bounding_box': [156, 310, 192, 332], 'confidence': 0.91}, {'entity_id': '649511d7-51f3-4424-ae28-30d6d5528ff6', 'text': 'Bank', 'entity_score': 0.5155511498451233, 'entity_type': 'ORGANIZATION', 'word_id': 'word_3_95', 'bounding_box': [202, 310, 271, 332], 'confidence': 0.91}, {'entity_id': 'b5018ccd-5fec-4ad0-98a7-e9ea0b1a66a5', 'text': 'Kinder,', 'entity_score': 0.8013015389442444, 'entity_type': 'LOCATION', 'word_id': 'word_3_96', 'bounding_box': [157, 343, 252, 369], 'confidence': 0.89}, {'entity_id': 'b5018ccd-5fec-4ad0-98a7-e9ea0b1a66a5', 'text': 'LA', 'entity_score': 0.8013015389442444, 'entity_type': 'LOCATION', 'word_id': 'word_3_97', 'bounding_box': [263, 343, 300, 365], 'confidence': 0.96}, {'entity_id': 'd7dedbbc-376c-42a7-91ba-dfaae759fe90', 'text': '601149948367', 'entity_score': 0.8499548435211182, 'entity_type': 'OTHER', 'word_id': 'word_3_99', 'bounding_box': [1178, 440, 1370, 462], 'confidence': 0.96}, {'e ...
# Going on a count:  3
# failed to format Unknown string format: three
# failed to format time data 'three' does not match format '%m/%d/%Y'
# =====================ENTITIES INFO========================
# [{'entity_id': '64dfd3a8-1b66-47bf-91bf-d21fe1ab7b6f', 'text': 'Yellowstone', 'entity_score': 0.9010781645774841, 'entity_type': 'ORGANIZATION', 'string_index': 0}, {'entity_id': '64dfd3a8-1b66-47bf-91bf-d21fe1ab7b6f', 'text': 'Bank', 'entity_score': 0.9010781645774841, 'entity_type': 'ORGANIZATION', 'string_index': 12}, {'entity_id': '64dfd3a8-1b66-47bf-91bf-d21fe1ab7b6f', 'text': 'LOAN', 'entity_score': 0.9010781645774841, 'entity_type': 'ORGANIZATION', 'string_index': 17}, {'entity_id': '57e75513-40c2-4c4e-a4e5-2a85a3a08fae', 'text': '1180303', 'entity_score': 0.7577444911003113, 'entity_type': 'OTHER', 'string_index': 25}, {'entity_id': '8bed8ec0-bbca-4168-baa3-f564cb478dc4', 'text': '500.00', 'entity_score': 0.994083821773529, 'entity_type': 'QUANTITY', 'string_index': 218}, {'entity_id': 'e7fd7b28-7d8d-4873-b55e-277254a87bdd', 'text': 'llgnation', 'entity_score': 0.5164151191711426, 'entity_type': 'OTHER', 'string_index': 252}, {'entity_id': '9681ea05-0a2b-4077-88e2-d9149eb89e7e', 'text': 'U.S.', 'entity_score': 0.9447214603424072, 'entity_type': 'LOCATION', 'string_index': 635}, {'entity_id': '6ad5f75b-8584-4036-b223-faf3bcacc7a2', 'text': '164.700.00', 'entity_score': 0.9954314231872559, 'entity_type': 'QUANTITY', 'string_index': 666}, {'entity_id': '3749c5df-e567-4801-b6a9-dc427fbda2a4', 'text': '¥', 'entity_score': 0.7077738046646118, 'entity_type': 'QUANTITY', 'string_index': 836}, {'entity_id': '2e1d1ea3-d2a1-4646-aae5-dfa4463dac0e', 'text': 'three', 'entity_score': 0.43088197708129883, 'entity_type': 'DATE', 'string_index': 942}, {'entity_id': '4ce7a4db-6069-45fc-ac83-32dac3f75a9f', 'text': 'years', 'entity_score': 0.46118301153182983, 'entity_type': 'QUANTITY', 'string_index': 948}, {'entity_id': '8b940bd2-c65d-4dcd-9e96-891ffcdcc007', 'text': '¥', 'entity_score': 0.9555363655090332, 'entity_type': 'QUANTITY', 'string_index': 958}, {'entity_id': '0dd59dea-0931-48e5-85e7-e406a69228a1', 'text': '164,700.00', 'entity_score': 0.9083118438720703, 'entity_type': 'QUANTITY', 'string_index': 985}, {'entity_id': '14de18c1-19ff-41cc-a0d9-719e93850cda', 'text': '85,620.36', 'entity_score': 0.8240308165550232, 'entity_type': 'QUANTITY', 'string_index': 1093}, {'entity_id': '14de18c1-19ff-41cc-a0d9-719e93850cda', 'text': 'home', 'entity_score': 0.8240308165550232, 'entity_type': 'QUANTITY', 'string_index': 1103}, {'entity_id': '1e8ee0e3-e53f-4e28-87c6-f445af865ecc', 'text': 'S', 'entity_score': 0.8456611037254333, 'entity_type': 'PERSON', 'string_index': 1224}, {'entity_id': 'a2f2653c-0bef-4aec-bfb0-0759e5f67631', 'text': 'Each', 'entity_score': 0.8178529143333435, 'entity_type': 'QUANTITY', 'string_index': 1330}, {'entity_id': '76caecfa-d551-4f66-8b84-cc857dcc21d0', 'text': 'Lender', 'entity_score': 0.4817068576812744, 'entity_type': 'PERSON', 'string_index': 1381}, {'entity_id': '499a5d9c-b64d-4a14-b42f-648fcb94f88a', 'text': 'Lender', 'entity_score': 0.7020429372787476, 'entity_type': 'PERSON', 'string_index': 1395}, {'entity_id': 'c65aef38-ff5d-4d93-b385-d88ca50eff3f', 'text': '1', 'entity_score': 0.5119611620903015, 'entity_type': 'QUANTITY', 'string_index': 1542}, {'entity_id': 'bd61f9e8-c123-450d-a9fe-3f8cd884d29e', 'text': 'both', 'entity_score': 0.5011534094810486, 'entity_type': 'QUANTITY', 'string_index': 2024}, {'entity_id': '17b156c0-479d-48dd-a6a5-8dd5433df255', 'text': 'Title', 'entity_score': 0.873329222202301, 'entity_type': 'TITLE', 'string_index': 2053}, {'entity_id': '17b156c0-479d-48dd-a6a5-8dd5433df255', 'text': '18,', 'entity_score': 0.873329222202301, 'entity_type': 'TITLE', 'string_index': 2059}, {'entity_id': '17b156c0-479d-48dd-a6a5-8dd5433df255', 'text': 'United', 'entity_score': 0.873329222202301, 'entity_type': 'TITLE', 'string_index': 2063}, {'entity_id': '17b156c0-479d-48dd-a6a5-8dd5433df255', 'text': 'States', 'entity_score': 0.873329222202301, 'entity_type': 'TITLE', 'string_index': 2070}, {'entity_id': '17b156c0-479d-48dd-a6a5-8dd5433df255', 'text': 'Code,', 'entity_score': 0.873329222202301 ...
# =====================ENDED========================
# successfully tagged entities: {'entities': [{'entity_id': '64dfd3a8-1b66-47bf-91bf-d21fe1ab7b6f', 'text': 'Yellowstone', 'entity_score': 0.9010781645774841, 'entity_type': 'ORGANIZATION', 'word_id': 'word_4_1', 'bounding_box': [1140, 81, 1330, 106], 'confidence': 0.91}, {'entity_id': '64dfd3a8-1b66-47bf-91bf-d21fe1ab7b6f', 'text': 'Bank', 'entity_score': 0.9010781645774841, 'entity_type': 'ORGANIZATION', 'word_id': 'word_4_2', 'bounding_box': [1342, 81, 1421, 106], 'confidence': 0.9}, {'entity_id': '64dfd3a8-1b66-47bf-91bf-d21fe1ab7b6f', 'text': 'LOAN', 'entity_score': 0.9010781645774841, 'entity_type': 'ORGANIZATION', 'word_id': 'word_4_3', 'bounding_box': [2135, 121, 2224, 147], 'confidence': 0.9}, {'entity_id': '57e75513-40c2-4c4e-a4e5-2a85a3a08fae', 'text': '1180303', 'entity_score': 0.7577444911003113, 'entity_type': 'OTHER', 'word_id': 'word_4_5', 'bounding_box': [2275, 121, 2401, 147], 'confidence': 0.96}, {'entity_id': '8bed8ec0-bbca-4168-baa3-f564cb478dc4', 'text': '500.00', 'entity_score': 0.994083821773529, 'entity_type': 'QUANTITY', 'word_id': 'word_4_37', 'bounding_box': [958, 250, 1045, 272], 'confidence': 0.93}, {'entity_id': '9681ea05-0a2b-4077-88e2-d9149eb89e7e', 'text': 'U.S.', 'entity_score': 0.9447214603424072, 'entity_type': 'LOCATION', 'word_id': 'word_4_122', 'bounding_box': [1236, 625, 1287, 648], 'confidence': 0.75}, {'entity_id': '6ad5f75b-8584-4036-b223-faf3bcacc7a2', 'text': '164.700.00', 'entity_score': 0.9954314231872559, 'entity_type': 'QUANTITY', 'word_id': 'word_4_128', 'bounding_box': [899, 672, 1042, 735], 'confidence': 0.64}, {'entity_id': '3749c5df-e567-4801-b6a9-dc427fbda2a4', 'text': '¥', 'entity_score': 0.7077738046646118, 'entity_type': 'QUANTITY', 'word_id': 'word_4_159', 'bounding_box': [2077, 714, 2128, 750], 'confidence': 0.0}, {'entity_id': '2e1d1ea3-d2a1-4646-aae5-dfa4463dac0e', 'text': 'three', 'entity_score': 0.43088197708129883, 'entity_type': 'DATE', 'word_id': 'word_4_181', 'bounding_box': [1876, 805, 1941, 827], 'confidence': 0.92}, {'entity_id': '4ce7a4db-6069-45fc-ac83-32dac3f75a9f', 'text': 'years?', 'entity_score': 0.46118301153182983, 'entity_type': 'QUANTITY', 'word_id': 'word_4_182', 'bounding_box': [1950, 805, 2035, 833], 'confidence': 0.91}, {'entity_id': '8b940bd2-c65d-4dcd-9e96-891ffcdcc007', 'text': '¥', 'entity_score': 0.9555363655090332, 'entity_type': 'QUANTITY', 'word_id': 'word_4_184', 'bounding_box': [2252, 793, 2302, 829], 'confidence': 0.0}, {'entity_id': '0dd59dea-0931-48e5-85e7-e406a69228a1', 'text': '164,700.00', 'entity_score': 0.9083118438720703, 'entity_type': 'QUANTITY', 'word_id': 'word_4_194', 'bounding_box': [899, 832, 1042, 888], 'confidence': 0.91}, {'entity_id': '14de18c1-19ff-41cc-a0d9-719e93850cda', 'text': '85,620.36', 'entity_score': 0.8240308165550232, 'entity_type': 'QUANTITY', 'word_id': 'word_4_212', 'bounding_box': [914, 885, 1042, 925], 'confidence': 0.92}, {'entity_id': '14de18c1-19ff-41cc-a0d9-719e93850cda', 'text': 'home', 'entity_score': 0.8240308165550232, 'entity_type': 'QUANTITY', 'word_id': 'word_4_213', 'bounding_box': [1153, 888, 1224, 910], 'confidence': 0.92}, {'entity_id': '1e8ee0e3-e53f-4e28-87c6-f445af865ecc', 'text': 'S,', 'entity_score': 0.8456611037254333, 'entity_type': 'PERSON', 'word_id': 'word_4_241', 'bounding_box': [1757, 937, 1799, 965], 'confidence': 0.89}, {'entity_id': 'a2f2653c-0bef-4aec-bfb0-0759e5f67631', 'text': 'Each', 'entity_score': 0.8178529143333435, 'entity_type': 'QUANTITY', 'word_id': 'word_4_263', 'bounding_box': [154, 1153, 217, 1174], 'confidence': 0.91}, {'entity_id': '76caecfa-d551-4f66-8b84-cc857dcc21d0', 'text': 'Lender', 'entity_score': 0.4817068576812744, 'entity_type': 'PERSON', 'word_id': 'word_4_270', 'bounding_box': [784, 1153, 872, 1174], 'confidence': 0.91}, {'entity_id': '499a5d9c-b64d-4a14-b42f-648fcb94f88a', 'text': 'Lender’s', 'entity_score': 0.7020429372787476, 'entity_type': 'PERSON', 'word_id': 'word_4_273', 'bounding_box': [964, 1153, 1071, 1175], 'confidence': 0.84}, {' ...
# Going on a count:  4
# =====================ENTITIES INFO========================
# [{'entity_id': '851ced7a-2c9f-47c5-8659-e335f92f47ab', 'text': 'Yellowstone', 'entity_score': 0.9028798341751099, 'entity_type': 'ORGANIZATION', 'string_index': 0}, {'entity_id': '851ced7a-2c9f-47c5-8659-e335f92f47ab', 'text': 'Bank', 'entity_score': 0.9028798341751099, 'entity_type': 'ORGANIZATION', 'string_index': 12}, {'entity_id': '851ced7a-2c9f-47c5-8659-e335f92f47ab', 'text': 'LOAN', 'entity_score': 0.9028798341751099, 'entity_type': 'ORGANIZATION', 'string_index': 17}, {'entity_id': '545b4a89-301f-41ff-86e0-ba12dd9e55e0', 'text': '1180303', 'entity_score': 0.965457558631897, 'entity_type': 'OTHER', 'string_index': 25}, {'entity_id': 'af173710-f041-4fc5-a3ad-1fceceb00fc2', 'text': 'Daniel', 'entity_score': 0.9928919672966003, 'entity_type': 'PERSON', 'string_index': 188}, {'entity_id': 'af173710-f041-4fc5-a3ad-1fceceb00fc2', 'text': 'M', 'entity_score': 0.9928919672966003, 'entity_type': 'PERSON', 'string_index': 195}, {'entity_id': 'af173710-f041-4fc5-a3ad-1fceceb00fc2', 'text': 'Johnson', 'entity_score': 0.9928919672966003, 'entity_type': 'PERSON', 'string_index': 197}, {'entity_id': '4f5a1cfa-a24b-4ff6-bc91-5825eecf5b6e', 'text': 'Victoria', 'entity_score': 0.9353666305541992, 'entity_type': 'PERSON', 'string_index': 238}, {'entity_id': '4f5a1cfa-a24b-4ff6-bc91-5825eecf5b6e', 'text': 'Smith', 'entity_score': 0.9353666305541992, 'entity_type': 'PERSON', 'string_index': 247}, {'entity_id': '4f5a1cfa-a24b-4ff6-bc91-5825eecf5b6e', 'text': 'Johnson', 'entity_score': 0.9353666305541992, 'entity_type': 'PERSON', 'string_index': 253}, {'entity_id': '6389bb72-a025-4ae1-bc93-38f43be11d24', 'text': '1180303', 'entity_score': 0.9870337247848511, 'entity_type': 'OTHER', 'string_index': 281}, {'entity_id': 'c648bcd4-cbdf-4403-97b2-64693279ba6b', 'text': 'ASSETS', 'entity_score': 0.5536984801292419, 'entity_type': 'ORGANIZATION', 'string_index': 293}, {'entity_id': 'bffb319d-b75a-4e3d-afda-145914077c86', 'text': 'Joint', 'entity_score': 0.5163435935974121, 'entity_type': 'ORGANIZATION', 'string_index': 358}, {'entity_id': 'bffb319d-b75a-4e3d-afda-145914077c86', 'text': 'J', 'entity_score': 0.5163435935974121, 'entity_type': 'ORGANIZATION', 'string_index': 364}, {'entity_id': '5e3a269c-d6d3-457d-8509-7b24d2adbd4b', 'text': '$', 'entity_score': 0.8104838132858276, 'entity_type': 'ORGANIZATION', 'string_index': 539}, {'entity_id': '5e3a269c-d6d3-457d-8509-7b24d2adbd4b', 'text': 'JD', 'entity_score': 0.8104838132858276, 'entity_type': 'ORGANIZATION', 'string_index': 541}, {'entity_id': '5e3a269c-d6d3-457d-8509-7b24d2adbd4b', 'text': 'Bank', 'entity_score': 0.8104838132858276, 'entity_type': 'ORGANIZATION', 'string_index': 544}, {'entity_id': '028374e9-f3fd-4250-ba34-46e73656911c', 'text': '0.00', 'entity_score': 0.5143641233444214, 'entity_type': 'QUANTITY', 'string_index': 573}, {'entity_id': 'a8602456-7583-454f-9564-f0175ec96dd2', 'text': '1,015.00', 'entity_score': 0.5577696561813354, 'entity_type': 'OTHER', 'string_index': 579}, {'entity_id': '087f426a-cf67-42be-9d74-4f42c1f96a9b', 'text': 'Kinder,', 'entity_score': 0.4691143035888672, 'entity_type': 'LOCATION', 'string_index': 588}, {'entity_id': '2656c6c5-c60f-4273-a445-389f829bf714', 'text': 'Acct', 'entity_score': 0.6239733695983887, 'entity_type': 'OTHER', 'string_index': 601}, {'entity_id': 'fe776393-115a-48bd-98aa-028bd344b9f1', 'text': '50504844', 'entity_score': 0.5474593043327332, 'entity_type': 'OTHER', 'string_index': 611}, {'entity_id': 'd3b782bb-ed00-4ee9-bb39-372bf29d1559', 'text': '$', 'entity_score': 0.8747095465660095, 'entity_type': 'QUANTITY', 'string_index': 620}, {'entity_id': 'd3b782bb-ed00-4ee9-bb39-372bf29d1559', 'text': '800.00', 'entity_score': 0.8747095465660095, 'entity_type': 'QUANTITY', 'string_index': 622}, {'entity_id': 'e117988f-8b98-4353-9c71-8f4db7d0ef7f', 'text': 'TFC11000050003609085', 'entity_score': 0.9632702469825745, 'entity_type': 'OTHER', 'string_index': 640}, {'entity_id': '8be73fad-55dc-416d-b89a-dc362e8fede6', 'text': '25.00', 'entity_s ...
# =====================ENDED========================
# successfully tagged entities: {'entities': [{'entity_id': '851ced7a-2c9f-47c5-8659-e335f92f47ab', 'text': 'Yellowstone', 'entity_score': 0.9028798341751099, 'entity_type': 'ORGANIZATION', 'word_id': 'word_5_1', 'bounding_box': [1145, 89, 1335, 114], 'confidence': 0.92}, {'entity_id': '851ced7a-2c9f-47c5-8659-e335f92f47ab', 'text': 'Bank', 'entity_score': 0.9028798341751099, 'entity_type': 'ORGANIZATION', 'word_id': 'word_5_2', 'bounding_box': [1347, 89, 1426, 114], 'confidence': 0.9}, {'entity_id': '851ced7a-2c9f-47c5-8659-e335f92f47ab', 'text': 'LOAN', 'entity_score': 0.9028798341751099, 'entity_type': 'ORGANIZATION', 'word_id': 'word_5_3', 'bounding_box': [2140, 124, 2229, 149], 'confidence': 0.92}, {'entity_id': '545b4a89-301f-41ff-86e0-ba12dd9e55e0', 'text': '1180303', 'entity_score': 0.965457558631897, 'entity_type': 'OTHER', 'word_id': 'word_5_5', 'bounding_box': [2280, 124, 2401, 149], 'confidence': 0.96}, {'entity_id': 'af173710-f041-4fc5-a3ad-1fceceb00fc2', 'text': 'Daniel', 'entity_score': 0.9928919672966003, 'entity_type': 'PERSON', 'word_id': 'word_5_30', 'bounding_box': [720, 279, 817, 304], 'confidence': 0.9}, {'entity_id': 'af173710-f041-4fc5-a3ad-1fceceb00fc2', 'text': 'M', 'entity_score': 0.9928919672966003, 'entity_type': 'PERSON', 'word_id': 'word_5_31', 'bounding_box': [829, 279, 853, 304], 'confidence': 0.92}, {'entity_id': 'af173710-f041-4fc5-a3ad-1fceceb00fc2', 'text': 'Johnson', 'entity_score': 0.9928919672966003, 'entity_type': 'PERSON', 'word_id': 'word_5_32', 'bounding_box': [865, 279, 1002, 304], 'confidence': 0.9}, {'entity_id': '4f5a1cfa-a24b-4ff6-bc91-5825eecf5b6e', 'text': 'Victoria', 'entity_score': 0.9353666305541992, 'entity_type': 'PERSON', 'word_id': 'word_5_39', 'bounding_box': [718, 388, 839, 414], 'confidence': 0.92}, {'entity_id': '4f5a1cfa-a24b-4ff6-bc91-5825eecf5b6e', 'text': 'Smith', 'entity_score': 0.9353666305541992, 'entity_type': 'PERSON', 'word_id': 'word_5_40', 'bounding_box': [851, 388, 940, 414], 'confidence': 0.89}, {'entity_id': '4f5a1cfa-a24b-4ff6-bc91-5825eecf5b6e', 'text': 'Johnson', 'entity_score': 0.9353666305541992, 'entity_type': 'PERSON', 'word_id': 'word_5_41', 'bounding_box': [952, 388, 1089, 414], 'confidence': 0.91}, {'entity_id': '6389bb72-a025-4ae1-bc93-38f43be11d24', 'text': '1180303', 'entity_score': 0.9870337247848511, 'entity_type': 'OTHER', 'word_id': 'word_5_46', 'bounding_box': [1770, 388, 1896, 414], 'confidence': 0.96}, {'entity_id': 'c648bcd4-cbdf-4403-97b2-64693279ba6b', 'text': 'ASSETS', 'entity_score': 0.5536984801292419, 'entity_type': 'ORGANIZATION', 'word_id': 'word_5_49', 'bounding_box': [1095, 460, 1226, 486], 'confidence': 0.89}, {'entity_id': 'bffb319d-b75a-4e3d-afda-145914077c86', 'text': 'Joint', 'entity_score': 0.5163435935974121, 'entity_type': 'ORGANIZATION', 'word_id': 'word_5_61', 'bounding_box': [1680, 507, 1732, 526], 'confidence': 0.91}, {'entity_id': 'bffb319d-b75a-4e3d-afda-145914077c86', 'text': 'J', 'entity_score': 0.5163435935974121, 'entity_type': 'ORGANIZATION', 'word_id': 'word_5_62', 'bounding_box': [1741, 507, 1768, 531], 'confidence': 0.92}, {'entity_id': '5e3a269c-d6d3-457d-8509-7b24d2adbd4b', 'text': '$', 'entity_score': 0.8104838132858276, 'entity_type': 'ORGANIZATION', 'word_id': 'word_5_106', 'bounding_box': [2116, 609, 2132, 638], 'confidence': 0.75}, {'entity_id': '5e3a269c-d6d3-457d-8509-7b24d2adbd4b', 'text': 'JD', 'entity_score': 0.8104838132858276, 'entity_type': 'ORGANIZATION', 'word_id': 'word_5_107', 'bounding_box': [156, 657, 197, 682], 'confidence': 0.9}, {'entity_id': '5e3a269c-d6d3-457d-8509-7b24d2adbd4b', 'text': 'Bank', 'entity_score': 0.8104838132858276, 'entity_type': 'ORGANIZATION', 'word_id': 'word_5_108', 'bounding_box': [209, 657, 288, 682], 'confidence': 0.92}, {'entity_id': '087f426a-cf67-42be-9d74-4f42c1f96a9b', 'text': 'Kinder,', 'entity_score': 0.4691143035888672, 'entity_type': 'LOCATION', 'word_id': 'word_5_113', 'bounding_box': [158, 694, 266, 724], 'confidence': 0.9}, {'entity_id': '26 ...
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/dateutil/parser/_parser.py:1218: UnknownTimezoneWarning: tzname PD identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)

# %%
list_of_tagged_word_ids = get_tagged_words(temp_tagged)
list_of_untagged_entities, list_of_untagged_word_ids = get_untagged_words(temp_untagged,list_of_tagged_word_ids)
list_of_untagged_entities
# Out:
# [{'word_id': 'word_1_3',
#   'text': 'Uniform',
#   'string_index': 17,
#   'bounding_box': [691, 150, 936, 201],
#   'confidence': 0.92},
#  {'word_id': 'word_1_4',
#   'text': 'Residential',
#   'string_index': 25,
#   'bounding_box': [962, 150, 1308, 201],
#   'confidence': 0.91},
#  {'word_id': 'word_1_5',
#   'text': 'Loan',
#   'string_index': 37,
#   'bounding_box': [1336, 151, 1486, 201],
#   'confidence': 0.91},
#  {'word_id': 'word_1_6',
#   'text': 'Application',
#   'string_index': 42,
#   'bounding_box': [1507, 150, 1864, 213],
#   'confidence': 0.91},
#  {'word_id': 'word_1_7',
#   'text': 'This',
#   'string_index': 54,
#   'bounding_box': [152, 238, 207, 261],
#   'confidence': 0.92},
#  {'word_id': 'word_1_8',
#   'text': 'application',
#   'string_index': 59,
#   'bounding_box': [215, 238, 352, 266],
#   'confidence': 0.91},
#  {'word_id': 'word_1_9',
#   'text': 'is',
#   'string_index': 71,
#   'bounding_box': [363, 238, 382, 261],
#   'confidence': 0.92},
#  {'word_id': 'word_1_10',
#   'text': 'designed',
#   'string_index': 74,
#   'bounding_box': [390, 238, 507, 267],
#   'confidence': 0.91},
#  {'word_id': 'word_1_11',
#   'text': 'to',
#   'string_index': 83,
#   'bounding_box': [515, 240, 538, 260],
#   'confidence': 0.92},
#  {'word_id': 'word_1_12',
#   'text': 'be',
#   'string_index': 86,
#   'bounding_box': [547, 238, 578, 261],
#   'confidence': 0.92},
#  {'word_id': 'word_1_13',
#   'text': 'completed',
#   'string_index': 89,
#   'bounding_box': [586, 238, 718, 266],
#   'confidence': 0.92},
#  {'word_id': 'word_1_14',
#   'text': 'by',
#   'string_index': 99,
#   'bounding_box': [728, 238, 757, 266],
#   'confidence': 0.93},
#  {'word_id': 'word_1_15',
#   'text': 'the',
#   'string_index': 102,
#   'bounding_box': [765, 238, 804, 261],
#   'confidence': 0.92},
#  {'word_id': 'word_1_16',
#   'text': 'applicants',
#   'string_index': 106,
#   'bounding_box': [813, 238, 961, 266],
#   'confidence': 0.91},
#  {'word_id': 'word_1_17',
#   'text': 'with',
#   'string_index': 117,
#   'bounding_box': [971, 238, 1021, 260],
#   'confidence': 0.92},
#  {'word_id': 'word_1_18',
#   'text': 'the',
#   'string_index': 122,
#   'bounding_box': [1030, 238, 1069, 261],
#   'confidence': 0.92},
#  {'word_id': 'word_1_19',
#   'text': 'Lender’s',
#   'string_index': 126,
#   'bounding_box': [1079, 238, 1188, 261],
#   'confidence': 0.76},
#  {'word_id': 'word_1_20',
#   'text': 'assistance.',
#   'string_index': 135,
#   'bounding_box': [1196, 238, 1338, 261],
#   'confidence': 0.92},
#  {'word_id': 'word_1_21',
#   'text': 'Applicants',
#   'string_index': 147,
#   'bounding_box': [1345, 238, 1479, 266],
#   'confidence': 0.93},
#  {'word_id': 'word_1_22',
#   'text': 'should',
#   'string_index': 158,
#   'bounding_box': [1487, 238, 1571, 261],
#   'confidence': 0.92},
#  {'word_id': 'word_1_23',
#   'text': 'complete',
#   'string_index': 165,
#   'bounding_box': [1580, 238, 1696, 266],
#   'confidence': 0.91},
#  {'word_id': 'word_1_24',
#   'text': 'this',
#   'string_index': 174,
#   'bounding_box': [1705, 238, 1749, 261],
#   'confidence': 0.92},
#  {'word_id': 'word_1_25',
#   'text': 'form',
#   'string_index': 179,
#   'bounding_box': [1757, 238, 1814, 260],
#   'confidence': 0.93},
#  {'word_id': 'word_1_26',
#   'text': 'as',
#   'string_index': 184,
#   'bounding_box': [1823, 244, 1853, 261],
#   'confidence': 0.92},
#  {'word_id': 'word_1_27',
#   'text': '“Borrower”',
#   'string_index': 187,
#   'bounding_box': [1861, 238, 1996, 261],
#   'confidence': 0.88},
#  {'word_id': 'word_1_28',
#   'text': 'or',
#   'string_index': 198,
#   'bounding_box': [2003, 244, 2029, 261],
#   'confidence': 0.91},
#  {'word_id': 'word_1_29',
#   'text': '“Co-Borrower,”',
#   'string_index': 201,
#   'bounding_box': [2035, 238, 2221, 264],
#   'confidence': 0.88},
#  {'word_id': 'word_1_30',
#   'text': 'as',
#   'string_index': 216,
#   'bounding_box': [2228, 244, 2257, 261],
#   'confidence': 0.92},
#  {'word_id': 'word_1_31',
#   'text': 'applicable.',
#   'string_index': 219,
#   'bounding_box': [2266, 238, 2402, 266],
#   'confidence': 0.9},
#  {'word_id': 'word_1_32',
#   'text': 'Co-Borrower',
#   'string_index': 231,
#   'bounding_box': [153, 270, 316, 292],
#   'confidence': 0.92},
#  {'word_id': 'word_1_33',
#   'text': 'information',
#   'string_index': 243,
#   'bounding_box': [324, 270, 465, 292],
#   'confidence': 0.91},
#  {'word_id': 'word_1_34',
#   'text': 'must',
#   'string_index': 255,
#   'bounding_box': [475, 272, 536, 292],
#   'confidence': 0.93},
#  {'word_id': 'word_1_35',
#   'text': 'also',
#   'string_index': 260,
#   'bounding_box': [544, 270, 597, 292],
#   'confidence': 0.92},
#  {'word_id': 'word_1_36',
#   'text': 'be',
#   'string_index': 265,
#   'bounding_box': [605, 271, 636, 292],
#   'confidence': 0.92},
#  {'word_id': 'word_1_37',
#   'text': 'provided',
#   'string_index': 268,
#   'bounding_box': [645, 270, 753, 298],
#   'confidence': 0.92},
#  {'word_id': 'word_1_38',
#   'text': 'and',
#   'string_index': 277,
#   'bounding_box': [763, 270, 819, 298],
#   'confidence': 0.93},
#  {'word_id': 'word_1_39',
#   'text': 'the',
#   'string_index': 281,
#   'bounding_box': [827, 271, 866, 292],
#   'confidence': 0.91},
#  {'word_id': 'word_1_40',
#   'text': 'appropriate',
#   'string_index': 285,
#   'bounding_box': [875, 270, 1020, 298],
#   'confidence': 0.91},
#  {'word_id': 'word_1_41',
#   'text': 'box',
#   'string_index': 297,
#   'bounding_box': [1029, 270, 1073, 292],
#   'confidence': 0.91},
#  {'word_id': 'word_1_42',
#   'text': 'checked',
#   'string_index': 301,
#   'bounding_box': [1082, 270, 1197, 298],
#   'confidence': 0.92},
#  {'word_id': 'word_1_43',
#   'text': 'when',
#   'string_index': 309,
#   'bounding_box': [1206, 271, 1273, 292],
#   'confidence': 0.92},
#  {'word_id': 'word_1_44',
#   'text': 'the',
#   'string_index': 314,
#   'bounding_box': [1354, 270, 1394, 292],
#   'confidence': 0.92},
#  {'word_id': 'word_1_45',
#   'text': 'income',
#   'string_index': 318,
#   'bounding_box': [1403, 271, 1495, 292],
#   'confidence': 0.92},
#  {'word_id': 'word_1_46',
#   'text': 'or',
#   'string_index': 325,
#   'bounding_box': [1504, 276, 1529, 292],
#   'confidence': 0.93},
#  {'word_id': 'word_1_47',
#   'text': 'assets',
#   'string_index': 328,
#   'bounding_box': [1537, 272, 1619, 292],
#   'confidence': 0.92},
#  {'word_id': 'word_1_48',
#   'text': 'of',
#   'string_index': 335,
#   'bounding_box': [1628, 271, 1651, 292],
#   'confidence': 0.93},
#  {'word_id': 'word_1_49',
#   'text': 'a',
#   'string_index': 338,
#   'bounding_box': [1659, 276, 1674, 292],
#   'confidence': 0.93},
#  {'word_id': 'word_1_50',
#   'text': 'person',
#   'string_index': 340,
#   'bounding_box': [1683, 276, 1768, 298],
#   'confidence': 0.93},
#  {'word_id': 'word_1_51',
#   'text': 'other',
#   'string_index': 347,
#   'bounding_box': [1778, 270, 1844, 292],
#   'confidence': 0.92},
#  {'word_id': 'word_1_52',
#   'text': 'than',
#   'string_index': 353,
#   'bounding_box': [1851, 270, 1906, 292],
#   'confidence': 0.93},
#  {'word_id': 'word_1_53',
#   'text': 'the',
#   'string_index': 358,
#   'bounding_box': [1914, 271, 1954, 292],
#   'confidence': 0.93},
#  {'word_id': 'word_1_54',
#   'text': 'Borrower',
#   'string_index': 362,
#   'bounding_box': [1963, 270, 2079, 292],
#   'confidence': 0.91},
#  {'word_id': 'word_1_55',
#   'text': 'including',
#   'string_index': 371,
#   'bounding_box': [2087, 270, 2209, 298],
#   'confidence': 0.91},
#  {'word_id': 'word_1_56',
#   'text': 'the',
#   'string_index': 381,
#   'bounding_box': [2218, 270, 2257, 292],
#   'confidence': 0.92},
#  {'word_id': 'word_1_57',
#   'text': 'Borrower’s',
#   'string_index': 385,
#   'bounding_box': [2267, 270, 2401, 292],
#   'confidence': 0.64},
#  {'word_id': 'word_1_58',
#   'text': 'spouse',
#   'string_index': 396,
#   'bounding_box': [153, 303, 254, 330],
#   'confidence': 0.91},
#  {'word_id': 'word_1_59',
#   'text': 'will',
#   'string_index': 403,
#   'bounding_box': [263, 302, 302, 324],
#   'confidence': 0.92},
#  {'word_id': 'word_1_60',
#   'text': 'be',
#   'string_index': 408,
#   'bounding_box': [313, 303, 343, 325],
#   'confidence': 0.93},
#  {'word_id': 'word_1_61',
#   'text': 'used',
#   'string_index': 411,
#   'bounding_box': [352, 303, 413, 325],
#   'confidence': 0.92},
#  {'word_id': 'word_1_62',
#   'text': 'as',
#   'string_index': 416,
#   'bounding_box': [422, 308, 451, 325],
#   'confidence': 0.93},
#  {'word_id': 'word_1_63',
#   'text': 'a',
#   'string_index': 419,
#   'bounding_box': [460, 308, 475, 325],
#   'confidence': 0.92},
#  {'word_id': 'word_1_64',
#   'text': 'basis',
#   'string_index': 421,
#   'bounding_box': [484, 303, 550, 325],
#   'confidence': 0.92},
#  {'word_id': 'word_1_65',
#   'text': 'for',
#   'string_index': 427,
#   'bounding_box': [559, 302, 592, 325],
#   'confidence': 0.92},
#  {'word_id': 'word_1_66',
#   'text': 'loan',
#   'string_index': 431,
#   'bounding_box': [601, 303, 653, 325],
#   'confidence': 0.92},
#  {'word_id': 'word_1_67',
#   'text': 'qualification',
#   'string_index': 436,
#   'bounding_box': [662, 302, 814, 330],
#   'confidence': 0.91},
#  {'word_id': 'word_1_68',
#   'text': 'or',
#   'string_index': 450,
#   'bounding_box': [823, 308, 849, 325],
#   'confidence': 0.93},
#  {'word_id': 'word_1_69',
#   'text': 'the',
#   'string_index': 453,
#   'bounding_box': [928, 303, 967, 325],
#   'confidence': 0.93},
#  {'word_id': 'word_1_70',
#   'text': 'income',
#   'string_index': 457,
#   'bounding_box': [977, 302, 1069, 325],
#   'confidence': 0.91},
#  {'word_id': 'word_1_71',
#   'text': 'or',
#   'string_index': 464,
#   'bounding_box': [1078, 308, 1103, 325],
#   'confidence': 0.91},
#  {'word_id': 'word_1_72',
#   'text': 'assets',
#   'string_index': 467,
#   'bounding_box': [1111, 304, 1194, 325],
#   'confidence': 0.91},
#  {'word_id': 'word_1_73',
#   'text': 'of',
#   'string_index': 474,
#   'bounding_box': [1202, 302, 1226, 325],
#   'confidence': 0.92},
#  {'word_id': 'word_1_74',
#   'text': 'the',
#   'string_index': 477,
#   'bounding_box': [1234, 303, 1273, 325],
#   'confidence': 0.92},
#  {'word_id': 'word_1_75',
#   'text': 'Borrower’s',
#   'string_index': 481,
#   'bounding_box': [1283, 302, 1418, 325],
#   'confidence': 0.79},
#  {'word_id': 'word_1_76',
#   'text': 'spouse',
#   'string_index': 492,
#   'bounding_box': [1427, 308, 1519, 330],
#   'confidence': 0.92},
#  {'word_id': 'word_1_77',
#   'text': 'or',
#   'string_index': 499,
#   'bounding_box': [1528, 308, 1553, 324],
#   'confidence': 0.93},
#  {'word_id': 'word_1_78',
#   'text': 'other',
#   'string_index': 502,
#   'bounding_box': [1561, 303, 1627, 325],
#   'confidence': 0.91},
#  {'word_id': 'word_1_79',
#   'text': 'person',
#   'string_index': 508,
#   'bounding_box': [1636, 308, 1721, 330],
#   'confidence': 0.92},
#  {'word_id': 'word_1_80',
#   'text': 'who',
#   'string_index': 515,
#   'bounding_box': [1730, 303, 1783, 325],
#   'confidence': 0.92},
#  {'word_id': 'word_1_81',
#   'text': 'has',
#   'string_index': 519,
#   'bounding_box': [1792, 303, 1837, 325],
#   'confidence': 0.91},
#  {'word_id': 'word_1_82',
#   'text': 'community',
#   'string_index': 523,
#   'bounding_box': [1846, 303, 1986, 330],
#   'confidence': 0.91},
#  {'word_id': 'word_1_83',
#   'text': 'property',
#   'string_index': 533,
#   'bounding_box': [1995, 304, 2102, 330],
#   'confidence': 0.92},
#  {'word_id': 'word_1_84',
#   'text': 'rights',
#   'string_index': 542,
#   'bounding_box': [2111, 302, 2181, 331],
#   'confidence': 0.91},
#  {'word_id': 'word_1_85',
#   'text': 'pursuant',
#   'string_index': 549,
#   'bounding_box': [2190, 304, 2301, 330],
#   'confidence': 0.92},
#  {'word_id': 'word_1_86',
#   'text': 'to',
#   'string_index': 558,
#   'bounding_box': [2309, 304, 2332, 325],
#   'confidence': 0.91},
#  {'word_id': 'word_1_87',
#   'text': 'state',
#   'string_index': 561,
#   'bounding_box': [2341, 304, 2401, 325],
#   'confidence': 0.91},
#  {'word_id': 'word_1_88',
#   'text': 'law',
#   'string_index': 567,
#   'bounding_box': [154, 334, 195, 357],
#   'confidence': 0.92},
#  {'word_id': 'word_1_89',
#   'text': 'will',
#   'string_index': 571,
#   'bounding_box': [204, 334, 242, 356],
#   'confidence': 0.92},
#  {'word_id': 'word_1_90',
#   'text': 'not',
#   'string_index': 576,
#   'bounding_box': [253, 336, 292, 357],
#   'confidence': 0.92},
#  {'word_id': 'word_1_91',
#   'text': 'be',
#   'string_index': 580,
#   'bounding_box': [302, 334, 332, 357],
#   'confidence': 0.93},
#  {'word_id': 'word_1_92',
#   'text': 'used',
#   'string_index': 583,
#   'bounding_box': [343, 334, 403, 357],
#   'confidence': 0.92},
#  {'word_id': 'word_1_93',
#   'text': 'as',
#   'string_index': 588,
#   'bounding_box': [413, 340, 442, 357],
#   'confidence': 0.92},
#  {'word_id': 'word_1_94',
#   'text': 'a',
#   'string_index': 591,
#   'bounding_box': [452, 340, 467, 357],
#   'confidence': 0.93},
#  {'word_id': 'word_1_95',
#   'text': 'basis',
#   'string_index': 593,
#   'bounding_box': [477, 334, 543, 357],
#   'confidence': 0.87},
#  {'word_id': 'word_1_96',
#   'text': 'for',
#   'string_index': 599,
#   'bounding_box': [552, 334, 585, 357],
#   'confidence': 0.92},
#  {'word_id': 'word_1_97',
#   'text': 'loan',
#   'string_index': 603,
#   'bounding_box': [594, 334, 646, 357],
#   'confidence': 0.87},
#  {'word_id': 'word_1_98',
#   'text': 'qualification,',
#   'string_index': 608,
#   'bounding_box': [657, 334, 815, 362],
#   'confidence': 0.91},
#  {'word_id': 'word_1_99',
#   'text': 'but',
#   'string_index': 623,
#   'bounding_box': [827, 334, 865, 357],
#   'confidence': 0.92},
#  {'word_id': 'word_1_100',
#   'text': 'his',
#   'string_index': 627,
#   'bounding_box': [875, 334, 910, 357],
#   'confidence': 0.92},
#  {'word_id': 'word_1_101',
#   'text': 'or',
#   'string_index': 631,
#   'bounding_box': [920, 340, 945, 357],
#   'confidence': 0.92},
#  {'word_id': 'word_1_102',
#   'text': 'her',
#   'string_index': 634,
#   'bounding_box': [955, 334, 995, 357],
#   'confidence': 0.89},
#  {'word_id': 'word_1_103',
#   'text': 'liabilities',
#   'string_index': 638,
#   'bounding_box': [1005, 334, 1113, 357],
#   'confidence': 0.89},
#  {'word_id': 'word_1_104',
#   'text': 'must',
#   'string_index': 650,
#   'bounding_box': [1123, 336, 1184, 357],
#   'confidence': 0.92},
#  {'word_id': 'word_1_105',
#   'text': 'be',
#   'string_index': 655,
#   'bounding_box': [1194, 334, 1224, 357],
#   'confidence': 0.92},
#  {'word_id': 'word_1_106',
#   'text': 'considered',
#   'string_index': 658,
#   'bounding_box': [1234, 334, 1374, 357],
#   'confidence': 0.91},
#  {'word_id': 'word_1_107',
#   'text': 'because',
#   'string_index': 669,
#   'bounding_box': [1384, 334, 1492, 357],
#   'confidence': 0.91},
#  {'word_id': 'word_1_108',
#   'text': 'the',
#   'string_index': 677,
#   'bounding_box': [1501, 334, 1541, 357],
#   'confidence': 0.9},
#  {'word_id': 'word_1_109',
#   'text': 'spouse',
#   'string_index': 681,
#   'bounding_box': [1550, 340, 1643, 362],
#   'confidence': 0.92},
#  {'word_id': 'word_1_110',
#   'text': 'or',
#   'string_index': 688,
#   'bounding_box': [1653, 340, 1678, 357],
#   'confidence': 0.92},
#  {'word_id': 'word_1_111',
#   'text': 'other',
#   'string_index': 691,
#   'bounding_box': [1687, 334, 1753, 357],
#   'confidence': 0.92},
#  {'word_id': 'word_1_112',
#   'text': 'person',
#   'string_index': 697,
#   'bounding_box': [1762, 340, 1848, 362],
#   'confidence': 0.92},
#  {'word_id': 'word_1_113',
#   'text': 'has',
#   'string_index': 704,
#   'bounding_box': [1858, 334, 1903, 357],
#   'confidence': 0.91},
#  {'word_id': 'word_1_114',
#   'text': 'community',
#   'string_index': 708,
#   'bounding_box': [1913, 334, 2053, 363],
#   'confidence': 0.92},
#  {'word_id': 'word_1_115',
#   'text': 'property',
#   'string_index': 718,
#   'bounding_box': [2063, 336, 2169, 363],
#   'confidence': 0.92},
#  {'word_id': 'word_1_116',
#   'text': 'rights',
#   'string_index': 727,
#   'bounding_box': [2179, 334, 2248, 363],
#   'confidence': 0.92},
#  {'word_id': 'word_1_117',
#   'text': 'pursuant',
#   'string_index': 734,
#   'bounding_box': [2259, 336, 2370, 362],
#   'confidence': 0.92},
#  {'word_id': 'word_1_118',
#   'text': 'to',
#   'string_index': 743,
#   'bounding_box': [2379, 336, 2401, 357],
#   'confidence': 0.92},
#  {'word_id': 'word_1_119',
#   'text': 'applicable',
#   'string_index': 746,
#   'bounding_box': [153, 367, 282, 394],
#   'confidence': 0.91},
#  {'word_id': 'word_1_120',
#   'text': 'law',
#   'string_index': 757,
#   'bounding_box': [293, 367, 334, 389],
#   'confidence': 0.92},
#  {'word_id': 'word_1_121',
#   'text': 'and',
#   'string_index': 761,
#   'bounding_box': [344, 367, 391, 389],
#   'confidence': 0.91},
#  {'word_id': 'word_1_122',
#   'text': 'Borrower',
#   'string_index': 765,
#   'bounding_box': [403, 367, 519, 389],
#   'confidence': 0.91},
#  {'word_id': 'word_1_123',
#   'text': 'resides',
#   'string_index': 774,
#   'bounding_box': [529, 367, 620, 389],
#   'confidence': 0.9},
#  {'word_id': 'word_1_124',
#   'text': 'in',
#   'string_index': 782,
#   'bounding_box': [631, 367, 651, 388],
#   'confidence': 0.92},
#  {'word_id': 'word_1_125',
#   'text': 'a',
#   'string_index': 785,
#   'bounding_box': [662, 372, 677, 389],
#   'confidence': 0.9},
#  {'word_id': 'word_1_126',
#   'text': 'community',
#   'string_index': 787,
#   'bounding_box': [687, 367, 827, 394],
#   'confidence': 0.9},
#  {'word_id': 'word_1_127',
#   'text': 'property',
#   'string_index': 797,
#   'bounding_box': [838, 368, 944, 394],
#   'confidence': 0.91},
#  {'word_id': 'word_1_128',
#   'text': 'state,',
#   'string_index': 806,
#   'bounding_box': [954, 368, 1021, 392],
#   'confidence': 0.91},
#  {'word_id': 'word_1_129',
#   'text': 'the',
#   'string_index': 813,
#   'bounding_box': [1032, 367, 1072, 389],
#   'confidence': 0.93},
#  {'word_id': 'word_1_130',
#   'text': 'security',
#   'string_index': 817,
#   'bounding_box': [1082, 367, 1183, 394],
#   'confidence': 0.92},
#  {'word_id': 'word_1_131',
#   'text': 'property',
#   'string_index': 826,
#   'bounding_box': [1193, 368, 1300, 394],
#   'confidence': 0.92},
#  {'word_id': 'word_1_132',
#   'text': 'is',
#   'string_index': 835,
#   'bounding_box': [1310, 367, 1329, 389],
#   'confidence': 0.92},
#  {'word_id': 'word_1_133',
#   'text': 'located',
#   'string_index': 838,
#   'bounding_box': [1340, 367, 1431, 389],
#   'confidence': 0.91},
#  {'word_id': 'word_1_134',
#   'text': 'in',
#   'string_index': 846,
#   'bounding_box': [1443, 367, 1462, 388],
#   'confidence': 0.92},
#  {'word_id': 'word_1_135',
#   'text': 'a',
#   'string_index': 849,
#   'bounding_box': [1474, 372, 1489, 389],
#   'confidence': 0.92},
#  {'word_id': 'word_1_136',
#   'text': 'community',
#   'string_index': 851,
#   'bounding_box': [1498, 367, 1639, 394],
#   'confidence': 0.91},
#  {'word_id': 'word_1_137',
#   'text': 'property',
#   'string_index': 861,
#   'bounding_box': [1649, 368, 1756, 394],
#   'confidence': 0.92},
#  {'word_id': 'word_1_138',
#   'text': 'state,',
#   'string_index': 870,
#   'bounding_box': [1766, 368, 1833, 392],
#   'confidence': 0.91},
#  {'word_id': 'word_1_139',
#   'text': 'or',
#   'string_index': 877,
#   'bounding_box': [1845, 372, 1870, 388],
#   'confidence': 0.92},
#  {'word_id': 'word_1_140',
#   'text': 'the',
#   'string_index': 880,
#   'bounding_box': [1879, 367, 1918, 389],
#   'confidence': 0.92},
#  {'word_id': 'word_1_141',
#   'text': 'Borrower',
#   'string_index': 884,
#   'bounding_box': [1930, 367, 2045, 389],
#   'confidence': 0.92},
#  {'word_id': 'word_1_142',
#   'text': 'is',
#   'string_index': 893,
#   'bounding_box': [2056, 367, 2074, 389],
#   'confidence': 0.92},
#  {'word_id': 'word_1_143',
#   'text': 'relying',
#   'string_index': 896,
#   'bounding_box': [2086, 367, 2167, 395],
#   'confidence': 0.92},
#  {'word_id': 'word_1_144',
#   'text': 'on',
#   'string_index': 904,
#   'bounding_box': [2178, 372, 2209, 389],
#   'confidence': 0.92},
#  {'word_id': 'word_1_145',
#   'text': 'other',
#   'string_index': 907,
#   'bounding_box': [2219, 367, 2286, 389],
#   'confidence': 0.92},
#  {'word_id': 'word_1_146',
#   'text': 'property',
#   'string_index': 913,
#   'bounding_box': [2296, 368, 2402, 394],
#   'confidence': 0.92},
#  {'word_id': 'word_1_151',
#   'text': 'located',
#   'string_index': 938,
#   'bounding_box': [154, 399, 244, 421],
#   'confidence': 0.92},
#  {'word_id': 'word_1_152',
#   'text': 'in',
#   'string_index': 946,
#   'bounding_box': [255, 399, 275, 420],
#   'confidence': 0.91},
#  {'word_id': 'word_1_153',
#   'text': 'a',
#   'string_index': 949,
#   'bounding_box': [285, 404, 300, 421],
#   'confidence': 0.91},
#  {'word_id': 'word_1_154',
#   'text': 'community',
#   'string_index': 951,
#   'bounding_box': [310, 399, 450, 427],
#   'confidence': 0.91},
#  {'word_id': 'word_1_155',
#   'text': 'property',
#   'string_index': 961,
#   'bounding_box': [460, 400, 566, 427],
#   'confidence': 0.92},
#  {'word_id': 'word_1_156',
#   'text': 'state',
#   'string_index': 970,
#   'bounding_box': [575, 400, 636, 421],
#   'confidence': 0.93},
#  {'word_id': 'word_1_157',
#   'text': 'as',
#   'string_index': 976,
#   'bounding_box': [646, 404, 675, 421],
#   'confidence': 0.93},
#  {'word_id': 'word_1_158',
#   'text': 'a',
#   'string_index': 979,
#   'bounding_box': [685, 404, 699, 421],
#   'confidence': 0.93},
#  {'word_id': 'word_1_159',
#   'text': 'basis',
#   'string_index': 981,
#   'bounding_box': [709, 399, 775, 421],
#   'confidence': 0.92},
#  {'word_id': 'word_1_160',
#   'text': 'for',
#   'string_index': 987,
#   'bounding_box': [785, 398, 818, 421],
#   'confidence': 0.93},
#  {'word_id': 'word_1_161',
#   'text': 'repayment',
#   'string_index': 991,
#   'bounding_box': [827, 400, 962, 427],
#   'confidence': 0.91},
#  {'word_id': 'word_1_162',
#   'text': 'of',
#   'string_index': 1001,
#   'bounding_box': [971, 399, 994, 421],
#   'confidence': 0.92},
#  {'word_id': 'word_1_163',
#   'text': 'the',
#   'string_index': 1004,
#   'bounding_box': [1003, 399, 1042, 421],
#   'confidence': 0.92},
#  {'word_id': 'word_1_164',
#   'text': 'loan.',
#   'string_index': 1008,
#   'bounding_box': [1053, 399, 1112, 421],
#   'confidence': 0.91},
#  {'word_id': 'word_1_165',
#   'text': 'If',
#   'string_index': 1014,
#   'bounding_box': [154, 443, 168, 465],
#   'confidence': 0.91},
#  {'word_id': 'word_1_166',
#   'text': 'this',
#   'string_index': 1017,
#   'bounding_box': [177, 443, 221, 466],
#   'confidence': 0.84},
#  {'word_id': 'word_1_167',
#   'text': 'is',
#   'string_index': 1022,
#   'bounding_box': [232, 444, 250, 465],
#   'confidence': 0.89},
#  {'word_id': 'word_1_168',
#   'text': 'an',
#   'string_index': 1025,
#   'bounding_box': [260, 449, 290, 471],
#   'confidence': 0.89},
#  {'word_id': 'word_1_169',
#   'text': 'application',
#   'string_index': 1028,
#   'bounding_box': [301, 443, 438, 471],
#   'confidence': 0.92},
#  {'word_id': 'word_1_170',
#   'text': 'for',
#   'string_index': 1040,
#   'bounding_box': [447, 443, 481, 465],
#   'confidence': 0.93},
#  {'word_id': 'word_1_171',
#   'text': 'joint',
#   'string_index': 1044,
#   'bounding_box': [488, 443, 542, 471],
#   'confidence': 0.89},
#  {'word_id': 'word_1_172',
#   'text': 'credit,',
#   'string_index': 1050,
#   'bounding_box': [551, 443, 627, 469],
#   'confidence': 0.92},
#  {'word_id': 'word_1_174',
#   'text': 'and',
#   'string_index': 1067,
#   'bounding_box': [763, 443, 810, 465],
#   'confidence': 0.91},
#  {'word_id': 'word_1_177',
#   'text': 'agree',
#   'string_index': 1088,
#   'bounding_box': [1063, 449, 1135, 471],
#   'confidence': 0.92},
#  {'word_id': 'word_1_178',
#   'text': 'that',
#   'string_index': 1094,
#   'bounding_box': [1144, 444, 1192, 465],
#   'confidence': 0.92},
#  {'word_id': 'word_1_179',
#   'text': 'we',
#   'string_index': 1099,
#   'bounding_box': [1201, 449, 1236, 465],
#   'confidence': 0.93},
#  {'word_id': 'word_1_180',
#   'text': 'intend',
#   'string_index': 1102,
#   'bounding_box': [1247, 443, 1323, 465],
#   'confidence': 0.92},
#  {'word_id': 'word_1_181',
#   'text': 'to',
#   'string_index': 1109,
#   'bounding_box': [1333, 445, 1356, 465],
#   'confidence': 0.93},
#  {'word_id': 'word_1_182',
#   'text': 'apg_ly',
#   'string_index': 1112,
#   'bounding_box': [1365, 443, 1433, 482],
#   'confidence': 0.64},
#  {'word_id': 'word_1_183',
#   'text': 'for',
#   'string_index': 1119,
#   'bounding_box': [1442, 443, 1475, 465],
#   'confidence': 0.92},
#  {'word_id': 'word_1_184',
#   'text': 'joint',
#   'string_index': 1123,
#   'bounding_box': [1482, 444, 1536, 471],
#   'confidence': 0.92},
#  {'word_id': 'word_1_185',
#   'text': 'credit',
#   'string_index': 1129,
#   'bounding_box': [1545, 443, 1615, 466],
#   'confidence': 0.93},
#  {'word_id': 'word_1_186',
#   'text': 'sign',
#   'string_index': 1136,
#   'bounding_box': [1625, 443, 1685, 471],
#   'confidence': 0.92},
#  {'word_id': 'word_1_187',
#   'text': 'below:',
#   'string_index': 1141,
#   'bounding_box': [1696, 443, 1786, 471],
#   'confidence': 0.9},
#  {'word_id': 'word_1_188',
#   'text': 'DocuSigned',
#   'string_index': 1148,
#   'bounding_box': [203, 469, 307, 486],
#   'confidence': 0.87},
#  {'word_id': 'word_1_189',
#   'text': 'by:',
#   'string_index': 1159,
#   'bounding_box': [313, 469, 337, 486],
#   'confidence': 0.9},
#  {'word_id': 'word_1_190',
#   'text': 'DocuSigned',
#   'string_index': 1163,
#   'bounding_box': [1354, 469, 1457, 486],
#   'confidence': 0.88},
#  {'word_id': 'word_1_191',
#   'text': 'by',
#   'string_index': 1174,
#   'bounding_box': [1463, 469, 1488, 486],
#   'confidence': 0.0},
#  {'word_id': 'word_1_195',
#   'text': "—thu'tl",
#   'string_index': 1177,
#   'bounding_box': [151, 473, 283, 551],
#   'confidence': 0.46},
#  {'word_id': 'word_1_199',
#   'text': '|',
#   'string_index': 1206,
#   'bounding_box': [1048, 517, 1052, 546],
#   'confidence': 0.66},
#  {'word_id': 'word_1_202',
#   'text': '|',
#   'string_index': 1221,
#   'bounding_box': [1275, 487, 1320, 554],
#   'confidence': 0.75},
#  {'word_id': 'word_1_203',
#   'text': '\\VAddoria',
#   'string_index': 1223,
#   'bounding_box': [1332, 494, 1442, 533],
#   'confidence': 0.0},
#  {'word_id': 'word_1_207',
#   'text': '|',
#   'string_index': 1260,
#   'bounding_box': [2198, 517, 2203, 546],
#   'confidence': 0.93},
#  {'word_id': 'word_1_210',
#   'text': 'Borfgeperes7c4400',
#   'string_index': 1275,
#   'bounding_box': [141, 549, 370, 595],
#   'confidence': 0.0},
#  {'word_id': 'word_1_211',
#   'text': 'Co-BbFewER:',
#   'string_index': 1293,
#   'bounding_box': [1303, 553, 1507, 582],
#   'confidence': 0.0},
#  {'word_id': 'word_1_212',
#   'text': '|',
#   'string_index': 1305,
#   'bounding_box': [151, 590, 154, 637],
#   'confidence': 0.88},
#  {'word_id': 'word_1_213',
#   'text': 'I.',
#   'string_index': 1307,
#   'bounding_box': [916, 601, 931, 626],
#   'confidence': 0.49},
#  {'word_id': 'word_1_214',
#   'text': 'TYPE',
#   'string_index': 1310,
#   'bounding_box': [944, 592, 1023, 640],
#   'confidence': 0.49},
#  {'word_id': 'word_1_215',
#   'text': 'OF',
#   'string_index': 1315,
#   'bounding_box': [1034, 601, 1079, 627],
#   'confidence': 0.92},
#  {'word_id': 'word_1_216',
#   'text': 'MORTGAGE',
#   'string_index': 1318,
#   'bounding_box': [1091, 601, 1281, 627],
#   'confidence': 0.91},
#  {'word_id': 'word_1_217',
#   'text': 'AND',
#   'string_index': 1327,
#   'bounding_box': [1291, 601, 1361, 626],
#   'confidence': 0.91},
#  {'word_id': 'word_1_218',
#   'text': 'TERMS',
#   'string_index': 1331,
#   'bounding_box': [1368, 601, 1484, 627],
#   'confidence': 0.92},
#  {'word_id': 'word_1_219',
#   'text': 'OF',
#   'string_index': 1337,
#   'bounding_box': [1495, 601, 1540, 627],
#   'confidence': 0.92},
#  {'word_id': 'word_1_220',
#   'text': 'LOAN',
#   'string_index': 1340,
#   'bounding_box': [1551, 601, 1639, 627],
#   'confidence': 0.92},
#  {'word_id': 'word_1_221',
#   'text': 'Mortgage',
#   'string_index': 1345,
#   'bounding_box': [154, 653, 302, 685],
#   'confidence': 0.9},
#  {'word_id': 'word_1_222',
#   'text': '[_JVA',
#   'string_index': 1354,
#   'bounding_box': [352, 644, 452, 680],
#   'confidence': 0.11},
#  {'word_id': 'word_1_223',
#   'text': '[¥]Conventional',
#   'string_index': 1360,
#   'bounding_box': [506, 644, 755, 680],
#   'confidence': 0.75},
#  {'word_id': 'word_1_224',
#   'text': '[]Other',
#   'string_index': 1376,
#   'bounding_box': [789, 644, 932, 680],
#   'confidence': 0.43},
#  {'word_id': 'word_1_225',
#   'text': 'explain:',
#   'string_index': 1384,
#   'bounding_box': [943, 652, 1074, 685],
#   'confidence': 0.92},
#  {'word_id': 'word_1_226',
#   'text': 'Agency',
#   'string_index': 1393,
#   'bounding_box': [1240, 651, 1350, 683],
#   'confidence': 0.91},
#  {'word_id': 'word_1_227',
#   'text': 'Case',
#   'string_index': 1400,
#   'bounding_box': [1360, 650, 1435, 676],
#   'confidence': 0.93},
#  {'word_id': 'word_1_228',
#   'text': 'Number',
#   'string_index': 1405,
#   'bounding_box': [1447, 651, 1564, 676],
#   'confidence': 0.91},
#  {'word_id': 'word_1_229',
#   'text': 'Lender',
#   'string_index': 1412,
#   'bounding_box': [1842, 651, 1944, 676],
#   'confidence': 0.89},
#  {'word_id': 'word_1_230',
#   'text': 'Case',
#   'string_index': 1419,
#   'bounding_box': [1954, 650, 2029, 676],
#   'confidence': 0.9},
#  {'word_id': 'word_1_231',
#   'text': 'Number',
#   'string_index': 1424,
#   'bounding_box': [2041, 651, 2158, 676],
#   'confidence': 0.92},
#  {'word_id': 'word_1_232',
#   'text': 'Applied',
#   'string_index': 1431,
#   'bounding_box': [153, 694, 273, 726],
#   'confidence': 0.91},
#  {'word_id': 'word_1_233',
#   'text': 'for:',
#   'string_index': 1439,
#   'bounding_box': [283, 694, 336, 720],
#   'confidence': 0.88},
#  {'word_id': 'word_1_234',
#   'text': '[_JFHA',
#   'string_index': 1444,
#   'bounding_box': [352, 686, 477, 721],
#   'confidence': 0.0},
#  {'word_id': 'word_1_235',
#   'text': '[]USDA/Rural',
#   'string_index': 1451,
#   'bounding_box': [506, 686, 742, 721],
#   'confidence': 0.35},
#  {'word_id': 'word_1_236',
#   'text': 'Housing',
#   'string_index': 1464,
#   'bounding_box': [755, 695, 874, 727],
#   'confidence': 0.93},
#  {'word_id': 'word_1_237',
#   'text': 'Service',
#   'string_index': 1472,
#   'bounding_box': [887, 694, 996, 720],
#   'confidence': 0.92},
#  {'word_id': 'word_1_250',
#   'text': 'Amount',
#   'string_index': 1488,
#   'bounding_box': [153, 738, 267, 786],
#   'confidence': 0.91},
#  {'word_id': 'word_1_251',
#   'text': 'Interest',
#   'string_index': 1495,
#   'bounding_box': [592, 751, 699, 776],
#   'confidence': 0.91},
#  {'word_id': 'word_1_252',
#   'text': 'Rate',
#   'string_index': 1504,
#   'bounding_box': [711, 751, 777, 776],
#   'confidence': 0.92},
#  {'word_id': 'word_1_253',
#   'text': 'No.',
#   'string_index': 1509,
#   'bounding_box': [867, 751, 913, 776],
#   'confidence': 0.91},
#  {'word_id': 'word_1_254',
#   'text': 'of',
#   'string_index': 1513,
#   'bounding_box': [923, 751, 950, 776],
#   'confidence': 0.91},
#  {'word_id': 'word_1_255',
#   'text': 'Months',
#   'string_index': 1516,
#   'bounding_box': [961, 751, 1068, 776],
#   'confidence': 0.92},
#  {'word_id': 'word_1_256',
#   'text': '|',
#   'string_index': 1523,
#   'bounding_box': [1083, 741, 1117, 790],
#   'confidence': 0.72},
#  {'word_id': 'word_1_257',
#   'text': 'Amortization',
#   'string_index': 1525,
#   'bounding_box': [1115, 752, 1317, 778],
#   'confidence': 0.91},
#  {'word_id': 'word_1_258',
#   'text': '[X]',
#   'string_index': 1538,
#   'bounding_box': [1339, 745, 1390, 780],
#   'confidence': 0.47},
#  {'word_id': 'word_1_259',
#   'text': 'Fixed',
#   'string_index': 1542,
#   'bounding_box': [1400, 753, 1476, 778],
#   'confidence': 0.47},
#  {'word_id': 'word_1_260',
#   'text': 'Rate',
#   'string_index': 1548,
#   'bounding_box': [1489, 753, 1555, 778],
#   'confidence': 0.91},
#  {'word_id': 'word_1_261',
#   'text': '[',
#   'string_index': 1553,
#   'bounding_box': [1577, 741, 1611, 790],
#   'confidence': 0.0},
#  {'word_id': 'word_1_262',
#   'text': ']',
#   'string_index': 1555,
#   'bounding_box': [1622, 745, 1644, 780],
#   'confidence': 0.0},
#  {'word_id': 'word_1_263',
#   'text': 'Other',
#   'string_index': 1557,
#   'bounding_box': [1653, 752, 1736, 778],
#   'confidence': 0.62},
#  {'word_id': 'word_1_264',
#   'text': 'explain:',
#   'string_index': 1563,
#   'bounding_box': [1747, 752, 1878, 784],
#   'confidence': 0.92},
#  {'word_id': 'word_1_269',
#   'text': '|',
#   'string_index': 1592,
#   'bounding_box': [832, 778, 858, 829],
#   'confidence': 0.87},
#  {'word_id': 'word_1_271',
#   'text': 'Type:',
#   'string_index': 1598,
#   'bounding_box': [1115, 780, 1199, 831],
#   'confidence': 0.92},
#  {'word_id': 'word_1_272',
#   'text': 'CaPm',
#   'string_index': 1604,
#   'bounding_box': [1339, 786, 1472, 822],
#   'confidence': 0.13},
#  {'word_id': 'word_1_273',
#   'text': 'CJARM',
#   'string_index': 1609,
#   'bounding_box': [1594, 786, 1724, 822],
#   'confidence': 0.56},
#  {'word_id': 'word_1_274',
#   'text': 'type:',
#   'string_index': 1615,
#   'bounding_box': [1738, 794, 1828, 826],
#   'confidence': 0.88},
#  {'word_id': 'word_1_275',
#   'text': 'I',
#   'string_index': 1621,
#   'bounding_box': [151, 832, 154, 880],
#   'confidence': 0.78},
#  {'word_id': 'word_1_276',
#   'text': 'Il.',
#   'string_index': 1623,
#   'bounding_box': [845, 844, 870, 869],
#   'confidence': 0.45},
#  {'word_id': 'word_1_277',
#   'text': 'PROPERTY',
#   'string_index': 1627,
#   'bounding_box': [881, 844, 1061, 870],
#   'confidence': 0.92},
#  {'word_id': 'word_1_278',
#   'text': 'INFORMATION',
#   'string_index': 1636,
#   'bounding_box': [1072, 844, 1301, 870],
#   'confidence': 0.89},
#  {'word_id': 'word_1_279',
#   'text': 'AND',
#   'string_index': 1648,
#   'bounding_box': [1311, 844, 1382, 869],
#   'confidence': 0.92},
#  {'word_id': 'word_1_280',
#   'text': 'PURPOSE',
#   'string_index': 1652,
#   'bounding_box': [1394, 844, 1554, 870],
#   'confidence': 0.93},
#  {'word_id': 'word_1_281',
#   'text': 'OF',
#   'string_index': 1660,
#   'bounding_box': [1565, 844, 1610, 870],
#   'confidence': 0.92},
#  {'word_id': 'word_1_282',
#   'text': 'LOAN',
#   'string_index': 1663,
#   'bounding_box': [1622, 844, 1709, 870],
#   'confidence': 0.91},
#  {'word_id': 'word_1_283',
#   'text': 'Subject',
#   'string_index': 1668,
#   'bounding_box': [154, 893, 263, 925],
#   'confidence': 0.87},
#  {'word_id': 'word_1_284',
#   'text': 'Property',
#   'string_index': 1676,
#   'bounding_box': [275, 893, 397, 925],
#   'confidence': 0.91},
#  {'word_id': 'word_1_285',
#   'text': 'Address',
#   'string_index': 1685,
#   'bounding_box': [406, 893, 526, 919],
#   'confidence': 0.91},
#  {'word_id': 'word_1_286',
#   'text': 'street,',
#   'string_index': 1693,
#   'bounding_box': [538, 893, 637, 925],
#   'confidence': 0.92},
#  {'word_id': 'word_1_287',
#   'text': 'city,',
#   'string_index': 1701,
#   'bounding_box': [649, 893, 702, 925],
#   'confidence': 0.92},
#  {'word_id': 'word_1_288',
#   'text': 'state,',
#   'string_index': 1707,
#   'bounding_box': [715, 895, 792, 922],
#   'confidence': 0.92},
#  {'word_id': 'word_1_289',
#   'text': '&',
#   'string_index': 1714,
#   'bounding_box': [805, 894, 824, 919],
#   'confidence': 0.93},
#  {'word_id': 'word_1_290',
#   'text': 'ZIP',
#   'string_index': 1716,
#   'bounding_box': [835, 893, 896, 925],
#   'confidence': 0.92},
#  {'word_id': 'word_1_291',
#   'text': 'No.',
#   'string_index': 1720,
#   'bounding_box': [2192, 893, 2238, 919],
#   'confidence': 0.92},
#  {'word_id': 'word_1_292',
#   'text': 'of',
#   'string_index': 1724,
#   'bounding_box': [2248, 893, 2275, 919],
#   'confidence': 0.92},
#  {'word_id': 'word_1_293',
#   'text': 'Units',
#   'string_index': 1727,
#   'bounding_box': [2287, 893, 2359, 919],
#   'confidence': 0.92},
#  {'word_id': 'word_1_295',
#   'text': 'Laptop',
#   'string_index': 1736,
#   'bounding_box': [196, 931, 304, 963],
#   'confidence': 0.9},
#  {'word_id': 'word_1_296',
#   'text': 'Loop,',
#   'string_index': 1743,
#   'bounding_box': [316, 931, 403, 963],
#   'confidence': 0.91},
#  {'word_id': 'word_1_301',
#   'text': 'Carbon',
#   'string_index': 1775,
#   'bounding_box': [860, 931, 974, 957],
#   'confidence': 0.92},
#  {'word_id': 'word_1_302',
#   'text': '1',
#   'string_index': 1782,
#   'bounding_box': [2199, 931, 2210, 956],
#   'confidence': 0.96},
#  {'word_id': 'word_1_303',
#   'text': 'Legal',
#   'string_index': 1784,
#   'bounding_box': [154, 985, 231, 1017],
#   'confidence': 0.92},
#  {'word_id': 'word_1_304',
#   'text': 'Description',
#   'string_index': 1790,
#   'bounding_box': [244, 985, 408, 1017],
#   'confidence': 0.91},
#  {'word_id': 'word_1_305',
#   'text': 'of',
#   'string_index': 1802,
#   'bounding_box': [420, 985, 446, 1010],
#   'confidence': 0.92},
#  {'word_id': 'word_1_306',
#   'text': 'Subject',
#   'string_index': 1805,
#   'bounding_box': [457, 985, 567, 1017],
#   'confidence': 0.91},
#  {'word_id': 'word_1_307',
#   'text': 'Property',
#   'string_index': 1813,
#   'bounding_box': [579, 985, 701, 1017],
#   'confidence': 0.92},
#  {'word_id': 'word_1_308',
#   'text': 'attach',
#   'string_index': 1822,
#   'bounding_box': [713, 985, 810, 1017],
#   'confidence': 0.9},
#  {'word_id': 'word_1_309',
#   'text': 'description',
#   'string_index': 1829,
#   'bounding_box': [821, 985, 980, 1017],
#   'confidence': 0.91},
#  {'word_id': 'word_1_310',
#   'text': 'if',
#   'string_index': 1841,
#   'bounding_box': [993, 985, 1008, 1010],
#   'confidence': 0.92},
#  {'word_id': 'word_1_311',
#   'text': 'necessary',
#   'string_index': 1844,
#   'bounding_box': [1019, 985, 1180, 1017],
#   'confidence': 0.92},
#  {'word_id': 'word_1_312',
#   'text': 'Year',
#   'string_index': 1854,
#   'bounding_box': [2190, 985, 2256, 1011],
#   'confidence': 0.92},
#  {'word_id': 'word_1_313',
#   'text': 'Built',
#   'string_index': 1859,
#   'bounding_box': [2267, 985, 2329, 1010],
#   'confidence': 0.91},
#  {'word_id': 'word_1_315',
#   'text': 'Purpose',
#   'string_index': 1870,
#   'bounding_box': [154, 1150, 275, 1182],
#   'confidence': 0.91},
#  {'word_id': 'word_1_316',
#   'text': 'of',
#   'string_index': 1878,
#   'bounding_box': [286, 1150, 313, 1175],
#   'confidence': 0.9},
#  {'word_id': 'word_1_317',
#   'text': 'Loan',
#   'string_index': 1881,
#   'bounding_box': [325, 1150, 394, 1175],
#   'confidence': 0.92},
#  {'word_id': 'word_1_318',
#   'text': '[X]',
#   'string_index': 1886,
#   'bounding_box': [418, 1141, 469, 1177],
#   'confidence': 0.78},
#  {'word_id': 'word_1_319',
#   'text': 'Purchase',
#   'string_index': 1890,
#   'bounding_box': [484, 1150, 619, 1175],
#   'confidence': 0.87},
#  {'word_id': 'word_1_320',
#   'text': ']',
#   'string_index': 1899,
#   'bounding_box': [668, 1141, 719, 1177],
#   'confidence': 0.0},
#  {'word_id': 'word_1_321',
#   'text': 'Construction',
#   'string_index': 1901,
#   'bounding_box': [733, 1149, 916, 1175],
#   'confidence': 0.89},
#  {'word_id': 'word_1_322',
#   'text': '[',
#   'string_index': 1914,
#   'bounding_box': [1027, 1141, 1078, 1177],
#   'confidence': 0.22},
#  {'word_id': 'word_1_323',
#   'text': 'other',
#   'string_index': 1916,
#   'bounding_box': [1091, 1149, 1173, 1175],
#   'confidence': 0.91},
#  {'word_id': 'word_1_324',
#   'text': 'explain:',
#   'string_index': 1922,
#   'bounding_box': [1184, 1146, 1316, 1186],
#   'confidence': 0.92},
#  {'word_id': 'word_1_325',
#   'text': 'Property',
#   'string_index': 1931,
#   'bounding_box': [1567, 1148, 1690, 1180],
#   'confidence': 0.92},
#  {'word_id': 'word_1_326',
#   'text': 'will',
#   'string_index': 1940,
#   'bounding_box': [1700, 1148, 1744, 1173],
#   'confidence': 0.92},
#  {'word_id': 'word_1_327',
#   'text': 'be:',
#   'string_index': 1945,
#   'bounding_box': [1756, 1148, 1799, 1173],
#   'confidence': 0.92},
#  {'word_id': 'word_1_328',
#   'text': '[1',
#   'string_index': 1949,
#   'bounding_box': [418, 1183, 469, 1218],
#   'confidence': 0.15},
#  {'word_id': 'word_1_329',
#   'text': 'Refinance',
#   'string_index': 1952,
#   'bounding_box': [484, 1191, 629, 1217],
#   'confidence': 0.64},
#  {'word_id': 'word_1_330',
#   'text': '[]',
#   'string_index': 1962,
#   'bounding_box': [668, 1183, 719, 1218],
#   'confidence': 0.38},
#  {'word_id': 'word_1_331',
#   'text': 'Construction-Permanent',
#   'string_index': 1965,
#   'bounding_box': [733, 1191, 1091, 1217],
#   'confidence': 0.92},
#  {'word_id': 'word_1_332',
#   'text': 'Primary',
#   'string_index': 1988,
#   'bounding_box': [1630, 1189, 1741, 1221],
#   'confidence': 0.44},
#  {'word_id': 'word_1_333',
#   'text': '[]',
#   'string_index': 1996,
#   'bounding_box': [1814, 1181, 1865, 1216],
#   'confidence': 0.44},
#  {'word_id': 'word_1_334',
#   'text': 'Secondary',
#   'string_index': 1999,
#   'bounding_box': [1879, 1189, 2037, 1221],
#   'confidence': 0.87},
#  {'word_id': 'word_1_335',
#   'text': '[]',
#   'string_index': 2009,
#   'bounding_box': [2081, 1181, 2132, 1216],
#   'confidence': 0.57},
#  {'word_id': 'word_1_336',
#   'text': 'Investment',
#   'string_index': 2012,
#   'bounding_box': [2146, 1189, 2305, 1215],
#   'confidence': 0.89},
#  {'word_id': 'word_1_337',
#   'text': 'Residence',
#   'string_index': 2023,
#   'bounding_box': [1630, 1219, 1783, 1259],
#   'confidence': 0.92},
#  {'word_id': 'word_1_338',
#   'text': 'Residence',
#   'string_index': 2033,
#   'bounding_box': [1880, 1223, 2033, 1248],
#   'confidence': 0.92},
#  {'word_id': 'word_1_341',
#   'text': 'Complete',
#   'string_index': 2043,
#   'bounding_box': [154, 1270, 303, 1302],
#   'confidence': 0.9},
#  {'word_id': 'word_1_342',
#   'text': 'this',
#   'string_index': 2052,
#   'bounding_box': [314, 1270, 370, 1295],
#   'confidence': 0.93},
#  {'word_id': 'word_1_343',
#   'text': 'line',
#   'string_index': 2057,
#   'bounding_box': [380, 1270, 436, 1295],
#   'confidence': 0.91},
#  {'word_id': 'word_1_344',
#   'text': 'if',
#   'string_index': 2062,
#   'bounding_box': [446, 1270, 468, 1295],
#   'confidence': 0.9},
#  {'word_id': 'word_1_345',
#   'text': 'construction',
#   'string_index': 2065,
#   'bounding_box': [476, 1270, 673, 1295],
#   'confidence': 0.92},
#  {'word_id': 'word_1_346',
#   'text': 'or',
#   'string_index': 2078,
#   'bounding_box': [685, 1276, 718, 1295],
#   'confidence': 0.93},
#  {'word_id': 'word_1_347',
#   'text': 'construction-permanent',
#   'string_index': 2081,
#   'bounding_box': [727, 1270, 1106, 1302],
#   'confidence': 0.91},
#  {'word_id': 'word_1_348',
#   'text': 'loan.',
#   'string_index': 2104,
#   'bounding_box': [1116, 1270, 1191, 1295],
#   'confidence': 0.9},
#  {'word_id': 'word_1_350',
#   'text': 'Year',
#   'string_index': 2110,
#   'bounding_box': [153, 1310, 218, 1335],
#   'confidence': 0.92},
#  {'word_id': 'word_1_351',
#   'text': 'Lot',
#   'string_index': 2115,
#   'bounding_box': [229, 1310, 273, 1335],
#   'confidence': 0.93},
#  {'word_id': 'word_1_352',
#   'text': 'Acquired',
#   'string_index': 2119,
#   'bounding_box': [281, 1310, 410, 1342],
#   'confidence': 0.92},
#  {'word_id': 'word_1_353',
#   'text': '|',
#   'string_index': 2128,
#   'bounding_box': [432, 1306, 460, 1347],
#   'confidence': 0.84},
#  {'word_id': 'word_1_354',
#   'text': 'Original',
#   'string_index': 2130,
#   'bounding_box': [466, 1310, 578, 1342],
#   'confidence': 0.91},
#  {'word_id': 'word_1_355',
#   'text': 'Cost',
#   'string_index': 2139,
#   'bounding_box': [590, 1310, 657, 1336],
#   'confidence': 0.92},
#  {'word_id': 'word_1_356',
#   'text': 'Amount',
#   'string_index': 2144,
#   'bounding_box': [840, 1310, 954, 1335],
#   'confidence': 0.91},
#  {'word_id': 'word_1_357',
#   'text': 'Existing',
#   'string_index': 2151,
#   'bounding_box': [966, 1310, 1079, 1342],
#   'confidence': 0.92},
#  {'word_id': 'word_1_358',
#   'text': 'Liens',
#   'string_index': 2160,
#   'bounding_box': [1092, 1310, 1168, 1335],
#   'confidence': 0.91},
#  {'word_id': 'word_1_359',
#   'text': '|',
#   'string_index': 2166,
#   'bounding_box': [1181, 1306, 1209, 1347],
#   'confidence': 0.79},
#  {'word_id': 'word_1_360',
#   'text': 'a',
#   'string_index': 2168,
#   'bounding_box': [1217, 1310, 1254, 1342],
#   'confidence': 0.79},
#  {'word_id': 'word_1_361',
#   'text': 'Present',
#   'string_index': 2170,
#   'bounding_box': [1267, 1310, 1377, 1335],
#   'confidence': 0.92},
#  {'word_id': 'word_1_362',
#   'text': 'Value',
#   'string_index': 2178,
#   'bounding_box': [1385, 1310, 1466, 1335],
#   'confidence': 0.87},
#  {'word_id': 'word_1_363',
#   'text': 'of',
#   'string_index': 2184,
#   'bounding_box': [1478, 1310, 1504, 1335],
#   'confidence': 0.92},
#  {'word_id': 'word_1_364',
#   'text': 'Lot',
#   'string_index': 2187,
#   'bounding_box': [1516, 1310, 1560, 1335],
#   'confidence': 0.95},
#  {'word_id': 'word_1_365',
#   'text': '|',
#   'string_index': 2191,
#   'bounding_box': [1584, 1306, 1612, 1347],
#   'confidence': 0.88},
#  {'word_id': 'word_1_366',
#   'text': 'b',
#   'string_index': 2193,
#   'bounding_box': [1617, 1310, 1654, 1342],
#   'confidence': 0.92},
#  {'word_id': 'word_1_367',
#   'text': 'Cost',
#   'string_index': 2195,
#   'bounding_box': [1666, 1310, 1732, 1336],
#   'confidence': 0.92},
#  {'word_id': 'word_1_368',
#   'text': 'of',
#   'string_index': 2200,
#   'bounding_box': [1743, 1310, 1770, 1335],
#   'confidence': 0.93},
#  {'word_id': 'word_1_369',
#   'text': 'Improvements',
#   'string_index': 2203,
#   'bounding_box': [1782, 1310, 1987, 1342],
#   'confidence': 0.9},
#  {'word_id': 'word_1_370',
#   'text': '|',
#   'string_index': 2216,
#   'bounding_box': [1984, 1306, 2012, 1347],
#   'confidence': 0.93},
#  {'word_id': 'word_1_371',
#   'text': 'Total',
#   'string_index': 2218,
#   'bounding_box': [2015, 1310, 2083, 1335],
#   'confidence': 0.93},
#  {'word_id': 'word_1_372',
#   'text': 'a',
#   'string_index': 2224,
#   'bounding_box': [2096, 1310, 2123, 1341],
#   'confidence': 0.92},
#  {'word_id': 'word_1_373',
#   'text': '+',
#   'string_index': 2226,
#   'bounding_box': [2134, 1317, 2151, 1335],
#   'confidence': 0.92},
#  {'word_id': 'word_1_374',
#   'text': 'b',
#   'string_index': 2228,
#   'bounding_box': [2163, 1310, 2189, 1342],
#   'confidence': 0.92},
#  {'word_id': 'word_1_375',
#   'text': '$',
#   'string_index': 2230,
#   'bounding_box': [466, 1363, 482, 1393],
#   'confidence': 0.89},
#  {'word_id': 'word_1_376',
#   'text': '$',
#   'string_index': 2232,
#   'bounding_box': [841, 1363, 857, 1393],
#   'confidence': 0.89},
#  {'word_id': 'word_1_377',
#   'text': '$',
#   'string_index': 2234,
#   'bounding_box': [1216, 1363, 1232, 1393],
#   'confidence': 0.89},
#  {'word_id': 'word_1_378',
#   'text': '$',
#   'string_index': 2236,
#   'bounding_box': [1616, 1363, 1632, 1393],
#   'confidence': 0.84},
#  {'word_id': 'word_1_379',
#   'text': '$',
#   'string_index': 2238,
#   'bounding_box': [2016, 1363, 2032, 1393],
#   'confidence': 0.91},
#  {'word_id': 'word_1_380',
#   'text': 'Complete',
#   'string_index': 2240,
#   'bounding_box': [154, 1408, 303, 1441],
#   'confidence': 0.9},
#  {'word_id': 'word_1_381',
#   'text': 'this',
#   'string_index': 2249,
#   'bounding_box': [313, 1408, 370, 1434],
#   'confidence': 0.93},
#  {'word_id': 'word_1_382',
#   'text': 'line',
#   'string_index': 2254,
#   'bounding_box': [380, 1408, 436, 1434],
#   'confidence': 0.92},
#  {'word_id': 'word_1_383',
#   'text': 'if',
#   'string_index': 2259,
#   'bounding_box': [430, 1404, 465, 1445],
#   'confidence': 0.9},
#  {'word_id': 'word_1_384',
#   'text': 'this',
#   'string_index': 2262,
#   'bounding_box': [476, 1408, 532, 1434],
#   'confidence': 0.92},
#  {'word_id': 'word_1_385',
#   'text': 'is',
#   'string_index': 2267,
#   'bounding_box': [543, 1408, 568, 1434],
#   'confidence': 0.93},
#  {'word_id': 'word_1_386',
#   'text': 'a',
#   'string_index': 2270,
#   'bounding_box': [578, 1415, 595, 1434],
#   'confidence': 0.93},
#  {'word_id': 'word_1_387',
#   'text': 'refinance',
#   'string_index': 2272,
#   'bounding_box': [605, 1408, 751, 1434],
#   'confidence': 0.92},
#  {'word_id': 'word_1_388',
#   'text': 'loan.',
#   'string_index': 2282,
#   'bounding_box': [761, 1409, 836, 1434],
#   'confidence': 0.92},
#  {'word_id': 'word_1_389',
#   'text': 'Year',
#   'string_index': 2288,
#   'bounding_box': [153, 1452, 218, 1477],
#   'confidence': 0.91},
#  {'word_id': 'word_1_390',
#   'text': 'Acquired',
#   'string_index': 2293,
#   'bounding_box': [226, 1452, 354, 1483],
#   'confidence': 0.92},
#  {'word_id': 'word_1_391',
#   'text': 'Original',
#   'string_index': 2302,
#   'bounding_box': [466, 1451, 578, 1484],
#   'confidence': 0.9},
#  {'word_id': 'word_1_392',
#   'text': 'Cost',
#   'string_index': 2311,
#   'bounding_box': [590, 1451, 657, 1477],
#   'confidence': 0.92},
#  {'word_id': 'word_1_393',
#   'text': 'Amount',
#   'string_index': 2316,
#   'bounding_box': [841, 1452, 954, 1477],
#   'confidence': 0.92},
#  {'word_id': 'word_1_394',
#   'text': 'Existing',
#   'string_index': 2323,
#   'bounding_box': [966, 1452, 1079, 1484],
#   'confidence': 0.91},
#  {'word_id': 'word_1_395',
#   'text': 'Liens',
#   'string_index': 2332,
#   'bounding_box': [1092, 1452, 1168, 1477],
#   'confidence': 0.91},
#  {'word_id': 'word_1_396',
#   'text': '|',
#   'string_index': 2338,
#   'bounding_box': [1183, 1448, 1211, 1488],
#   'confidence': 0.92},
#  {'word_id': 'word_1_397',
#   'text': 'Purpose',
#   'string_index': 2340,
#   'bounding_box': [1217, 1452, 1337, 1483],
#   'confidence': 0.92},
#  {'word_id': 'word_1_398',
#   'text': 'of',
#   'string_index': 2348,
#   'bounding_box': [1349, 1452, 1375, 1477],
#   'confidence': 0.92},
#  {'word_id': 'word_1_399',
#   'text': 'Refinance',
#   'string_index': 2351,
#   'bounding_box': [1387, 1452, 1533, 1477],
#   'confidence': 0.92},
#  {'word_id': 'word_1_400',
#   'text': 'Describe',
#   'string_index': 2361,
#   'bounding_box': [1717, 1457, 1829, 1479],
#   'confidence': 0.92},
#  {'word_id': 'word_1_401',
#   'text': 'Improvements',
#   'string_index': 2370,
#   'bounding_box': [1840, 1457, 2020, 1485],
#   'confidence': 0.92},
#  {'word_id': 'word_1_402',
#   'text': '[',
#   'string_index': 2383,
#   'bounding_box': [2025, 1441, 2051, 1491],
#   'confidence': 0.0},
#  {'word_id': 'word_1_403',
#   'text': 'made',
#   'string_index': 2385,
#   'bounding_box': [2102, 1457, 2172, 1479],
#   'confidence': 0.93},
#  {'word_id': 'word_1_404',
#   'text': '[',
#   'string_index': 2390,
#   'bounding_box': [2175, 1441, 2209, 1491],
#   'confidence': 0.18},
#  {'word_id': 'word_1_405',
#   'text': 'to',
#   'string_index': 2392,
#   'bounding_box': [2253, 1458, 2275, 1479],
#   'confidence': 0.92},
#  {'word_id': 'word_1_406',
#   'text': 'be',
#   'string_index': 2395,
#   'bounding_box': [2286, 1457, 2316, 1479],
#   'confidence': 0.92},
#  {'word_id': 'word_1_407',
#   'text': 'made',
# ...
#   'bounding_box': [245, 1915, 285, 1937],
#   'confidence': 0.91},
#  {'word_id': 'word_2_314',
#   'text': 'Statement',
#   'string_index': 1782,
#   'bounding_box': [294, 1915, 424, 1938],
#   'confidence': 0.91},
#  {'word_id': 'word_2_315',
#   'text': 'can',
#   'string_index': 1792,
#   'bounding_box': [432, 1920, 477, 1937],
#   'confidence': 0.92},
#  {'word_id': 'word_2_316',
#   'text': 'be',
#   'string_index': 1796,
#   'bounding_box': [487, 1915, 517, 1937],
#   'confidence': 0.92},
#  {'word_id': 'word_2_317',
#   'text': 'meaningfully',
#   'string_index': 1799,
#   'bounding_box': [526, 1915, 687, 1943],
#   'confidence': 0.9},
#  {'word_id': 'word_2_318',
#   'text': 'and',
#   'string_index': 1812,
#   'bounding_box': [695, 1915, 742, 1937],
#   'confidence': 0.92},
#  {'word_id': 'word_2_319',
#   'text': 'fairly',
#   'string_index': 1816,
#   'bounding_box': [750, 1915, 810, 1943],
#   'confidence': 0.92},
#  {'word_id': 'word_2_320',
#   'text': 'presented',
#   'string_index': 1823,
#   'bounding_box': [818, 1915, 944, 1943],
#   'confidence': 0.92},
#  {'word_id': 'word_2_321',
#   'text': 'on',
#   'string_index': 1833,
#   'bounding_box': [953, 1921, 983, 1937],
#   'confidence': 0.93},
#  {'word_id': 'word_2_322',
#   'text': 'a',
#   'string_index': 1836,
#   'bounding_box': [992, 1921, 1007, 1937],
#   'confidence': 0.92},
#  {'word_id': 'word_2_323',
#   'text': 'combined',
#   'string_index': 1838,
#   'bounding_box': [1015, 1915, 1140, 1937],
#   'confidence': 0.92},
#  {'word_id': 'word_2_324',
#   'text': 'basis;',
#   'string_index': 1847,
#   'bounding_box': [1149, 1915, 1222, 1940],
#   'confidence': 0.91},
#  {'word_id': 'word_2_325',
#   'text': 'otherwise,',
#   'string_index': 1854,
#   'bounding_box': [1230, 1915, 1360, 1940],
#   'confidence': 0.91},
#  {'word_id': 'word_2_326',
#   'text': 'separate',
#   'string_index': 1865,
#   'bounding_box': [1369, 1917, 1480, 1942],
#   'confidence': 0.92},
#  {'word_id': 'word_2_327',
#   'text': 'Statements',
#   'string_index': 1874,
#   'bounding_box': [1489, 1915, 1633, 1938],
#   'confidence': 0.91},
#  {'word_id': 'word_2_328',
#   'text': 'and',
#   'string_index': 1885,
#   'bounding_box': [1642, 1915, 1689, 1937],
#   'confidence': 0.91},
#  {'word_id': 'word_2_329',
#   'text': 'Schedules',
#   'string_index': 1889,
#   'bounding_box': [1698, 1915, 1832, 1938],
#   'confidence': 0.91},
#  {'word_id': 'word_2_330',
#   'text': 'are',
#   'string_index': 1899,
#   'bounding_box': [1840, 1920, 1880, 1937],
#   'confidence': 0.92},
#  {'word_id': 'word_2_331',
#   'text': 'required.',
#   'string_index': 1903,
#   'bounding_box': [1890, 1915, 1999, 1943],
#   'confidence': 0.92},
#  {'word_id': 'word_2_332',
#   'text': 'If',
#   'string_index': 1913,
#   'bounding_box': [2009, 1915, 2023, 1937],
#   'confidence': 0.85},
#  {'word_id': 'word_2_333',
#   'text': 'the',
#   'string_index': 1916,
#   'bounding_box': [2030, 1915, 2069, 1937],
#   'confidence': 0.93},
#  {'word_id': 'word_2_334',
#   'text': 'Co-Borrower',
#   'string_index': 1920,
#   'bounding_box': [2078, 1915, 2241, 1938],
#   'confidence': 0.9},
#  {'word_id': 'word_2_335',
#   'text': 'section',
#   'string_index': 1932,
#   'bounding_box': [2248, 1915, 2338, 1937],
#   'confidence': 0.91},
#  {'word_id': 'word_2_336',
#   'text': 'was',
#   'string_index': 1940,
#   'bounding_box': [2347, 1920, 2397, 1937],
#   'confidence': 0.92},
#  {'word_id': 'word_2_337',
#   'text': 'completed',
#   'string_index': 1944,
#   'bounding_box': [153, 1946, 285, 1974],
#   'confidence': 0.9},
#  {'word_id': 'word_2_338',
#   'text': 'about',
#   'string_index': 1954,
#   'bounding_box': [295, 1946, 367, 1968],
#   'confidence': 0.92},
#  {'word_id': 'word_2_339',
#   'text': 'a',
#   'string_index': 1960,
#   'bounding_box': [376, 1952, 391, 1968],
#   'confidence': 0.92},
#  {'word_id': 'word_2_340',
#   'text': 'non-applicant',
#   'string_index': 1962,
#   'bounding_box': [401, 1946, 574, 1974],
#   'confidence': 0.92},
#  {'word_id': 'word_2_341',
#   'text': 'spouse',
#   'string_index': 1976,
#   'bounding_box': [583, 1952, 676, 1974],
#   'confidence': 0.92},
#  {'word_id': 'word_2_342',
#   'text': 'or',
#   'string_index': 1983,
#   'bounding_box': [686, 1952, 711, 1968],
#   'confidence': 0.93},
#  {'word_id': 'word_2_343',
#   'text': 'other',
#   'string_index': 1986,
#   'bounding_box': [720, 1946, 786, 1968],
#   'confidence': 0.91},
#  {'word_id': 'word_2_344',
#   'text': 'person,',
#   'string_index': 1992,
#   'bounding_box': [795, 1952, 888, 1974],
#   'confidence': 0.92},
#  {'word_id': 'word_2_345',
#   'text': 'this',
#   'string_index': 2000,
#   'bounding_box': [898, 1946, 943, 1968],
#   'confidence': 0.92},
#  {'word_id': 'word_2_346',
#   'text': 'Statement',
#   'string_index': 2005,
#   'bounding_box': [953, 1946, 1084, 1969],
#   'confidence': 0.91},
#  {'word_id': 'word_2_347',
#   'text': 'and',
#   'string_index': 2015,
#   'bounding_box': [1093, 1946, 1139, 1968],
#   'confidence': 0.9},
#  {'word_id': 'word_2_348',
#   'text': 'supporting',
#   'string_index': 2019,
#   'bounding_box': [1150, 1946, 1285, 1974],
#   'confidence': 0.9},
#  {'word_id': 'word_2_349',
#   'text': 'schedules',
#   'string_index': 2030,
#   'bounding_box': [1295, 1946, 1425, 1968],
#   'confidence': 0.92},
#  {'word_id': 'word_2_350',
#   'text': 'must',
#   'string_index': 2040,
#   'bounding_box': [1435, 1948, 1496, 1968],
#   'confidence': 0.92},
#  {'word_id': 'word_2_351',
#   'text': 'be',
#   'string_index': 2045,
#   'bounding_box': [1506, 1946, 1536, 1968],
#   'confidence': 0.91},
#  {'word_id': 'word_2_352',
#   'text': 'completed',
#   'string_index': 2048,
#   'bounding_box': [1546, 1946, 1678, 1974],
#   'confidence': 0.9},
#  {'word_id': 'word_2_353',
#   'text': 'about',
#   'string_index': 2058,
#   'bounding_box': [1688, 1946, 1760, 1968],
#   'confidence': 0.92},
#  {'word_id': 'word_2_354',
#   'text': 'that',
#   'string_index': 2064,
#   'bounding_box': [1768, 1946, 1817, 1968],
#   'confidence': 0.93},
#  {'word_id': 'word_2_355',
#   'text': 'spouse',
#   'string_index': 2069,
#   'bounding_box': [1826, 1952, 1918, 1974],
#   'confidence': 0.92},
#  {'word_id': 'word_2_356',
#   'text': 'or',
#   'string_index': 2076,
#   'bounding_box': [1928, 1952, 1954, 1968],
#   'confidence': 0.93},
#  {'word_id': 'word_2_357',
#   'text': 'other',
#   'string_index': 2079,
#   'bounding_box': [1962, 1946, 2028, 1968],
#   'confidence': 0.92},
#  {'word_id': 'word_2_358',
#   'text': 'person',
#   'string_index': 2085,
#   'bounding_box': [2037, 1952, 2123, 1974],
#   'confidence': 0.92},
#  {'word_id': 'word_2_359',
#   'text': 'also.',
#   'string_index': 2092,
#   'bounding_box': [2134, 1946, 2191, 1968],
#   'confidence': 0.93},
#  {'word_id': 'word_2_360',
#   'text': 'Completed',
#   'string_index': 2098,
#   'bounding_box': [1778, 1988, 1916, 2016],
#   'confidence': 0.91},
#  {'word_id': 'word_2_361',
#   'text': 'x]',
#   'string_index': 2108,
#   'bounding_box': [1981, 1972, 2036, 2022],
#   'confidence': 0.71},
#  {'word_id': 'word_2_362',
#   'text': 'Jointly',
#   'string_index': 2111,
#   'bounding_box': [2044, 1984, 2125, 2021],
#   'confidence': 0.91},
#  {'word_id': 'word_2_363',
#   'text': ']',
#   'string_index': 2119,
#   'bounding_box': [2210, 1976, 2227, 2012],
#   'confidence': 0.65},
#  {'word_id': 'word_2_364',
#   'text': 'Not',
#   'string_index': 2121,
#   'bounding_box': [2242, 1988, 2285, 2010],
#   'confidence': 0.89},
#  {'word_id': 'word_2_365',
#   'text': 'Jointly',
#   'string_index': 2125,
#   'bounding_box': [2293, 1988, 2374, 2016],
#   'confidence': 0.91},
#  {'word_id': 'word_2_367',
#   'text': 'ASSETS',
#   'string_index': 2133,
#   'bounding_box': [370, 2029, 484, 2052],
#   'confidence': 0.9},
#  {'word_id': 'word_2_368',
#   'text': 'Description',
#   'string_index': 2140,
#   'bounding_box': [154, 2063, 297, 2091],
#   'confidence': 0.91},
#  {'word_id': 'word_2_369',
#   'text': 'Cash',
#   'string_index': 2152,
#   'bounding_box': [811, 2029, 880, 2052],
#   'confidence': 0.91},
#  {'word_id': 'word_2_370',
#   'text': 'or',
#   'string_index': 2157,
#   'bounding_box': [890, 2035, 918, 2052],
#   'confidence': 0.91},
#  {'word_id': 'word_2_371',
#   'text': 'Market',
#   'string_index': 2160,
#   'bounding_box': [778, 2063, 869, 2085],
#   'confidence': 0.9},
#  {'word_id': 'word_2_372',
#   'text': 'Value',
#   'string_index': 2167,
#   'bounding_box': [876, 2063, 951, 2085],
#   'confidence': 0.9},
#  {'word_id': 'word_2_374',
#   'text': 'Cash',
#   'string_index': 2173,
#   'bounding_box': [153, 2108, 218, 2131],
#   'confidence': 0.91},
#  {'word_id': 'word_2_375',
#   'text': 'deposit',
#   'string_index': 2178,
#   'bounding_box': [229, 2109, 321, 2137],
#   'confidence': 0.92},
#  {'word_id': 'word_2_376',
#   'text': 'toward',
#   'string_index': 2186,
#   'bounding_box': [330, 2109, 414, 2131],
#   'confidence': 0.92},
#  {'word_id': 'word_2_377',
#   'text': 'purchase',
#   'string_index': 2193,
#   'bounding_box': [424, 2109, 542, 2137],
#   'confidence': 0.9},
#  {'word_id': 'word_2_378',
#   'text': 'held',
#   'string_index': 2202,
#   'bounding_box': [552, 2109, 604, 2131],
#   'confidence': 0.93},
#  {'word_id': 'word_2_379',
#   'text': 'by:',
#   'string_index': 2207,
#   'bounding_box': [615, 2109, 650, 2137],
#   'confidence': 0.93},
#  {'word_id': 'word_2_380',
#   'text': 'Liabilities',
#   'string_index': 2211,
#   'bounding_box': [1041, 2029, 1173, 2052],
#   'confidence': 0.92},
#  {'word_id': 'word_2_381',
#   'text': 'and',
#   'string_index': 2223,
#   'bounding_box': [1181, 2030, 1231, 2052],
#   'confidence': 0.9},
#  {'word_id': 'word_2_382',
#   'text': 'Pledged',
#   'string_index': 2227,
#   'bounding_box': [1242, 2030, 1352, 2058],
#   'confidence': 0.91},
#  {'word_id': 'word_2_383',
#   'text': 'Assets.',
#   'string_index': 2235,
#   'bounding_box': [1360, 2030, 1461, 2052],
#   'confidence': 0.92},
#  {'word_id': 'word_2_384',
#   'text': 'List',
#   'string_index': 2243,
#   'bounding_box': [1471, 2030, 1514, 2052],
#   'confidence': 0.93},
#  {'word_id': 'word_2_385',
#   'text': 'the',
#   'string_index': 2248,
#   'bounding_box': [1522, 2030, 1561, 2052],
#   'confidence': 0.93},
#  {'word_id': 'word_2_386',
#   'text': "creditor’'s",
#   'string_index': 2252,
#   'bounding_box': [1570, 2030, 1685, 2052],
#   'confidence': 0.4},
#  {'word_id': 'word_2_387',
#   'text': 'name,',
#   'string_index': 2264,
#   'bounding_box': [1694, 2035, 1771, 2055],
#   'confidence': 0.91},
#  {'word_id': 'word_2_388',
#   'text': 'address,',
#   'string_index': 2270,
#   'bounding_box': [1782, 2030, 1890, 2055],
#   'confidence': 0.92},
#  {'word_id': 'word_2_389',
#   'text': 'and',
#   'string_index': 2279,
#   'bounding_box': [1900, 2030, 1946, 2052],
#   'confidence': 0.92},
#  {'word_id': 'word_2_390',
#   'text': 'account',
#   'string_index': 2283,
#   'bounding_box': [1956, 2031, 2057, 2052],
#   'confidence': 0.92},
#  {'word_id': 'word_2_391',
#   'text': 'number',
#   'string_index': 2291,
#   'bounding_box': [2066, 2030, 2163, 2052],
#   'confidence': 0.92},
#  {'word_id': 'word_2_392',
#   'text': 'for',
#   'string_index': 2298,
#   'bounding_box': [2170, 2030, 2204, 2052],
#   'confidence': 0.92},
#  {'word_id': 'word_2_393',
#   'text': 'all',
#   'string_index': 2302,
#   'bounding_box': [2212, 2030, 2239, 2052],
#   'confidence': 0.88},
#  {'word_id': 'word_2_394',
#   'text': 'outstanding',
#   'string_index': 2306,
#   'bounding_box': [2248, 2030, 2397, 2058],
#   'confidence': 0.89},
#  {'word_id': 'word_2_395',
#   'text': 'debts,',
#   'string_index': 2318,
#   'bounding_box': [1039, 2063, 1115, 2088],
#   'confidence': 0.9},
#  {'word_id': 'word_2_396',
#   'text': 'including',
#   'string_index': 2325,
#   'bounding_box': [1125, 2063, 1237, 2091],
#   'confidence': 0.91},
#  {'word_id': 'word_2_397',
#   'text': 'automobile',
#   'string_index': 2335,
#   'bounding_box': [1245, 2063, 1385, 2085],
#   'confidence': 0.92},
#  {'word_id': 'word_2_398',
#   'text': 'loans,',
#   'string_index': 2346,
#   'bounding_box': [1393, 2063, 1467, 2089],
#   'confidence': 0.92},
#  {'word_id': 'word_2_399',
#   'text': 'revolving',
#   'string_index': 2353,
#   'bounding_box': [1477, 2063, 1587, 2091],
#   'confidence': 0.93},
#  {'word_id': 'word_2_400',
#   'text': 'charge',
#   'string_index': 2363,
#   'bounding_box': [1595, 2063, 1682, 2091],
#   'confidence': 0.92},
#  {'word_id': 'word_2_401',
#   'text': 'accounts,',
#   'string_index': 2370,
#   'bounding_box': [1690, 2065, 1811, 2089],
#   'confidence': 0.9},
#  {'word_id': 'word_2_402',
#   'text': 'real',
#   'string_index': 2380,
#   'bounding_box': [1821, 2063, 1866, 2085],
#   'confidence': 0.9},
#  {'word_id': 'word_2_403',
#   'text': 'estate',
#   'string_index': 2385,
#   'bounding_box': [1874, 2065, 1951, 2085],
#   'confidence': 0.93},
#  {'word_id': 'word_2_404',
#   'text': 'loans,',
#   'string_index': 2392,
#   'bounding_box': [1960, 2063, 2033, 2089],
#   'confidence': 0.92},
#  {'word_id': 'word_2_405',
#   'text': 'alimony,',
#   'string_index': 2399,
#   'bounding_box': [2042, 2063, 2144, 2091],
#   'confidence': 0.91},
#  {'word_id': 'word_2_406',
#   'text': 'child',
#   'string_index': 2408,
#   'bounding_box': [2153, 2063, 2211, 2085],
#   'confidence': 0.92},
#  {'word_id': 'word_2_407',
#   'text': 'support,',
#   'string_index': 2414,
#   'bounding_box': [2219, 2065, 2322, 2091],
#   'confidence': 0.92},
#  {'word_id': 'word_2_408',
#   'text': 'stock',
#   'string_index': 2423,
#   'bounding_box': [2331, 2063, 2397, 2085],
#   'confidence': 0.92},
#  {'word_id': 'word_2_409',
#   'text': 'pledges,',
#   'string_index': 2429,
#   'bounding_box': [1040, 2096, 1146, 2125],
#   'confidence': 0.92},
#  {'word_id': 'word_2_410',
#   'text': 'etc.',
#   'string_index': 2438,
#   'bounding_box': [1155, 2098, 1199, 2119],
#   'confidence': 0.92},
#  {'word_id': 'word_2_411',
#   'text': 'Use',
#   'string_index': 2443,
#   'bounding_box': [1207, 2096, 1256, 2119],
#   'confidence': 0.92},
#  {'word_id': 'word_2_412',
#   'text': 'continuation',
#   'string_index': 2447,
#   'bounding_box': [1264, 2096, 1418, 2119],
#   'confidence': 0.92},
#  {'word_id': 'word_2_413',
#   'text': 'sheet,',
#   'string_index': 2460,
#   'bounding_box': [1427, 2096, 1503, 2122],
#   'confidence': 0.92},
#  {'word_id': 'word_2_414',
#   'text': 'if',
#   'string_index': 2467,
#   'bounding_box': [1513, 2096, 1525, 2118],
#   'confidence': 0.93},
#  {'word_id': 'word_2_415',
#   'text': 'necessary.',
#   'string_index': 2470,
#   'bounding_box': [1534, 2102, 1668, 2124],
#   'confidence': 0.92},
#  {'word_id': 'word_2_416',
#   'text': 'Indicate',
#   'string_index': 2481,
#   'bounding_box': [1677, 2096, 1775, 2118],
#   'confidence': 0.91},
#  {'word_id': 'word_2_417',
#   'text': 'by',
#   'string_index': 2490,
#   'bounding_box': [1783, 2097, 1812, 2124],
#   'confidence': 0.93},
#  {'word_id': 'word_2_418',
#   'text': '*',
#   'string_index': 2493,
#   'bounding_box': [1820, 2096, 1848, 2124],
#   'confidence': 0.91},
#  {'word_id': 'word_2_419',
#   'text': 'those',
#   'string_index': 2495,
#   'bounding_box': [1855, 2096, 1925, 2119],
#   'confidence': 0.92},
#  {'word_id': 'word_2_420',
#   'text': 'liabilities,',
#   'string_index': 2501,
#   'bounding_box': [1934, 2096, 2047, 2122],
#   'confidence': 0.89},
#  {'word_id': 'word_2_421',
#   'text': 'which',
#   'string_index': 2514,
#   'bounding_box': [2056, 2096, 2128, 2118],
#   'confidence': 0.93},
#  {'word_id': 'word_2_422',
#   'text': 'will',
#   'string_index': 2520,
#   'bounding_box': [2137, 2096, 2175, 2118],
#   'confidence': 0.91},
#  {'word_id': 'word_2_423',
#   'text': 'be',
#   'string_index': 2525,
#   'bounding_box': [2184, 2097, 2214, 2118],
#   'confidence': 0.93},
#  {'word_id': 'word_2_424',
#   'text': 'satisfied',
#   'string_index': 2528,
#   'bounding_box': [2222, 2096, 2326, 2119],
#   'confidence': 0.91},
#  {'word_id': 'word_2_425',
#   'text': 'upon',
#   'string_index': 2538,
#   'bounding_box': [2335, 2102, 2397, 2124],
#   'confidence': 0.93},
#  {'word_id': 'word_2_426',
#   'text': 'sale',
#   'string_index': 2543,
#   'bounding_box': [1040, 2130, 1091, 2152],
#   'confidence': 0.9},
#  {'word_id': 'word_2_427',
#   'text': 'of',
#   'string_index': 2548,
#   'bounding_box': [1101, 2129, 1125, 2152],
#   'confidence': 0.9},
#  {'word_id': 'word_2_428',
#   'text': 'real',
#   'string_index': 2551,
#   'bounding_box': [1135, 2130, 1179, 2152],
#   'confidence': 0.91},
#  {'word_id': 'word_2_429',
#   'text': 'estate',
#   'string_index': 2556,
#   'bounding_box': [1190, 2131, 1267, 2152],
#   'confidence': 0.92},
#  {'word_id': 'word_2_430',
#   'text': 'owned',
#   'string_index': 2563,
#   'bounding_box': [1276, 2130, 1360, 2152],
#   'confidence': 0.93},
#  {'word_id': 'word_2_431',
#   'text': 'or',
#   'string_index': 2569,
#   'bounding_box': [1370, 2135, 1395, 2152],
#   'confidence': 0.92},
#  ...]

# %%
untagged_word_ids = [ent["word_id"] for ent in list_of_untagged_entities]

# %% [markdown]
# # Now Tagging experimentation with other taggers

# %%
def process_tagged_with_text(page):
    # extract all named entities
    tagged_entities = []
    index_count = 0
    entity_id = ''
    
    for term, tag in sentence:
        if tag != 'O':
            word = term
            word_tag = tag
            entity_id = uuid.uuid4()
            make_entity = {'entity_id': entity_id.hex, 'text': word, 'entity_score': 0.9902280569076538 , 'entity_type': word_tag,'string_index': index_count }                    
            index_count = len(term)+index_count+1
            tagged_entities.append(make_entity)
        else:
            index_count = len(term)+index_count+1
        
    return tagged_entities

# %%
tagged_snre_pages = []
for blob_by_page in page_blobs:
    temp_tag = [sner_tagger.tag(word_tokenize(blob_by_page))]
    temp_result_array = process_tagged_with_text(temp_tag)
    tagged_snre_pages.append(temp_result_array)

# %%
zipped_sner_tagged_entities = tagger.zip_words_entities(temp_untagged[0],tagged_snre_pages[0])

# %%
comparelist = [word["word_id"] for word in zipped_sner_tagged_entities["entities"]]

# %%
comparelist
# Out:
# ['word_1_1',
#  'word_1_2',
#  'word_1_3',
#  'word_1_4',
#  'word_1_5',
#  'word_1_6',
#  'word_1_200',
#  'word_1_308',
#  'word_1_443',
#  'word_1_482',
#  'word_1_624',
#  'word_1_799',
#  'word_1_807']

# %%
page_blobs[0]
# Out:
# "Yellowstone Bank Uniform Residential Loan Application This application is designed to be completed by the applicants with the Lender’s assistance. Applicants should complete this form as “Borrower” or “Co-Borrower,” as applicable. Co-Borrower information must also be provided and the appropriate box checked when the income or assets of a person other than the Borrower including the Borrower’s spouse will be used as a basis for loan qualification or the income or assets of the Borrower’s spouse or other person who has community property rights pursuant to state law will not be used as a basis for loan qualification, but his or her liabilities must be considered because the spouse or other person has community property rights pursuant to applicable law and Borrower resides in a community property state, the security property is located in a community property state, or the Borrower is relying on other property LOAN #: 1180303 located in a community property state as a basis for repayment of the loan. If this is an application for joint credit, Borrower and Co-Borrower each agree that we intend to apg_ly for joint credit sign below: DocuSigned by: DocuSigned by —thu'tl M Jolunson. 31912018 | 09:23:25 pDT | \\VAddoria Switly Jelunson, 3/19/2018 | 09:30:08 PDT Borfgeperes7c4400 Co-BbFewER: | I. TYPE OF MORTGAGE AND TERMS OF LOAN Mortgage [_JVA [¥]Conventional []Other explain: Agency Case Number Lender Case Number Applied for: [_JFHA []USDA/Rural Housing Service 1180303 Amount Interest Rate No. of Months | Amortization [X] Fixed Rate [ ] Other explain: $ 164,700.00 4375 % | 360 Type: CaPm CJARM type: I Il. PROPERTY INFORMATION AND PURPOSE OF LOAN Subject Property Address street, city, state, & ZIP No. of Units 29 Laptop Loop, Roberts, MT 59070 County: Carbon 1 Legal Description of Subject Property attach description if necessary Year Built 2017 Purpose of Loan [X] Purchase ] Construction [ other explain: Property will be: [1 Refinance [] Construction-Permanent Primary [] Secondary [] Investment Residence Residence Complete this line if construction or construction-permanent loan. Year Lot Acquired | Original Cost Amount Existing Liens | a Present Value of Lot | b Cost of Improvements | Total a + b $ $ $ $ $ Complete this line if this is a refinance loan. Year Acquired Original Cost Amount Existing Liens | Purpose of Refinance Describe Improvements [ made [ to be made $ $ Cost: $ Title will be held in what Names Daniel M Johnson, Victoria Smith Johnson Manner in which Title will be held Joint tenants Source of Down Payment, Settlement Charges, and/or Subordinate Financing explain Equity On Pending Sale Estate will be held in: Fee Simple Leasehold show expiration date Borrower Ill. BORROWER INFORMATION Co-Borrower Borrower’s Name include Jr. or Sr. if applicable Daniel M Johnson Co-Borrower’s Name include Jr. or Sr. if applicable Victoria Smith Johnson Social Security Number Home Phone incl. area code 434-06-8836 337-998-1279 DOB mm/dd/yyyy | Yrs. School 04/12/1967 14 ISocial Security Number Home Phone incl. area code 438-39-1513 337-936-1975 DOB mm/dd/yyyy 09/15/1970 Yrs. School 14 [X] Married [] Unmarried include single, | Dependents not listed by Co-Borrower divorced, widowed [X] married [] Unmarried include single, divorced, widowed Dependents not listed by Borrower [ Separated no.1 ages 5 [ Separated no.o ages Present Address street, city, state, ZIP [¥]Own []Rent No.Yrs. |PresentAddress street, city, state, ZIP [¥]Own [JRent No.Yrs. 2803 lkes Rd 18Y OM | 2803 Ikes Rd 18Y OM Kinder, LA 70648 Kinder, LA 70648 Mailing Address, if different from Present Address Mailing Address, if different from Present Address 2803 lkes Rd 2803 lkes Rd Kinder, LA 70648 Kinder, LA 70648 If residing at present address for less than two years, complete the following: Former Address street, city, state, ZIP [CJown [CJRent No.Yrs. |FormerAddress street, city, state, ZIP [Jown [CJRent No.Yrs. Borrower IV. EMPLOYMENT INFORMATION Co-Borrower Name & Addres ...

# %%
# !pip install Snorkel
# Out:
# Collecting Snorkel
#   Downloading snorkel-0.9.6-py3-none-any.whl (144 kB)
#      |████████████████████████████████| 144 kB 13.0 MB/s eta 0:00:01
# Requirement already satisfied: pandas<2.0.0,>=0.25.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from Snorkel) (1.0.3)
# Requirement already satisfied: numpy<2.0.0,>=1.16.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from Snorkel) (1.18.1)
# Collecting munkres>=1.0.6
#   Downloading munkres-1.1.2-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: scipy<2.0.0,>=1.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from Snorkel) (1.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.33.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from Snorkel) (4.44.1)
# Collecting scikit-learn<0.22.0,>=0.20.2
#   Downloading scikit_learn-0.21.3-cp36-cp36m-manylinux1_x86_64.whl (6.7 MB)
#      |████████████████████████████████| 6.7 MB 31.7 MB/s eta 0:00:01
# Collecting torch<2.0.0,>=1.2.0
#   Downloading torch-1.6.0-cp36-cp36m-manylinux1_x86_64.whl (748.8 MB)
#      |████████████████████████████████| 748.8 MB 2.9 kB/s  eta 0:00:01
# Collecting tensorboard<2.0.0,>=1.14.0
#   Downloading tensorboard-1.15.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 50.5 MB/s eta 0:00:01
# Collecting networkx<2.4,>=2.2
#   Downloading networkx-2.3.zip (1.7 MB)
#      |████████████████████████████████| 1.7 MB 38.0 MB/s eta 0:00:01
# Requirement already satisfied: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas<2.0.0,>=0.25.0->Snorkel) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas<2.0.0,>=0.25.0->Snorkel) (2.8.1)
# Requirement already satisfied: joblib>=0.11 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from scikit-learn<0.22.0,>=0.20.2->Snorkel) (0.14.1)
# Requirement already satisfied: future in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from torch<2.0.0,>=1.2.0->Snorkel) (0.18.2)
# Collecting grpcio>=1.6.3
#   Downloading grpcio-1.31.0-cp36-cp36m-manylinux2014_x86_64.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 67.8 MB/s eta 0:00:01
# Requirement already satisfied: protobuf>=3.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorboard<2.0.0,>=1.14.0->Snorkel) (3.12.2)
# Requirement already satisfied: setuptools>=41.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorboard<2.0.0,>=1.14.0->Snorkel) (46.1.3.post20200330)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorboard<2.0.0,>=1.14.0->Snorkel) (1.0.1)
# Requirement already satisfied: six>=1.10.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorboard<2.0.0,>=1.14.0->Snorkel) (1.14.0)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.2.2-py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 10.9 MB/s eta 0:00:01
# Collecting absl-py>=0.4
#   Downloading absl-py-0.9.0.tar.gz (104 kB)
#      |████████████████████████████████| 104 kB 67.6 MB/s eta 0:00:01
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorboard<2.0.0,>=1.14.0->Snorkel) (0.34.2)
# Requirement already satisfied: decorator>=4.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from networkx<2.4,>=2.2->Snorkel) (4.4.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from markdown>=2.6.8->tensorboard<2.0.0,>=1.14.0->Snorkel) (1.5.0)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.0.0,>=1.14.0->Snorkel) (2.2.0)
# Building wheels for collected packages: networkx, absl-py
#   Building wheel for networkx (setup.py) ... done
#   Created wheel for networkx: filename=networkx-2.3-py2.py3-none-any.whl size=1556408 sha256=7009104369e71a3d528a1411fe2f10fccf4f31af54034f6aa4e03ade93d91ef1
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/81/dc/bb/fbde77ddcbf8d5a04787faf6cc9f1edf4c70a67961d7c75abf
#   Building wheel for absl-py (setup.py) ... done
#   Created wheel for absl-py: filename=absl_py-0.9.0-py3-none-any.whl size=121931 sha256=7af15f5441e1828203c81df99fe46bb6ecb087e07f3762a55fb3cf1ca7c3f9b2
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/c3/af/84/3962a6af7b4ab336e951b7877dcfb758cf94548bb1771e0679
# Successfully built networkx absl-py
# Installing collected packages: munkres, scikit-learn, torch, grpcio, markdown, absl-py, tensorboard, networkx, Snorkel
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.22.1
#     Uninstalling scikit-learn-0.22.1:
#       Successfully uninstalled scikit-learn-0.22.1
#   Attempting uninstall: networkx
#     Found existing installation: networkx 2.4
#     Uninstalling networkx-2.4:
#       Successfully uninstalled networkx-2.4
# Successfully installed Snorkel-0.9.6 absl-py-0.9.0 grpcio-1.31.0 markdown-3.2.2 munkres-1.1.2 networkx-2.3 scikit-learn-0.21.3 tensorboard-1.15.0 torch-1.6.0
# WARNING: You are using pip version 20.0.2; however, version 20.2.2 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
