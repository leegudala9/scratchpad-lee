# %%
import urllib.request

# %%
filename = "1003_rid_new.txt"
with open(filename) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content]

# %%
content
# Out:
# ['bd5ff6ce-f0cf-4b16-8e75-5a25b09b6ad6',
#  'b92f37d3-0e81-4ec8-9748-c671367f1608',
#  'a0a6cdfd-3702-461f-bd0b-55d438c165ce',
#  '01f10366-dfd8-40cc-848a-a50d0940c563',
#  '1d6a9945-0551-41e9-b780-d9e3320a9a3d',
#  'dcc3eec3-bee5-4a59-b705-f9bc7ee2dcaf',
#  'a9495265-db4b-441f-993b-3f41a65c4cb3',
#  'bddbaf72-0729-413b-bbe9-f7f0b3b1f8e3',
#  'c16bc10f-4020-4565-b425-bcb9e656b948',
#  '31681405-e27d-4750-abe6-b82a3b8d912a',
#  '9063b293-5a80-46e5-8a84-8f1c83c3ff34',
#  'a25e3f47-a998-4312-b213-713b982fb8fa',
#  '1a4a3a3f-55a0-4b9e-8c4d-0b9751daa511',
#  '2f6fdd72-b3fa-4e75-ac4b-5bdc7eb3a308',
#  '9b27b3a8-8995-41de-8b30-e87a85d1648f',
#  '1dde1a3d-6818-428c-b63b-923825ef9b74',
#  '98a31bfb-caf4-45d2-92de-ea4af7e94ee1',
#  '553062be-3c1a-4b88-a600-ecb631790377',
#  '465e36be-86a6-42f0-9aeb-c36f4b84a828',
#  '720149b0-42de-4087-8f60-eec741e1d7c7',
#  '142a7af8-9e44-41cf-9033-0e62fe08f8e2',
#  'ae987c20-4519-4191-abdd-3c22d2b40162',
#  '274e9551-e87c-4e24-8768-07dff7a79fd7',
# ...

# %%
for i in content:
    link = f'https://remember.calibertraining.heavywater.com/recall?_remember_id={i}&_datapoint=_aggregated_ocr'
    print(link)
# Out:
# https://remember.calibertraining.heavywater.com/recall?_remember_id=0461de27-8b27-481f-9528-2c044ae0c4dd&_datapoint=_aggregated_ocr
# https://remember.calibertraining.heavywater.com/recall?_remember_id=1171e553-e248-4dc1-a341-89df73674921&_datapoint=_aggregated_ocr
# https://remember.calibertraining.heavywater.com/recall?_remember_id=3507f955-9d4b-4057-a4a9-c683f35c20bf&_datapoint=_aggregated_ocr
# https://remember.calibertraining.heavywater.com/recall?_remember_id=1be4eec7-5d53-4289-a114-ce59777bf496&_datapoint=_aggregated_ocr
# https://remember.calibertraining.heavywater.com/recall?_remember_id=178124aa-fa54-48c7-95ce-42454e30afaf&_datapoint=_aggregated_ocr
# https://remember.calibertraining.heavywater.com/recall?_remember_id=0e4c6c87-1ec4-4742-a5b4-b0588ea0b9a4&_datapoint=_aggregated_ocr
# https://remember.calibertraining.heavywater.com/recall?_remember_id=1cd460a6-cc1a-45bf-9a34-a255f3289f4d&_datapoint=_aggregated_ocr
# ...

# %%
req = urllib.request.Request(link)
with urllib.request.urlopen(req) as response:
       the_page = response.read()

# %%
the_page
# Out:
# b'{"datapoints":[{"metadata":{"_remember_id":"4cf6d225-31d3-43ad-b245-87fd35a0ae31","_datapoint":"_aggregated_ocr","memorized_date":"2020-06-19T20:19:18.013"},"data":"S3://hw-app-usbank-training/aiva/SI/2020:06:19:14:38:45:4CfnC1/AggregatedOCR/4cf6d225-31d3-43ad-b245-87fd35a0ae31.json"}],"message":"successful recall"}'

# %%
'https://remember.usbanktraining.heavywater.com/recall?_remember_id=0461de27-8b27-481f-9528-2c044ae0c4dd&_datapoint=_aggregated_ocr'

# %%
# !export AWS_ACCESS_KEY_ID="ASIA2SS3XVNQCQM3CKXI"
# !export AWS_SECRET_ACCESS_KEY="6j+BpiwweJl/C7JRiE1Vqhj9LzY5PMx3JizdBXLk"
# !export AWS_SESSION_TOKEN="..."

# %%
import boto3
BUCKET = 'hw-app-usbank-training'
FILE_TO_READ = "S3://hw-app-usbank-training/aiva/SI/2020:06:19:14:38:45:4CfnC1/AggregatedOCR/4cf6d225-31d3-43ad-b245-87fd35a0ae31.json"
client = boto3.client('s3',
                       aws_access_key_id = AWS_ACCESS_KEY_ID
                       aws_secret_access_key = AWS_SECRET_ACCESS_KEY
                     )
result = client.get_object(Bucket=BUCKET, Key=FILE_TO_READ) 
text = result["Body"].read().decode()
print(text['Details']) #
# Out:
#   File "<ipython-input-22-77115e1eec01>", line 6
#     aws_secret_access_key = AWS_SECRET_ACCESS_KEY
#                         ^
# SyntaxError: invalid syntax

# %%
s3_obj =boto3.client('s3')

s3_clientobj = s3_obj.get_object(Bucket=BUCKET, Key=FILE_TO_READ)
s3_clientdata = s3_clientobj['Body'].read().decode('utf-8')
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-28-a18c79e1edd6> in <module>
#       1 s3_obj =boto3.client('s3')
#       2
# ----> 3 s3_clientobj = s3_obj.get_object(Bucket=BUCKET, Key=FILE_TO_READ)
#       4 s3_clientdata = s3_clientobj['Body'].read().decode('utf-8')
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     314                     "%s() only accepts keyword arguments." % py_operation_name)
#     315             # The "self" in this scope is referring to the BaseClient.
# --> 316             return self._make_api_call(operation_name, kwargs)
#     317
#     318         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
# ...
