# %%
import entity_formatter
from entity_tagger import entity_tagger as tagger
import requests
import json
import pandas as pd
import boto3
import traceback

# %%
## MOST IMPORTANT
exp_id = "exp03" #unique for each experiment

# %%
ssm = boto3.client("ssm")
s3 = boto3.client("s3")
root_url = ssm.get_parameter(Name=f"/account/root-url")["Parameter"]["Value"]
apikey = ssm.get_parameter(Name="/account/internal-api-key")["Parameter"]["Value"]
v1_url = f"https://remember.{root_url}"
v2_url = f"https://rememberv2.{root_url}/latest"
acc_owner = ssm.get_parameter(Name="/account/owner")["Parameter"]["Value"].upper()
headers = {"x-api-key": apikey, "Authorization": apikey}

# %%
def rememberv2_query(index={}, filters={}):
    url = f"{v2_url}/query"
    results = {}
    try:
        payload = {
            "Index": index,
            "Filter": filters
        }
        results = json.loads(requests.post(url=url, data=json.dumps(payload), headers=headers).text)["Results"]
    except:
        print(traceback.format_exc())    
    return results


def rememberv2_read(objectid):
    url = f"{v2_url}/read"
    results = {}
    try:
        payload = {
            "ObjectId": objectid,
        }
        results = json.loads(requests.post(url=url, data=json.dumps(payload), headers=headers).text)["Results"]
    except:
        print(traceback.format_exc())
    return results



def remember_recall(rid, datapoint):
    url = f"{v1_url}/recall?_remember_id={rid}&_datapoint={datapoint}"
    res = {}
    try:
        res = json.loads(requests.get(url=url).text)["datapoints"][0]["data"]
    except:
        print(traceback.format_exc())
    return res
    
# def make_text_blob(word_ocr):
#     text_list = []
    
#     for i in word_ocr["Words"]:
#         text_list.append(i["text"])
#     #print("\n\n\nBefore Sending it off: " , text_list)
#     return text_list

def remember_write(datapoint):
    resp_dict = {}
    url = f"{v2_url}/write"
    try:
        resp = requests.post(
            url=url, data=json.dumps(datapoint), headers=headers
        )
        resp_dict = resp.json()
    except:
        print(traceback.format_exc())
    return resp_dict


def create_datapoint(Type, Fields, TransactionId, Attributes=None):
    datapoint = {
        "Type": Type,
        "Fields": Fields,
        "TransactionId": TransactionId,
    }
    if Attributes != None:
        datapoint["Attributes"] = Attributes
    return remember_write(datapoint)


def remember_memorize(data, rid, datapoint, metadata={}):
    url = f"{v1_url}/memoorize"
    try:
        metadata.update({
            "_remember_id": rid,
            "_datapoint": datapoint
        })
        payload = {
            "data": data,
            "metadata": metadata 
        }
        resp = requests.post(
                url=url, data=json.dumps(payload), headers=headers)
    except:
        print(traceback.format_exc())
    return resp
def do_sner_tag(text):
    text = text.replace("/","-")
    text = text.replace("[]","")
    tagged_list = sner_tagger.tag(word_tokenize(text))
    return tagged_list
def do_spacy_tag(text):
    text = text.replace("/","-")
    

def aggregate_formatted_entities(docid):
    temp_dict = {}
    try:
        recall_txn = rememberv2_read(docid)[0]
        txnid = recall_txn["TransactionId"]
        file_pages = recall_txn["Pages"]
        start = file_pages[0]
        doc_pages = list(range(1, len(file_pages)+1))
        page_ocrs_ids = {x['ParentIndex']:x['ObjectId'] for x in rememberv2_query({'PageOcr::TransactionId': txnid}, {'ParentIndex': file_pages})}
        results = {}
        formatted_doc = {}
        for page in sorted(page_ocrs_ids.keys()):
            try:
                words_ocr = rememberv2_query({'Parent': page_ocrs_ids[page]})
                parsed_words = tagger.parse_words(words_ocr[0]['Words'])
                

                tagged = tagger.handler({'body': json.dumps(words_ocr[0])}, {})
                formatted = entity_formatter.format_entities(json.loads(tagged['body'])['entities'], page-start+1)['body']
                results[page] = formatted
                create_datapoint("PageTaggedEntitiesExp", {"Entities": formatted, "FilePageIndex": page, "ExpId": exp_id}, txnid ,{"PageTaggedEntitiesExp::DocumentId": docid})
                for key in formatted.keys():
                    if key in formatted_doc:
                        formatted_doc[key] = formatted_doc[key] + formatted[key]
                    else:
                        formatted_doc[key] = formatted[key]
            except:
                print(traceback.format_exc())
                pass
        return formatted_doc
    except:
        print(traceback.format_exc())
        pass


def get_bucket_key(path):
    bucket = path.split('/')[2]
    key = path.replace(f'S3://{bucket}/', '')
    return bucket, key


def get_object(path, s3):
    bucket, key = get_bucket_key(path)
    res = s3.get_object(
        Bucket=bucket,
        Key=key
    )['Body'].read().decode('utf-8')
    return res


def put_object(path, s3, data):
    bucket, key = get_bucket_key(path)
    s3.put_object(
        Bucket=bucket,
        Body=json.dumps(data),
        Key=key
    )
    
    
    
def memorize_results_update_inplace(docid):
    formatted_doc = aggregate_formatted_entities(docid)
    current_path = remember_recall(docid, '_aggregated_formatted_entities_path')
    new_path = current_path.replace("FormattedEntities", f"FormattedEntities{exp_id}")
    put_object(new_path, s3, formatted_doc)
    return new_path

# %%
text_test = "Yellowstone Bank Uniform Residential Loan Application This application is designed to be completed by the applicants with the Lender’s assistance. Applicants should complete this form as “Borrower” or “Co-Borrower,” as applicable. Co-Borrower information must also be provided and the appropriate box checked when the income or assets of a person other than the Borrower including the Borrower’s spouse will be used as a basis for loan qualification or the income or assets of the Borrower’s spouse or other person who has community property rights pursuant to state law will not be used as a basis for loan qualification, but his or her liabilities must be considered because the spouse or other person has community property rights pursuant to applicable law and Borrower resides in a community property state, the security property is located in a community property state, or the Borrower is relying on other property LOAN #: 1180303 located in a community property state as a basis for repayment of the loan. If this is an application for joint credit, Borrower and Co-Borrower each agree that we intend to apg_ly for joint credit sign below: DocuSigned by: DocuSigned by —thu'tl M Jolunson. 31912018 | 09:23:25 pDT | \\VAddoria Switly Jelunson, 3-19-2018 | 09:30:08 PDT Borfgeperes7c4400 Co-BbFewER: | I. TYPE OF MORTGAGE AND TERMS OF LOAN Mortgage [_JVA [¥]Conventional Other explain: Agency Case Number Lender Case Number Applied for: [_JFHA USDA-Rural Housing Service 1180303 Amount: $ 164,700.00 Interest Rate 4375 %  No. of Months 360  | Amortization [X] Fixed Rate [ ] Other explain:  | Type: CaPm CJARM type: I Il. PROPERTY INFORMATION AND PURPOSE OF LOAN Subject Property Address street, city, state, & ZIP  29 Laptop Loop, Roberts, MT 59070 County: Carbon  No. of Units 1 1 Legal Description of Subject Property attach description if necessary Year Built 2017 Purpose of Loan [X] Purchase ] Construction [ other explain: Property will be: [1 Refinance  Construction-Permanent Primary  Secondary  Investment Residence Residence Complete this line if construction or construction-permanent loan. Year Lot Acquired | Original Cost Amount Existing Liens | a Present Value of Lot | b Cost of Improvements | Total a + b $ $ $ $ $ Complete this line if this is a refinance loan. Year Acquired Original Cost Amount Existing Liens | Purpose of Refinance Describe Improvements [ made [ to be made $ $ Cost: $ Title will be held in what Names Daniel M Johnson, Victoria Smith Johnson Manner in which Title will be held Joint tenants Source of Down Payment, Settlement Charges, and-or Subordinate Financing explain Equity On Pending Sale Estate will be held in: Fee Simple Leasehold show expiration date Borrower Ill.  BORROWER INFORMATION Co-Borrower Borrower’s Name include Jr. or Sr. if applicable Daniel M Johnson Co-Borrower’s Name include Jr. or Sr. if applicable Victoria Smith Johnson Social Security Number 434-06-8836 Home Phone incl. area code 337-998-1279  DOB mm-dd-yyyy | 04-12-1967 Yrs. School  14 ISocial Security Number 438-39-1513 Home Phone incl. area code  337-936-1975 DOB mm-dd-yyyy 09-15-1970 Yrs. School 14 [X] Married  Unmarried include single, | Dependents not listed by Co-Borrower divorced, widowed [X] married  Unmarried include single, divorced, widowed Dependents not listed by Borrower [ Separated no.1 ages 5 [ Separated no.o ages Present Address street, city, state, ZIP [¥]Own Rent No.Yrs. |PresentAddress street, city, state, ZIP [¥]Own [JRent No.Yrs. 2803 lkes Rd 18Y OM | 2803 Ikes Rd 18Y OM Kinder, LA 70648 Kinder, LA 70648 Mailing Address, if different from Present Address Mailing Address, if different from Present Address 2803 lkes Rd 2803 lkes Rd Kinder, LA 70648 Kinder, LA 70648 If residing at present address for less than two years, complete the following: Former Address street, city, state, ZIP [CJown [CJRent No.Yrs. |FormerAddress street, city, state, ZIP [Jown [CJRent No.Yrs. Borrower  IV. EMPLOYMENT INFORMATION Co-Borrower Name & Address of Employer Daniel Johnson Trucking, LLC  [¥] self Employed | years on this job 24Y OM | Name & Address of Employer [ self Employed | Yrs. on this job - o Yrs. employed in Yrs. employed in this line of this line of work-profession work-profession 30 Position-Title-Type of Business Sole Owner Business Phone incl. area code Position-Title-Type of Business Business Phone incl. area code If employed in current position for less than two years or if currently employed in more than one position, complete the following: Uniform Residential Loan Application Freddie Mac Form 65 7-05 rev.6-09 Ellie Mae, Inc. Page 1 of 5 03-19-20 Fannie Mae Form 1003 7-05 rev.6-09 GURLA09_S 0817 GURLA09S POD 18 07:59 AM PST"

# %%
entities = tagger.comprehend_entities(text_test)

# %%
entities
# Out:
# [{'entity_id': '6fb69815-ef00-4baf-b2a8-18c44c934285',
#   'text': 'Yellowstone',
#   'entity_score': 0.9902280569076538,
#   'entity_type': 'ORGANIZATION',
#   'string_index': 0},
#  {'entity_id': '6fb69815-ef00-4baf-b2a8-18c44c934285',
#   'text': 'Bank',
#   'entity_score': 0.9902280569076538,
#   'entity_type': 'ORGANIZATION',
#   'string_index': 12},
#  {'entity_id': 'e836bde1-c690-4eb8-87c1-0cc62a337ca8',
#   'text': 'LOAN',
#   'entity_score': 0.47207576036453247,
#   'entity_type': 'OTHER',
#   'string_index': 922},
#  {'entity_id': 'e836bde1-c690-4eb8-87c1-0cc62a337ca8',
#   'text': '#',
#   'entity_score': 0.47207576036453247,
#   'entity_type': 'OTHER',
#   'string_index': 927},
#  {'entity_id': 'ee7ece63-4f63-4a45-a6f4-9e59d83ffc0b',
#   'text': '1180303',
#   'entity_score': 0.8419227600097656,
#   'entity_type': 'OTHER',
#   'string_index': 930},
#  {'entity_id': 'e21b7ccf-e168-4c93-af6e-2624b9b5d5ff',
#   'text': 'Borrower',
#   'entity_score': 0.6179987788200378,
#   'entity_type': 'ORGANIZATION',
#   'string_index': 1058},
#  {'entity_id': 'e45f949e-4c4f-4798-afee-cfdff80d8a29',
#   'text': 'each',
#   'entity_score': 0.672205924987793,
#   'entity_type': 'QUANTITY',
#   'string_index': 1083},
#  {'entity_id': '4c63c232-b689-4f92-abcb-d98ce44b016a',
#   'text': 'M',
#   'entity_score': 0.9932633638381958,
#   'entity_type': 'PERSON',
#   'string_index': 1185},
#  {'entity_id': '4c63c232-b689-4f92-abcb-d98ce44b016a',
#   'text': 'Jolunson',
#   'entity_score': 0.9932633638381958,
#   'entity_type': 'PERSON',
#   'string_index': 1187},
#  {'entity_id': '768ace8a-af73-4bfe-aaef-188edbe4a4d2',
#   'text': '31912018',
#   'entity_score': 0.9047284722328186,
#   'entity_type': 'OTHER',
#   'string_index': 1197},
#  {'entity_id': 'e49f3af6-7d74-43a5-bb13-4c0610826b03',
#   'text': '09:23:25',
#   'entity_score': 0.9690229296684265,
#   'entity_type': 'DATE',
#   'string_index': 1208},
#  {'entity_id': 'e49f3af6-7d74-43a5-bb13-4c0610826b03',
#   'text': 'pDT',
#   'entity_score': 0.9690229296684265,
#   'entity_type': 'DATE',
#   'string_index': 1217},
#  {'entity_id': 'f52951fc-986f-4aad-9685-b38105122f56',
#   'text': 'VAddoria',
#   'entity_score': 0.8004038333892822,
#   'entity_type': 'PERSON',
#   'string_index': 1224},
#  {'entity_id': 'f52951fc-986f-4aad-9685-b38105122f56',
#   'text': 'Switly',
#   'entity_score': 0.8004038333892822,
#   'entity_type': 'PERSON',
#   'string_index': 1233},
#  {'entity_id': 'f52951fc-986f-4aad-9685-b38105122f56',
#   'text': 'Jelunson',
#   'entity_score': 0.8004038333892822,
#   'entity_type': 'PERSON',
#   'string_index': 1240},
#  {'entity_id': '9ea45341-caf5-413a-9103-caea906bb4ea',
#   'text': '3-19-2018',
#   'entity_score': 0.9929705262184143,
#   'entity_type': 'DATE',
#   'string_index': 1250},
#  {'entity_id': '2c04a2c9-3be0-4bfa-be88-5d21886decd6',
#   'text': '09:30:08',
#   'entity_score': 0.9482100605964661,
#   'entity_type': 'DATE',
#   'string_index': 1262},
#  {'entity_id': '2c04a2c9-3be0-4bfa-be88-5d21886decd6',
#   'text': 'PDT',
#   'entity_score': 0.9482100605964661,
#   'entity_type': 'DATE',
#   'string_index': 1271},
#  {'entity_id': '081fd489-5ba3-4298-b81c-5116eacd857c',
#   'text': 'USDA',
#   'entity_score': 0.8166912198066711,
#   'entity_type': 'ORGANIZATION',
#   'string_index': 1449},
#  {'entity_id': 'b94c30ed-8c0a-4af5-b72d-fdb0f98f5e38',
#   'text': '1180303',
#   'entity_score': 0.6549552083015442,
#   'entity_type': 'OTHER',
#   'string_index': 1476},
#  {'entity_id': 'e0ea558b-f801-443d-bc8c-780599c2f6aa',
#   'text': '$',
#   'entity_score': 0.9995477795600891,
#   'entity_type': 'QUANTITY',
#   'string_index': 1492},
#  {'entity_id': 'e0ea558b-f801-443d-bc8c-780599c2f6aa',
#   'text': '164,700.00',
#   'entity_score': 0.9995477795600891,
#   'entity_type': 'QUANTITY',
#   'string_index': 1494},
#  {'entity_id': '56b88e01-ba11-4481-b590-154ad67f0a70',
#   'text': '4375',
#   'entity_score': 0.9761762619018555,
#   'entity_type': 'QUANTITY',
#   'string_index': 1519},
#  {'entity_id': '56b88e01-ba11-4481-b590-154ad67f0a70',
#   'text': '%',
#   'entity_score': 0.9761762619018555,
#   'entity_type': 'QUANTITY',
#   'string_index': 1524},
#  {'entity_id': 'afe4ad60-aaf3-4a48-b0e8-baaa16416271',
#   'text': '360',
#   'entity_score': 0.5023699402809143,
#   'entity_type': 'QUANTITY',
#   'string_index': 1541},
#  {'entity_id': '412c882d-7125-4fbb-8fa4-7f3a364996ab',
#   'text': ',',
#   'entity_score': 0.5587416291236877,
#   'entity_type': 'LOCATION',
#   'string_index': 1699},
#  {'entity_id': '412c882d-7125-4fbb-8fa4-7f3a364996ab',
#   'text': 'city',
#   'entity_score': 0.5587416291236877,
#   'entity_type': 'LOCATION',
#   'string_index': 1701},
#  {'entity_id': '3354f54f-b22c-45c6-84c7-a58bfe112286',
#   'text': 'state,',
#   'entity_score': 0.5831610560417175,
#   'entity_type': 'LOCATION',
#   'string_index': 1707},
#  {'entity_id': '3354f54f-b22c-45c6-84c7-a58bfe112286',
#   'text': '&',
#   'entity_score': 0.5831610560417175,
#   'entity_type': 'LOCATION',
#   'string_index': 1714},
#  {'entity_id': '4a2f4a98-c383-479b-b6cb-a9447f0e103d',
#   'text': '29',
#   'entity_score': 0.7560200095176697,
#   'entity_type': 'LOCATION',
#   'string_index': 1721},
#  {'entity_id': 'c84803be-cc19-40bb-b9a8-03ef4f0764a9',
#   'text': 'Roberts,',
#   'entity_score': 0.8124059438705444,
#   'entity_type': 'LOCATION',
#   'string_index': 1737},
#  {'entity_id': 'c84803be-cc19-40bb-b9a8-03ef4f0764a9',
#   'text': 'MT',
#   'entity_score': 0.8124059438705444,
#   'entity_type': 'LOCATION',
#   'string_index': 1746},
#  {'entity_id': 'c84803be-cc19-40bb-b9a8-03ef4f0764a9',
#   'text': '59070',
#   'entity_score': 0.8124059438705444,
#   'entity_type': 'LOCATION',
#   'string_index': 1749},
#  {'entity_id': 'c84803be-cc19-40bb-b9a8-03ef4f0764a9',
#   'text': 'County',
#   'entity_score': 0.8124059438705444,
#   'entity_type': 'LOCATION',
#   'string_index': 1755},
#  {'entity_id': '092302da-e7f4-402f-9d5a-8e07b5f95fab',
#   'text': '2017',
#   'entity_score': 0.9925611615180969,
#   'entity_type': 'DATE',
#   'string_index': 1869},
#  {'entity_id': 'b9e82aeb-26e1-4c00-a00b-4611592bd900',
#   'text': 'Daniel',
#   'entity_score': 0.9997121691703796,
#   'entity_type': 'PERSON',
#   'string_index': 2446},
#  {'entity_id': 'b9e82aeb-26e1-4c00-a00b-4611592bd900',
#   'text': 'M',
#   'entity_score': 0.9997121691703796,
#   'entity_type': 'PERSON',
#   'string_index': 2453},
#  {'entity_id': 'b9e82aeb-26e1-4c00-a00b-4611592bd900',
#   'text': 'Johnson',
#   'entity_score': 0.9997121691703796,
#   'entity_type': 'PERSON',
#   'string_index': 2455},
#  {'entity_id': 'ba81b9f0-a1ad-4658-99a1-bb078fa315ef',
#   'text': 'Victoria',
#   'entity_score': 0.9838111996650696,
#   'entity_type': 'PERSON',
#   'string_index': 2464},
#  {'entity_id': 'ba81b9f0-a1ad-4658-99a1-bb078fa315ef',
#   'text': 'Smith',
#   'entity_score': 0.9838111996650696,
#   'entity_type': 'PERSON',
#   'string_index': 2473},
#  {'entity_id': 'ba81b9f0-a1ad-4658-99a1-bb078fa315ef',
#   'text': 'Johnson',
#   'entity_score': 0.9838111996650696,
#   'entity_type': 'PERSON',
#   'string_index': 2479},
#  {'entity_id': '8072b7b1-ee5f-45d9-8a19-4ae5f7a7cb4c',
#   'text': 'Borrower',
#   'entity_score': 0.6744263768196106,
#   'entity_type': 'ORGANIZATION',
#   'string_index': 2706},
#  {'entity_id': '71a07cb4-e898-46ee-9630-d6b40ee0482b',
#   'text': 'Borrower',
#   'entity_score': 0.3749220371246338,
#   'entity_type': 'ORGANIZATION',
#   'string_index': 2745},
#  {'entity_id': '4b1725c1-c294-4e4a-83c5-566a67b86264',
#   'text': 'Daniel',
#   'entity_score': 0.9979849457740784,
#   'entity_type': 'PERSON',
#   'string_index': 2803},
#  {'entity_id': '4b1725c1-c294-4e4a-83c5-566a67b86264',
#   'text': 'M',
#   'entity_score': 0.9979849457740784,
#   'entity_type': 'PERSON',
#   'string_index': 2810},
#  {'entity_id': '4b1725c1-c294-4e4a-83c5-566a67b86264',
#   'text': 'Johnson',
#   'entity_score': 0.9979849457740784,
#   'entity_type': 'PERSON',
#   'string_index': 2812},
#  {'entity_id': '599771fc-d880-4f6a-b29f-4ec91c3e8aa1',
#   'text': 'Victoria',
#   'entity_score': 0.9951210618019104,
#   'entity_type': 'PERSON',
#   'string_index': 2872},
#  {'entity_id': '599771fc-d880-4f6a-b29f-4ec91c3e8aa1',
#   'text': 'Smith',
#   'entity_score': 0.9951210618019104,
#   'entity_type': 'PERSON',
#   'string_index': 2881},
#  {'entity_id': '599771fc-d880-4f6a-b29f-4ec91c3e8aa1',
#   'text': 'Johnson',
#   'entity_score': 0.9951210618019104,
#   'entity_type': 'PERSON',
#   'string_index': 2887},
#  {'entity_id': '7d54260a-6565-40f9-8eab-d37554b4b63e',
#   'text': '434-06-8836',
#   'entity_score': 0.9735944867134094,
#   'entity_type': 'OTHER',
#   'string_index': 2918},
#  {'entity_id': '7c3b854f-0f37-455c-9cef-0463d7a9ffa2',
#   'text': '337-998-1279',
#   'entity_score': 0.9918112754821777,
#   'entity_type': 'OTHER',
#   'string_index': 2957},
#  {'entity_id': '52028d98-7ac6-44e0-a4ae-5248b779cb07',
#   'text': '04-12-1967',
#   'entity_score': 0.9959851503372192,
#   'entity_type': 'DATE',
#   'string_index': 2988},
#  {'entity_id': '0c4a6fa4-6e0f-4713-866e-d1358b3d56de',
#   'text': '438-39-1513',
#   'entity_score': 0.9732532501220703,
#   'entity_type': 'OTHER',
#   'string_index': 3039},
#  {'entity_id': 'e6f4a817-bd8a-4d65-9bc8-20ab1636ad06',
#   'text': '337-936-1975',
#   'entity_score': 0.9087522029876709,
#   'entity_type': 'OTHER',
#   'string_index': 3079},
#  {'entity_id': '3cd95880-3f6c-4592-9527-9bbd227bd2c0',
#   'text': '09-15-1970',
#   'entity_score': 0.9890129566192627,
#   'entity_type': 'DATE',
#   'string_index': 3107},
#  {'entity_id': '854e92f5-ac18-4570-ba88-1a3e4c31b7ae',
#   'text': 'single',
#   'entity_score': 0.528148353099823,
#   'entity_type': 'QUANTITY',
#   'string_index': 3164},
#  {'entity_id': 'c1931dc6-8dc6-46ed-9a67-d10444a0be6b',
#   'text': 'single',
#   'entity_score': 0.5291399955749512,
#   'entity_type': 'QUANTITY',
#   'string_index': 3260},
#  {'entity_id': '07b97d32-fa91-45a5-b14e-6eb04f2be35f',
#   'text': '5',
#   'entity_score': 0.5446134209632874,
#   'entity_type': 'QUANTITY',
#   'string_index': 3342},
#  {'entity_id': 'a55f778b-4ef6-4edb-a1c2-252ba77dfb95',
#   'text': 'street',
#   'entity_score': 0.7064993381500244,
#   'entity_type': 'LOCATION',
#   'string_index': 3443},
#  {'entity_id': 'ed5cca30-fdaa-454e-9c7b-4c49423fa333',
#   'text': 'JRent',
#   'entity_score': 0.4398095905780792,
#   'entity_type': 'LOCATION',
#   'string_index': 3476},
#  {'entity_id': 'd78ad98e-b5b1-409a-bf1c-65c67952b87d',
#   'text': '2803',
#   'entity_score': 0.5864965915679932,
#   'entity_type': 'QUANTITY',
#   'string_index': 3490},
#  {'entity_id': 'b4851203-8e78-43ef-b7ba-427c101880fa',
#   'text': 'Rd',
#   'entity_score': 0.619084894657135,
#   'entity_type': 'LOCATION',
#   'string_index': 3500},
#  {'entity_id': 'b4851203-8e78-43ef-b7ba-427c101880fa',
#   'text': '18Y',
#   'entity_score': 0.619084894657135,
#   'entity_type': 'LOCATION',
#   'string_index': 3503},
#  {'entity_id': '589f1f7a-9aff-4204-9a70-96b71ca7b864',
#   'text': '2803',
#   'entity_score': 0.8944215178489685,
#   'entity_type': 'LOCATION',
#   'string_index': 3512},
#  {'entity_id': '589f1f7a-9aff-4204-9a70-96b71ca7b864',
#   'text': 'Ikes',
#   'entity_score': 0.8944215178489685,
#   'entity_type': 'LOCATION',
#   'string_index': 3517},
#  {'entity_id': '589f1f7a-9aff-4204-9a70-96b71ca7b864',
#   'text': 'Rd',
#   'entity_score': 0.8944215178489685,
#   'entity_type': 'LOCATION',
#   'string_index': 3522},
#  {'entity_id': '589f1f7a-9aff-4204-9a70-96b71ca7b864',
#   'text': '18Y',
#   'entity_score': 0.8944215178489685,
#   'entity_type': 'LOCATION',
#   'string_index': 3525},
#  {'entity_id': '589f1f7a-9aff-4204-9a70-96b71ca7b864',
#   'text': 'OM',
#   'entity_score': 0.8944215178489685,
#   'entity_type': 'LOCATION',
#   'string_index': 3529},
#  {'entity_id': '589f1f7a-9aff-4204-9a70-96b71ca7b864',
#   'text': 'Kinder',
#   'entity_score': 0.8944215178489685,
#   'entity_type': 'LOCATION',
#   'string_index': 3532},
#  {'entity_id': '5099a367-69d6-4bdb-a4a4-d9d89f167a1b',
#   'text': 'LA',
#   'entity_score': 0.9463868141174316,
#   'entity_type': 'LOCATION',
#   'string_index': 3540},
#  {'entity_id': '5099a367-69d6-4bdb-a4a4-d9d89f167a1b',
#   'text': '70648',
#   'entity_score': 0.9463868141174316,
#   'entity_type': 'LOCATION',
#   'string_index': 3543},
#  {'entity_id': '5099a367-69d6-4bdb-a4a4-d9d89f167a1b',
#   'text': 'Kinder,',
#   'entity_score': 0.9463868141174316,
#   'entity_type': 'LOCATION',
#   'string_index': 3549},
#  {'entity_id': '5099a367-69d6-4bdb-a4a4-d9d89f167a1b',
#   'text': 'LA',
#   'entity_score': 0.9463868141174316,
#   'entity_type': 'LOCATION',
#   'string_index': 3557},
#  {'entity_id': '5099a367-69d6-4bdb-a4a4-d9d89f167a1b',
#   'text': '70648',
#   'entity_score': 0.9463868141174316,
#   'entity_type': 'LOCATION',
#   'string_index': 3560},
#  {'entity_id': 'e6a32229-0252-488f-b50d-2f860383b66d',
#   'text': '2803',
#   'entity_score': 0.5028656721115112,
#   'entity_type': 'QUANTITY',
#   'string_index': 3668},
#  {'entity_id': '8d670bb8-6cc6-427f-ac27-57fe37f87ead',
#   'text': 'lkes',
#   'entity_score': 0.760083019733429,
#   'entity_type': 'LOCATION',
#   'string_index': 3673},
#  {'entity_id': '8d670bb8-6cc6-427f-ac27-57fe37f87ead',
#   'text': 'Rd',
#   'entity_score': 0.760083019733429,
#   'entity_type': 'LOCATION',
#   'string_index': 3678},
#  {'entity_id': '8d670bb8-6cc6-427f-ac27-57fe37f87ead',
#   'text': '2803',
#   'entity_score': 0.760083019733429,
#   'entity_type': 'LOCATION',
#   'string_index': 3681},
#  {'entity_id': '8d670bb8-6cc6-427f-ac27-57fe37f87ead',
#   'text': 'lkes',
#   'entity_score': 0.760083019733429,
#   'entity_type': 'LOCATION',
#   'string_index': 3686},
#  {'entity_id': '8d670bb8-6cc6-427f-ac27-57fe37f87ead',
#   'text': 'Rd',
#   'entity_score': 0.760083019733429,
#   'entity_type': 'LOCATION',
#   'string_index': 3691},
#  {'entity_id': '8d670bb8-6cc6-427f-ac27-57fe37f87ead',
#   'text': 'Kinder,',
#   'entity_score': 0.760083019733429,
#   'entity_type': 'LOCATION',
#   'string_index': 3694},
#  {'entity_id': '8d670bb8-6cc6-427f-ac27-57fe37f87ead',
#   'text': 'LA',
#   'entity_score': 0.760083019733429,
#   'entity_type': 'LOCATION',
#   'string_index': 3702},
#  {'entity_id': '8d670bb8-6cc6-427f-ac27-57fe37f87ead',
#   'text': '70648',
#   'entity_score': 0.760083019733429,
#   'entity_type': 'LOCATION',
#   'string_index': 3705},
#  {'entity_id': '8d670bb8-6cc6-427f-ac27-57fe37f87ead',
#   'text': 'Kinder,',
#   'entity_score': 0.760083019733429,
#   'entity_type': 'LOCATION',
#   'string_index': 3711},
#  {'entity_id': '8d670bb8-6cc6-427f-ac27-57fe37f87ead',
#   'text': 'LA',
#   'entity_score': 0.760083019733429,
#   'entity_type': 'LOCATION',
#   'string_index': 3719},
#  {'entity_id': '8d670bb8-6cc6-427f-ac27-57fe37f87ead',
#   'text': '70648',
#   'entity_score': 0.760083019733429,
#   'entity_type': 'LOCATION',
#   'string_index': 3722},
#  {'entity_id': 'f64c090c-cd66-4bed-974d-404f7ea9e616',
#   'text': 'less',
#   'entity_score': 0.9246681928634644,
#   'entity_type': 'QUANTITY',
#   'string_index': 3763},
#  {'entity_id': 'f64c090c-cd66-4bed-974d-404f7ea9e616',
#   'text': 'than',
#   'entity_score': 0.9246681928634644,
#   'entity_type': 'QUANTITY',
#   'string_index': 3768},
#  {'entity_id': 'f64c090c-cd66-4bed-974d-404f7ea9e616',
#   'text': 'two',
#   'entity_score': 0.9246681928634644,
#   'entity_type': 'QUANTITY',
#   'string_index': 3773},
#  {'entity_id': 'f64c090c-cd66-4bed-974d-404f7ea9e616',
#   'text': 'years',
#   'entity_score': 0.9246681928634644,
#   'entity_type': 'QUANTITY',
#   'string_index': 3777},
#  {'entity_id': 'b7e31dab-f827-4276-9910-c9b3edb2b2ba',
#   'text': 'city',
#   'entity_score': 0.6843047142028809,
#   'entity_type': 'LOCATION',
#   'string_index': 3831},
#  {'entity_id': '4c3b676d-0579-4c1c-9da5-8e97719983ff',
#   'text': 'state',
#   'entity_score': 0.729198157787323,
#   'entity_type': 'LOCATION',
#   'string_index': 3837},
#  {'entity_id': '4795d9e9-3f59-47c3-9b69-5ba808d2d205',
#   'text': 'street',
#   'entity_score': 0.9545425772666931,
#   'entity_type': 'LOCATION',
#   'string_index': 3886},
#  {'entity_id': '824559da-b7f3-4e32-8c8a-189312e6f437',
#   'text': 'CJRent',
#   'entity_score': 0.7443932890892029,
#   'entity_type': 'ORGANIZATION',
#   'string_index': 3918},
#  {'entity_id': '6a87af59-9c34-40a1-bb4c-8b21f8fbaae2',
#   'text': 'INFORMATION',
#   'entity_score': 0.5629963278770447,
#   'entity_type': 'ORGANIZATION',
#   'string_index': 3958},
#  {'entity_id': 'b28549b0-28e0-4856-8957-0071132d14bc',
#   'text': 'Daniel',
#   'entity_score': 0.95353764295578,
#   'entity_type': 'ORGANIZATION',
#   'string_index': 4009},
#  {'entity_id': 'b28549b0-28e0-4856-8957-0071132d14bc',
#   'text': 'Johnson',
#   'entity_score': 0.95353764295578,
#   'entity_type': 'ORGANIZATION',
#   'string_index': 4016},
#  {'entity_id': 'b28549b0-28e0-4856-8957-0071132d14bc',
#   'text': 'Trucking,',
#   'entity_score': 0.95353764295578,
#   'entity_type': 'ORGANIZATION',
#   'string_index': 4024},
#  {'entity_id': 'b28549b0-28e0-4856-8957-0071132d14bc',
#   'text': 'LLC',
#   'entity_score': 0.95353764295578,
#   'entity_type': 'ORGANIZATION',
#   'string_index': 4034},
#  {'entity_id': '7d1896e3-4d2e-4a8d-acb9-5b1abfb232f1',
#   'text': '24Y',
#   'entity_score': 0.6524632573127747,
#   'entity_type': 'QUANTITY',
#   'string_index': 4077},
#  {'entity_id': '25f84529-7c85-4fdc-bc55-ea1221f37ea9',
#   'text': 'Yrs',
#   'entity_score': 0.4587084949016571,
#   'entity_type': 'ORGANIZATION',
#   'string_index': 4131},
#  {'entity_id': '09937de2-dc9e-42ed-9a62-cf921e65f578',
#   'text': 'Yrs',
#   'entity_score': 0.5073912739753723,
#   'entity_type': 'ORGANIZATION',
#   'string_index': 4152},
#  {'entity_id': 'e689c006-590e-412e-b308-009c1d6df49e',
#   'text': 'Yrs',
#   'entity_score': 0.5665810704231262,
#   'entity_type': 'ORGANIZATION',
#   'string_index': 4169},
#  {'entity_id': '72d90c44-a565-46ea-967e-568c445f44bd',
#   'text': '30',
#   'entity_score': 0.96628338098526,
#   'entity_type': 'QUANTITY',
#   'string_index': 4244},
#  {'entity_id': '72d90c44-a565-46ea-967e-568c445f44bd',
#   'text': 'Position',
#   'entity_score': 0.96628338098526,
#   'entity_type': 'QUANTITY',
#   'string_index': 4247},
#  {'entity_id': '3afc768d-46fa-4ffb-8af2-9406e2d79018',
#   'text': 'less',
#   'entity_score': 0.9807624816894531,
#   'entity_type': 'QUANTITY',
#   'string_index': 4420},
#  {'entity_id': '3afc768d-46fa-4ffb-8af2-9406e2d79018',
#   'text': 'than',
#   'entity_score': 0.9807624816894531,
#   'entity_type': 'QUANTITY',
#   'string_index': 4425},
#  {'entity_id': '3afc768d-46fa-4ffb-8af2-9406e2d79018',
#   'text': 'two',
#   'entity_score': 0.9807624816894531,
#   'entity_type': 'QUANTITY',
#   'string_index': 4430},
#  {'entity_id': '3afc768d-46fa-4ffb-8af2-9406e2d79018',
#   'text': 'years',
#   'entity_score': 0.9807624816894531,
#   'entity_type': 'QUANTITY',
#   'string_index': 4434},
#  {'entity_id': '6a5a0f09-172b-49ee-97f0-bd82ba01b16a',
#   'text': 'more',
#   'entity_score': 0.9394159317016602,
#   'entity_type': 'QUANTITY',
#   'string_index': 4468},
#  {'entity_id': '6a5a0f09-172b-49ee-97f0-bd82ba01b16a',
#   'text': 'than',
#   'entity_score': 0.9394159317016602,
#   'entity_type': 'QUANTITY',
#   'string_index': 4473},
#  {'entity_id': '6a5a0f09-172b-49ee-97f0-bd82ba01b16a',
#   'text': 'one',
#   'entity_score': 0.9394159317016602,
#   'entity_type': 'QUANTITY',
#   'string_index': 4478},
#  {'entity_id': '6a5a0f09-172b-49ee-97f0-bd82ba01b16a',
#   'text': 'position',
#   'entity_score': 0.9394159317016602,
#   'entity_type': 'QUANTITY',
#   'string_index': 4482},
#  {'entity_id': '44115f7f-0c37-4599-9b73-df1970be9ac0',
#   'text': 'Freddie',
#   'entity_score': 0.32693541049957275,
#   'entity_type': 'ORGANIZATION',
#   'string_index': 4553},
#  {'entity_id': 'c0d26ea0-ca83-4523-8178-75412955772c',
#   'text': 'Mac',
#   'entity_score': 0.8219207525253296,
#   'entity_type': 'PERSON',
#   'string_index': 4561},
#  {'entity_id': '3d50cac3-536a-4c0c-87c2-44dd0cf74810',
#   'text': 'rev.6-09',
#   'entity_score': 0.5483368635177612,
#   'entity_type': 'DATE',
#   'string_index': 4578},
#  {'entity_id': 'fcd8b25d-e048-4aba-afbf-b1c4675493fd',
#   'text': 'Ellie',
#   'entity_score': 0.8950033187866211,
#   'entity_type': 'ORGANIZATION',
#   'string_index': 4587},
#  {'entity_id': 'fcd8b25d-e048-4aba-afbf-b1c4675493fd',
#   'text': 'Mae,',
#   'entity_score': 0.8950033187866211,
#   'entity_type': 'ORGANIZATION',
#   'string_index': 4593},
#  {'entity_id': 'd8790e08-a030-4527-8732-beb3fdd32ac8',
#   'text': '1',
#   'entity_score': 0.43381693959236145,
#   'entity_type': 'QUANTITY',
#   'string_index': 4608},
#  {'entity_id': 'c22d5dd3-6bc2-49f7-bf3d-e5e59ba1f876',
#   'text': '03-19-20',
#   'entity_score': 0.6088290810585022,
#   'entity_type': 'DATE',
#   'string_index': 4615},
#  {'entity_id': '0cc0a554-6ea4-495d-82ce-7618aa37e9f9',
#   'text': 'Fannie',
#   'entity_score': 0.7734054327011108,
#   'entity_type': 'PERSON',
#   'string_index': 4624},
#  {'entity_id': '0cc0a554-6ea4-495d-82ce-7618aa37e9f9',
#   'text': 'Mae',
#   'entity_score': 0.7734054327011108,
#   'entity_type': 'PERSON',
#   'string_index': 4631},
#  {'entity_id': 'eaeb4c65-43df-4e4c-a8d3-4bbe23425957',
#   'text': 'Form',
#   'entity_score': 0.4726429581642151,
#   'entity_type': 'OTHER',
#   'string_index': 4635},
#  {'entity_id': '78f73521-981f-43f4-a7f0-b57ba7ee2130',
#   'text': 'rev.6-09',
#   'entity_score': 0.6666686534881592,
#   'entity_type': 'DATE',
#   'string_index': 4650},
#  {'entity_id': '2f63846d-5699-4507-8531-07f3271699f6',
#   'text': '0817',
#   'entity_score': 0.31434160470962524,
#   'entity_type': 'OTHER',
#   'string_index': 4669},
#  {'entity_id': '4d86b219-ca58-4733-b3f3-cdd39521bcaa',
#   'text': 'GURLA09S',
#   'entity_score': 0.34982815384864807,
#   'entity_type': 'PERSON',
#   'string_index': 4674},
#  {'entity_id': '25ad2b52-03ba-4cd4-95e0-f0dcd3949de3',
#   'text': '18',
#   'entity_score': 0.9200587272644043,
#   'entity_type': 'DATE',
#   'string_index': 4687},
#  {'entity_id': '25ad2b52-03ba-4cd4-95e0-f0dcd3949de3',
#   'text': '07:59',
#   'entity_score': 0.9200587272644043,
#   'entity_type': 'DATE',
#   'string_index': 4690},
#  {'entity_id': '25ad2b52-03ba-4cd4-95e0-f0dcd3949de3',
#   'text': 'AM',
#   'entity_score': 0.9200587272644043,
#   'entity_type': 'DATE',
#   'string_index': 4696},
#  {'entity_id': '25ad2b52-03ba-4cd4-95e0-f0dcd3949de3',
#   'text': 'PST',
#   'entity_score': 0.9200587272644043,
#   'entity_type': 'DATE',
#   'string_index': 4699}]

# %%
df = pd.read_csv("1003_rid_new.csv",names=["rid"])

# %%
temp = df.head(1)

# %%
temp[f"{exp_id}_path"] = temp.apply(lambda row: memorize_results_update_inplace(row["rid"]), axis = 1)

# %%
aws_json = aggregate_formatted_entities("bd5ff6ce-f0cf-4b16-8e75-5a25b09b6ad6")
# Out:
# Yellowstone Bank Uniform Residential Loan Application This application is designed to be completed by the applicants with the Lender’s assistance. Applicants should complete this form as “Borrower” or “Co-Borrower,” as applicable. Co-Borrower information must also be provided and the appropriate box checked when the income or assets of a person other than the Borrower including the Borrower’s spouse will be used as a basis for loan qualification or the income or assets of the Borrower’s spouse or other person who has community property rights pursuant to state law will not be used as a basis for loan qualification, but his or her liabilities must be considered because the spouse or other person has community property rights pursuant to applicable law and Borrower resides in a community property state, the security property is located in a community property state, or the Borrower is relying on other property LOAN #: 1180303 located in a community property state as a basis for repayment of the loan. If this is an application for joint credit, Borrower and Co-Borrower each agree that we intend to apg_ly for joint credit sign below: DocuSigned by: DocuSigned by —thu'tl M Jolunson. 31912018 | 09:23:25 pDT | \VAddoria Switly Jelunson, 3-19-2018 | 09:30:08 PDT Borfgeperes7c4400 Co-BbFewER: | I. TYPE OF MORTGAGE AND TERMS OF LOAN Mortgage [_JVA [¥]Conventional Other explain: Agency Case Number Lender Case Number Applied for: [_JFHA USDA-Rural Housing Service 1180303 Amount Interest Rate No. of Months | Amortization [X] Fixed Rate [ ] Other explain: $ 164,700.00 4375 % | 360 Type: CaPm CJARM type: I Il. PROPERTY INFORMATION AND PURPOSE OF LOAN Subject Property Address street, city, state, & ZIP No. of Units 29 Laptop Loop, Roberts, MT 59070 County: Carbon 1 Legal Description of Subject Property attach description if necessary Year Built 2017 Purpose of Loan [X] Purchase ] Construction [ other explain: Property will be: [1 Refinance  Construction-Permanent Primary  Secondary  Investment Residence Residence Complete this line if construction or construction-permanent loan. Year Lot Acquired | Original Cost Amount Existing Liens | a Present Value of Lot | b Cost of Improvements | Total a + b $ $ $ $ $ Complete this line if this is a refinance loan. Year Acquired Original Cost Amount Existing Liens | Purpose of Refinance Describe Improvements [ made [ to be made $ $ Cost: $ Title will be held in what Names Daniel M Johnson, Victoria Smith Johnson Manner in which Title will be held Joint tenants Source of Down Payment, Settlement Charges, and-or Subordinate Financing explain Equity On Pending Sale Estate will be held in: Fee Simple Leasehold show expiration date Borrower Ill. BORROWER INFORMATION Co-Borrower Borrower’s Name include Jr. or Sr. if applicable Daniel M Johnson Co-Borrower’s Name include Jr. or Sr. if applicable Victoria Smith Johnson Social Security Number Home Phone incl. area code 434-06-8836 337-998-1279 DOB mm-dd-yyyy | Yrs. School 04-12-1967 14 ISocial Security Number Home Phone incl. area code 438-39-1513 337-936-1975 DOB mm-dd-yyyy 09-15-1970 Yrs. School 14 [X] Married  Unmarried include single, | Dependents not listed by Co-Borrower divorced, widowed [X] married  Unmarried include single, divorced, widowed Dependents not listed by Borrower [ Separated no.1 ages 5 [ Separated no.o ages Present Address street, city, state, ZIP [¥]Own Rent No.Yrs. |PresentAddress street, city, state, ZIP [¥]Own [JRent No.Yrs. 2803 lkes Rd 18Y OM | 2803 Ikes Rd 18Y OM Kinder, LA 70648 Kinder, LA 70648 Mailing Address, if different from Present Address Mailing Address, if different from Present Address 2803 lkes Rd 2803 lkes Rd Kinder, LA 70648 Kinder, LA 70648 If residing at present address for less than two years, complete the following: Former Address street, city, state, ZIP [CJown [CJRent No.Yrs. |FormerAddress street, city, state, ZIP [Jown [CJRent No.Yrs. Borrower IV. EMPLOYMENT INFORMATION Co-Borrower Name & Address of Employer [¥]  ...
# failed to format Unknown string format: 09:23:25 pDT
# failed to format time data '09:23:25 pDT' does not match format '%m/%d/%Y'
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/dateutil/parser/_parser.py:1218: UnknownTimezoneWarning: tzname PDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# failed to format Unknown string format: 7/05 rev.6/09
# failed to format time data '7/05 rev.6/09' does not match format '%m/%d/%Y'
# Match:  434-06-8836
# Match:  438-39-1513
# successfully tagged entities: {'entities': [{'entity_id': '68a0944c-5561-4923-bab9-b302cb3e4563', 'text': 'Yellowstone', 'entity_score': 0.9902280569076538, 'entity_type': 'ORGANIZATION', 'word_id': 'word_1_1', 'bounding_box': [1139, 84, 1329, 109], 'confidence': 0.91}, {'entity_id': '68a0944c-5561-4923-bab9-b302cb3e4563', 'text': 'Bank', 'entity_score': 0.9902280569076538, 'entity_type': 'ORGANIZATION', 'word_id': 'word_1_2', 'bounding_box': [1342, 84, 1420, 109], 'confidence': 0.92}, {'entity_id': '3cdc3b5b-ac07-4a29-bc11-133dcb8ec39e', 'text': 'LOAN', 'entity_score': 0.47207576036453247, 'entity_type': 'OTHER', 'word_id': 'word_1_147', 'bounding_box': [2135, 124, 2223, 149], 'confidence': 0.91}, {'entity_id': '3cdc3b5b-ac07-4a29-bc11-133dcb8ec39e', 'text': '#:', 'entity_score': 0.47207576036453247, 'entity_type': 'OTHER', 'word_id': 'word_1_148', 'bounding_box': [2234, 124, 2261, 149], 'confidence': 0.91}, {'entity_id': '9e87fdf4-ebf9-410a-955a-a38de7b4e237', 'text': '1180303', 'entity_score': 0.8419227600097656, 'entity_type': 'OTHER', 'word_id': 'word_1_149', 'bounding_box': [2275, 124, 2401, 149], 'confidence': 0.96}, {'entity_id': '97ab0863-5e6c-451c-b880-77e7444d1cac', 'text': 'Borrower', 'entity_score': 0.7616485357284546, 'entity_type': 'ORGANIZATION', 'word_id': 'word_1_173', 'bounding_box': [639, 443, 754, 466], 'confidence': 0.92}, {'entity_id': '98a91d19-914b-4cf6-b8c4-d3af51fb90b7', 'text': 'Co-Borrower', 'entity_score': 0.5539014339447021, 'entity_type': 'ORGANIZATION', 'word_id': 'word_1_175', 'bounding_box': [820, 443, 983, 466], 'confidence': 0.92}, {'entity_id': 'a6c1c8fe-e3a7-4234-afe3-eb3e549809c0', 'text': 'each', 'entity_score': 0.6596502065658569, 'entity_type': 'QUANTITY', 'word_id': 'word_1_176', 'bounding_box': [991, 444, 1052, 466], 'confidence': 0.92}, {'entity_id': 'cff81eb9-4286-48e9-8147-01ef276b043b', 'text': 'M', 'entity_score': 0.992927610874176, 'entity_type': 'PERSON', 'word_id': 'word_1_196', 'bounding_box': [297, 495, 332, 529], 'confidence': 0.74}, {'entity_id': 'cff81eb9-4286-48e9-8147-01ef276b043b', 'text': 'Jolunson.', 'entity_score': 0.992927610874176, 'entity_type': 'PERSON', 'word_id': 'word_1_197', 'bounding_box': [349, 491, 479, 537], 'confidence': 0.57}, {'entity_id': '1791400d-bcbf-4710-94dd-f97724cb056d', 'text': '31912018', 'entity_score': 0.9042136669158936, 'entity_type': 'OTHER', 'word_id': 'word_1_198', 'bounding_box': [905, 517, 1037, 540], 'confidence': 0.45}, {'entity_id': 'ad82beb3-9711-4314-892d-2895028e28af', 'text': '09:23:25', 'entity_score': 0.9613386988639832, 'entity_type': 'DATE', 'word_id': 'word_1_200', 'bounding_box': [1064, 517, 1182, 540], 'confidence': 0.73}, {'entity_id': 'ad82beb3-9711-4314-892d-2895028e28af', 'text': 'pDT', 'entity_score': 0.9613386988639832, 'entity_type': 'DATE', 'word_id': 'word_1_201', 'bounding_box': [1193, 517, 1251, 540], 'confidence': 0.0}, {'entity_id': '193aff0b-5996-4708-aca0-625d799ae62a', 'text': 'Switly', 'entity_score': 0.8062213063240051, 'entity_type': 'PERSON', 'word_id': 'word_1_204', 'bounding_box': [1458, 491, 1544, 537], 'confidence': 0.13}, {'entity_id': '193aff0b-5996-4708-aca0-625d799ae62a', 'text': 'Jelunson,', 'entity_score': 0.8062213063240051, 'entity_type': 'PERSON', 'word_id': 'word_1_205', 'bounding_box': [1560, 491, 1690, 538], 'confidence': 0.25}, {'entity_id': 'a775cf69-9074-4655-ab9a-a78f191d6e14', 'text': '3/19/2018', 'entity_score': 0.9924353957176208, 'entity_type': 'DATE', 'word_id': 'word_1_206', 'bounding_box': [2056, 517, 2187, 540], 'confidence': 0.89}, {'entity_id': '2fb2b34e-662c-450d-bcec-ceacba6f4a5b', 'text': '09:30:08', 'entity_score': 0.9322439432144165, 'entity_type': 'DATE', 'word_id': 'word_1_208', 'bounding_box': [2214, 517, 2332, 540], 'confidence': 0.92}, {'entity_id': '2fb2b34e-662c-450d-bcec-ceacba6f4a5b', 'text': 'PDT', 'entity_score': 0.9322439432144165, 'entity_type': 'DATE', 'word_id': 'word_1_209', 'bounding_box': [2343, 517, 2401, 540], 'confidence': 0.92}, {'entity_id' ...
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/dateutil/parser/_parser.py:1218: UnknownTimezoneWarning: tzname PST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# Borrower Yellowstone Bank IV. EMPLOYMENT INFORMATION LOAN #: 1180303 Co-Borrower Name & Address of Employer [ Self Employed | Dates from—to Monthly Income $ Name & Address of Employer [ self Employed | Dates from—to Monthly Income $ Position-Title-Type of Business Business Phone incl. area code Position-Title-Type of Business Business Phone incl. area code Name & Address of Employer ] Self Employed | Dates from—to Monthly Income $ Name & Address of Employer [ Self Employed | Dates from—to Monthly Income $ Position-Title-Type of Business Business Phone incl. area code | Position-Title-Type of Business Business Phone incl. area code V. MONTHLY INCOME AND COMBINED HOUSING EXPENSE INFORMATION | Gross Combined Monthly Monthly Income Borrower Co-Borrower Total Housing Expense Present Proposed Base Empl. Income* | $ 3,727.66 | $ 3,727.66 | Rent $ Overtime First Mortgage P&l 700.00 | $ 822.32 Bonuses Other Financing P&I Commissions Hazard Insurance na 50.08 Dividends-Interest Real Estate Taxes na 200.00 Net Rental Income Mortgage Insurance Other before completing, Homeowner Assn. Dues see the notice in “describe other income,” below Other: 0.00 Total $ 3,727.66 | $ $ 3,727.66 | Total $ 700.00| S 1,072.40 * Self Employed Borrowers may be required to provide additional documentation such as tax returns and financial statements. Describe Other Income Notice: Alimony, child support, or separate maintenance income need not be revealed if the Borrower B or Co-Borrower C does not choose to have it considered for repaying this loan. B-C Monthly Amount $ VI. ASSETS AND LIABILITIES This Statement and any applicable supporting schedules may be completed jointly by both married and unmarried Co-Borrowers if their assets and liabilities are sufficiently joined so that the Statement can be meaningfully and fairly presented on a combined basis; otherwise, separate Statements and Schedules are required. If the Co-Borrower section was completed about a non-applicant spouse or other person, this Statement and supporting schedules must be completed about that spouse or other person also. Completed x] Jointly ] Not Jointly ASSETS Description Cash or Market Value Cash deposit toward purchase held by: Liabilities and Pledged Assets. List the creditor’'s name, address, and account number for all outstanding debts, including automobile loans, revolving charge accounts, real estate loans, alimony, child support, stock pledges, etc. Use continuation sheet, if necessary. Indicate by * those liabilities, which will be satisfied upon sale of real estate owned or upon refinancing of the subject property. Borrower B, Co-Borrower C, Joint J Monthly Payment & LIABILITIES Months Left to Pay Unpaid Balance List checking and savings accounts below Name and address of Company B $ Payment-Months Name and address of Bank, S&L, or Credit Union CITIMORTGAGE INC *638.00 *59,245.00 Net equity 158 Acct. no. 1124249933 Acct. no. $ 85,000.00| Name and address of Company B $ Payment-Months Name and address of Bank, S&L, or Credit Union US BANK 224-38 17,283.00 o Bank PO BOX 2188 inder, OSHKOSH, W1 54903 Acct.no. 514001353 Acct. no. 50004342 $ 1,200.00| Name and address of Company J $ Payment-Months $ Name and address of Bank, S&L, or Credit Union STATE FARM BANK, F.S.B *343.00 *10,437.00 JD Bank MUST BE ON ARC LETTERHEAD ¥ Kinder, LA Acct.no. 854532880700001 Uniform Residential Loan Application Freddie Mac Form 65 7-05 rev.6-09 Ellie Mae, Inc. Daniel M Johnson Page 2 of 5 o Fannie Mae Form 1003 7-05 rev.6-09 GURLA09_S 0817 GURLA09S POD 03-19-2018 07:59 AM PST
# failed to format Unknown string format: 7/05 rev.6/09
# failed to format time data '7/05 rev.6/09' does not match format '%m/%d/%Y'
# failed to format Unknown string format: 7/05 rev.6/09
# failed to format time data '7/05 rev.6/09' does not match format '%m/%d/%Y'
# successfully tagged entities: {'entities': [{'entity_id': 'ef2fb23a-711b-4896-9dac-a5af3fa400b1', 'text': 'Borrower', 'entity_score': 0.8734652400016785, 'entity_type': 'ORGANIZATION', 'word_id': 'word_2_1', 'bounding_box': [519, 166, 663, 191], 'confidence': 0.91}, {'entity_id': 'ef2fb23a-711b-4896-9dac-a5af3fa400b1', 'text': 'Yellowstone', 'entity_score': 0.8734652400016785, 'entity_type': 'ORGANIZATION', 'word_id': 'word_2_2', 'bounding_box': [1139, 84, 1329, 109], 'confidence': 0.91}, {'entity_id': 'ef2fb23a-711b-4896-9dac-a5af3fa400b1', 'text': 'Bank', 'entity_score': 0.8734652400016785, 'entity_type': 'ORGANIZATION', 'word_id': 'word_2_3', 'bounding_box': [1342, 84, 1420, 109], 'confidence': 0.92}, {'entity_id': 'ef2fb23a-711b-4896-9dac-a5af3fa400b1', 'text': 'IV.', 'entity_score': 0.8734652400016785, 'entity_type': 'ORGANIZATION', 'word_id': 'word_2_4', 'bounding_box': [1020, 166, 1054, 190], 'confidence': 0.89}, {'entity_id': 'a1d2fc98-c6b0-460c-ba62-df12dae515d1', 'text': '1180303', 'entity_score': 0.5023931860923767, 'entity_type': 'LOCATION', 'word_id': 'word_2_9', 'bounding_box': [2275, 124, 2401, 149], 'confidence': 0.96}, {'entity_id': 'c56353f4-5d06-401f-a79a-a8bfd2ea4a04', 'text': '$', 'entity_score': 0.9998103380203247, 'entity_type': 'QUANTITY', 'word_id': 'word_2_155', 'bounding_box': [466, 1015, 480, 1041], 'confidence': 0.74}, {'entity_id': 'c56353f4-5d06-401f-a79a-a8bfd2ea4a04', 'text': '3,727.66', 'entity_score': 0.9998103380203247, 'entity_type': 'QUANTITY', 'word_id': 'word_2_156', 'bounding_box': [653, 1012, 765, 1038], 'confidence': 0.9}, {'entity_id': '45251a5e-1480-4571-99ae-0efd2709d77a', 'text': '$', 'entity_score': 0.9989977478981018, 'entity_type': 'QUANTITY', 'word_id': 'word_2_158', 'bounding_box': [1115, 1015, 1130, 1041], 'confidence': 0.87}, {'entity_id': '45251a5e-1480-4571-99ae-0efd2709d77a', 'text': '3,727.66', 'entity_score': 0.9989977478981018, 'entity_type': 'QUANTITY', 'word_id': 'word_2_159', 'bounding_box': [1303, 1012, 1415, 1038], 'confidence': 0.92}, {'entity_id': '9aa9d8e5-370b-4942-a740-9f2b5c0b959d', 'text': '700.00', 'entity_score': 0.6537825465202332, 'entity_type': 'QUANTITY', 'word_id': 'word_2_167', 'bounding_box': [1978, 1070, 2065, 1092], 'confidence': 0.61}, {'entity_id': 'c3c48746-1f75-4a42-9587-0ad36a795ddd', 'text': '$', 'entity_score': 0.9988178610801697, 'entity_type': 'QUANTITY', 'word_id': 'word_2_169', 'bounding_box': [2090, 1069, 2105, 1095], 'confidence': 0.83}, {'entity_id': 'c3c48746-1f75-4a42-9587-0ad36a795ddd', 'text': '822.32', 'entity_score': 0.9988178610801697, 'entity_type': 'QUANTITY', 'word_id': 'word_2_170', 'bounding_box': [2305, 1070, 2392, 1092], 'confidence': 0.92}, {'entity_id': '9e6a9af8-b39e-42f3-afff-7970cb49056d', 'text': '50.08', 'entity_score': 0.9978299736976624, 'entity_type': 'QUANTITY', 'word_id': 'word_2_179', 'bounding_box': [2322, 1179, 2392, 1201], 'confidence': 0.92}, {'entity_id': 'c5234301-40c9-4323-8b62-8c06f0a083b7', 'text': '200.00', 'entity_score': 0.9980912804603577, 'entity_type': 'QUANTITY', 'word_id': 'word_2_185', 'bounding_box': [2305, 1234, 2392, 1256], 'confidence': 0.91}, {'entity_id': '42b4b457-0285-488a-a2da-1bfc75d1703a', 'text': 'Homeowner', 'entity_score': 0.6116047501564026, 'entity_type': 'ORGANIZATION', 'word_id': 'word_2_194', 'bounding_box': [1441, 1341, 1591, 1363], 'confidence': 0.91}, {'entity_id': '07112b31-5d1b-4269-a7c0-4dd5aeb7a7cf', 'text': '0.00', 'entity_score': 0.9932965636253357, 'entity_type': 'QUANTITY', 'word_id': 'word_2_206', 'bounding_box': [2338, 1394, 2392, 1416], 'confidence': 0.92}, {'entity_id': '0931b36c-fdff-4e62-98d5-4810c9658556', 'text': '$', 'entity_score': 0.9972246885299683, 'entity_type': 'QUANTITY', 'word_id': 'word_2_208', 'bounding_box': [466, 1448, 480, 1474], 'confidence': 0.9}, {'entity_id': '0931b36c-fdff-4e62-98d5-4810c9658556', 'text': '3,727.66', 'entity_score': 0.9972246885299683, 'entity_type': 'QUANTITY', 'word_id': 'word_2_209', 'bounding_box': [653, 1449,  ...
# Yellowstone Bank VI. ASSETS AND LIABILITIES cont’d LOAN #: 1180303 Acct.no. 50502095 $ 2,700.00| Name and address of Company J $ Payment-Months $ Name and address of Bank, S&L, or Credit Union DISCOVER FIN SVCS LLC 146.00 7,270.00 50 JD Bank Kinder, LA Acct.no. 601149948367 Acct.no. 50504841 $ 800.00| Name and address of Company C $ Payment-Months $ Stocks & Bonds Company name-number | $ BK OF AMER 55.00 5,559.00 & description 102 PO BOX 982235 EL PASO, TX 79998 Acct.no. 5524337755790161 Name and address of Company C $ Payment-Months $ Life insurance net cash value $ DISCOVER FIN SVCS LLC *116.00 *5,228.00 46 Face amount: $ Subtotal Liquid Assets $ 90,500.00 Real estate owned enter market value | $ Acct. no. 601149943162 from schedule of real estate owned 240,000.00 | Name and address of Company $ Payment-Months $ Vested interest in retirement fund $ *See Sch Of Liabilities 85.00 2,097.00 Net worth of businesses owned attach | § financial statement Automobiles owned make and year $ Acct. no. Alimony-Child Support-Separate Maintenance $ Payments Owed to: Other Assets itemize $ Job-Related Expense child care, union dues, etc. $ Total Monthly Payments $ 435.00 Total Assets a. | $ 330,500.00 | Net Worth $ 224,453.00] Total Liabilities b. | $ 106,047.00 a minus b Schedule of Real Estate Owned If additional properties are owned, use continuation sheet. Insurance, Property Address enter S if sold, PS if pending sale or | Type of Present Amount of Gross Mortgage Maintenance, Net R if rental being held for income Property| Market Value Mortgages & Liens | Rental Income Payments Taxes & Misc. Rental Income 2803 lkes Rd Kinder, LA 70648 SFR | $ 190,000.00| 0.00- $ $ 0.00 g 0.00 $ 20 acres Leblanc, LA 70651 LAND 50,000.00 0.00 0.00 100.00 100 Totals | $ 240,000.00| $ $ $ $ 100.00| $ 100 List any additional names under which credit has previously been received and indicate appropriate creditor names and account numbers: Alternate Name Creditor Name Account Number l VII. DETAILS OF TRANSACTION VIil. DECLARATIONS a. Purchase Price $ 244,700.00| f you answer “Yes” to any questions a through i, please use Borrower |Co-Borrower i i i continuation sheet for explanation. b. Alterations, improvements, repairs Yes No Yes No c. Land if acquired separately - - - a. Are there any outstanding judgments against you? O | O d. Refinance incl. debts to be paid off - - — b. Have you been declared bankrupt within the past 7 years? O | O 6. Estimated prepaid items 1,341.36 c. Have you had property foreclosed upon or given title or deed in lieu thereof G| ] f. Estimated closing costs 4,779.00 in the last 7 years? g. PMI, MIP, Funding Fee d. Are you a party to a lawsuit? 1G] | X1 h. Discount if Borrower will pay e. Have you directly or indirectly been obligated on any loan which resuttedin [ [¥1 | [ [¥] foreclosure, transfer of title in lieu of foreclosure, or judgment? i. Total costs add items a through h 250,820.36 This would include such loans as home mortgage loans, SBA loans, home improvement loans, : N . educational loans, manufactured mobile home loans, any mortgage, financial obligation, bond, j- Subordinate financing or loan guarantee. If “Yes," provide details, including date, name and address of Lender, FHA or VA case number, if any, and reasons for the action. k. Borrower’s closing costs paid by Seller Uniform Residential Loan Application Freddie Mac Form 65 7-05 rev.6-09 Ellie Mae, Inc. Daniel M Johnson Page 3 of 5 Fannie Mae Form 1003 7-05 rev.6-09 GURLA09_S 0817 GURLA09S POD 03-19-2018 07:59 AM PST
# failed to format Unknown string format: 7/05 rev.6/09
# failed to format time data '7/05 rev.6/09' does not match format '%m/%d/%Y'
# failed to format Unknown string format: 7/05 rev.6/09
# failed to format time data '7/05 rev.6/09' does not match format '%m/%d/%Y'
# successfully tagged entities: {'entities': [{'entity_id': 'b9a45412-bc99-47f4-98f1-7a9f6fee88e0', 'text': 'Yellowstone', 'entity_score': 0.8284072279930115, 'entity_type': 'ORGANIZATION', 'word_id': 'word_3_1', 'bounding_box': [1139, 84, 1329, 109], 'confidence': 0.91}, {'entity_id': 'b9a45412-bc99-47f4-98f1-7a9f6fee88e0', 'text': 'Bank', 'entity_score': 0.8284072279930115, 'entity_type': 'ORGANIZATION', 'word_id': 'word_3_2', 'bounding_box': [1342, 84, 1420, 109], 'confidence': 0.92}, {'entity_id': 'b9a45412-bc99-47f4-98f1-7a9f6fee88e0', 'text': 'VI.', 'entity_score': 0.8284072279930115, 'entity_type': 'ORGANIZATION', 'word_id': 'word_3_3', 'bounding_box': [981, 165, 1020, 190], 'confidence': 0.89}, {'entity_id': 'b9a45412-bc99-47f4-98f1-7a9f6fee88e0', 'text': 'ASSETS', 'entity_score': 0.8284072279930115, 'entity_type': 'ORGANIZATION', 'word_id': 'word_3_4', 'bounding_box': [1028, 164, 1159, 190], 'confidence': 0.91}, {'entity_id': '9c4a929b-6bd2-436c-b0cb-edd736dbc846', 'text': '1180303', 'entity_score': 0.6352875828742981, 'entity_type': 'OTHER', 'word_id': 'word_3_10', 'bounding_box': [2275, 124, 2397, 149], 'confidence': 0.96}, {'entity_id': '9c4a929b-6bd2-436c-b0cb-edd736dbc846', 'text': 'Acct.no.', 'entity_score': 0.6352875828742981, 'entity_type': 'OTHER', 'word_id': 'word_3_65', 'bounding_box': [153, 214, 260, 237], 'confidence': 0.78}, {'entity_id': 'b1bbf08a-5394-4939-9c2e-044b110712d4', 'text': '$', 'entity_score': 0.9865849614143372, 'entity_type': 'QUANTITY', 'word_id': 'word_3_67', 'bounding_box': [715, 213, 730, 239], 'confidence': 0.86}, {'entity_id': 'b1bbf08a-5394-4939-9c2e-044b110712d4', 'text': '2,700.00|', 'entity_score': 0.9865849614143372, 'entity_type': 'QUANTITY', 'word_id': 'word_3_68', 'bounding_box': [908, 216, 1020, 241], 'confidence': 0.84}, {'entity_id': 'f6562e03-6f0c-462d-ba21-d47444325974', 'text': 'Union', 'entity_score': 0.803857147693634, 'entity_type': 'ORGANIZATION', 'word_id': 'word_3_86', 'bounding_box': [714, 264, 787, 286], 'confidence': 0.91}, {'entity_id': 'ae5a5a5a-0844-49ee-9e0f-6a4594befcfd', 'text': 'FIN', 'entity_score': 0.9042515754699707, 'entity_type': 'ORGANIZATION', 'word_id': 'word_3_88', 'bounding_box': [1202, 258, 1245, 280], 'confidence': 0.86}, {'entity_id': 'ae5a5a5a-0844-49ee-9e0f-6a4594befcfd', 'text': 'SVCS', 'entity_score': 0.9042515754699707, 'entity_type': 'ORGANIZATION', 'word_id': 'word_3_89', 'bounding_box': [1256, 258, 1333, 280], 'confidence': 0.89}, {'entity_id': 'ae5a5a5a-0844-49ee-9e0f-6a4594befcfd', 'text': 'LLC', 'entity_score': 0.9042515754699707, 'entity_type': 'ORGANIZATION', 'word_id': 'word_3_90', 'bounding_box': [1345, 258, 1398, 280], 'confidence': 0.89}, {'entity_id': 'cb1059fc-6244-4d71-aba1-0b3d73e49002', 'text': '146.00', 'entity_score': 0.8945065140724182, 'entity_type': 'QUANTITY', 'word_id': 'word_3_91', 'bounding_box': [1970, 252, 2056, 292], 'confidence': 0.93}, {'entity_id': 'f1603a15-ce79-4142-a8e9-9ae78f774281', 'text': 'JD', 'entity_score': 0.5717811584472656, 'entity_type': 'LOCATION', 'word_id': 'word_3_94', 'bounding_box': [156, 310, 192, 332], 'confidence': 0.91}, {'entity_id': '168d7be1-6670-4352-b8dc-82976c3cd3f5', 'text': 'Bank', 'entity_score': 0.5155511498451233, 'entity_type': 'ORGANIZATION', 'word_id': 'word_3_95', 'bounding_box': [202, 310, 271, 332], 'confidence': 0.91}, {'entity_id': '7ccc17d1-7bc8-4e5c-8373-938ba3416b53', 'text': 'Kinder,', 'entity_score': 0.8013015389442444, 'entity_type': 'LOCATION', 'word_id': 'word_3_96', 'bounding_box': [157, 343, 252, 369], 'confidence': 0.89}, {'entity_id': '7ccc17d1-7bc8-4e5c-8373-938ba3416b53', 'text': 'LA', 'entity_score': 0.8013015389442444, 'entity_type': 'LOCATION', 'word_id': 'word_3_97', 'bounding_box': [263, 343, 300, 365], 'confidence': 0.96}, {'entity_id': '98c8e548-b41f-49ca-9814-5614eeeac011', 'text': '601149948367', 'entity_score': 0.8499548435211182, 'entity_type': 'OTHER', 'word_id': 'word_3_99', 'bounding_box': [1178, 440, 1370, 462], 'confidence': 0.96}, {'e ...
# Yellowstone Bank LOAN #: 1180303 VII. DETAILS OF TRANSACTION VIil. DECLARATIONS I Other Credits explain If you answer “Yes” to any questions a through i, please use Borrower |Co-Borrower Cash Deposit on sales contract 500.00 coyntinuation sheet for ex}llgnation. ght. e - Yes No Yes No f. Are you presently delinquent or in default on any Federal debt or any other O | X loan, mortgage, financial obligation, bond, or loan guarantee? g. Are you obligated to pay alimony, child support, or separate maintenance? O | O X h. Is any part of the down payment borrowed? O | OX i. Are you a co-maker or endorser on a note? O | X j. Are you a U.S. citizen? X1 o Loan amount 164.700.00 k. Are you .a permanent resident alien? . . OX¥ | Om exclude PMI, MIP, Funding Fee financed 1. Do you intend to cccupy the property as your primary residence? ¥ 00 X0 n. PMI, MIF; Funding Fee financed m. Have you had an ownership interest in a property in the last three years? 1| ¥ 0. Loan amount add m & n 164,700.00 1 What type of property did you own — principal residence PR, second p. Cash frorr_\-to Borrower 85,620.36 home SH, or investment property IP? PR PR subtract j, k, 1 & o from i 2 How did you hold title to the home — by yourself S, jointly with your spouse SP, or jointly with another person O? SP SP IX. ACKNOWLEDGEMENT AND AGREEMENT Each of the undersigned specifically represents to Lender and to Lender’s actual or potential agents, brokers, processors, attorneys, insurers, servicers, successors and assigns and agrees and acknowledges that: 1 the information provided in this application is true and correct as of the date set forth opposite my signature and that any intentional or negligent misrepresentation of this information contained in this application may result in civil liability, including monetary damages, to any person who may suffer any loss due to reliance upon any misrepresentation that | have made on this application, and-or in criminal penalties including, but not limited to, fine or imprisonment or both under the provisions of Title 18, United States Code, Sec. 1001, et seq.; 2 the loan requested pursuant to this application the “Loan” will be secured by a mortgage or deed of trust on the property described in this application; 3 the property will not be used for any illegal or prohibited purpose or use; 4 all statements made in this application are made for the purpose of obtaining a residential mortgage loan; 5 the property will be occupied as indicated in this application; 6 the Lender, its servicers, successors or assigns may retain the original and-or an electronic record of this application, whether or not the Loan is approved; 7 the Lender and its agents, brokers, insurers, servicers, successors, and assigns may continuously rely on the information contained in the application, and | am obligated to amend and-or supplement the information provided in this application if any of the material facts that | have represented herein should change prior to closing of the Loan; 8 in the event that my payments on the Loan become delinquent, the Lender, its servicers, successors or assigns may, in addition to any other rights and remedies that it may have relating to such delinquency, report my name and account information to one or more consumer reporting agencies; 9 ownership of the Loan and-or administration of the Loan account may be transferred with such notice as may be required by law; 10 neither Lender nor its agents, brokers, insurers, servicers, successors or assigns has made any representation or warranty, express or implied, to me regarding the property or the condition or value of the property; and 11 my transmission of this application as an “electronic record” containing my “electronic signature,” as those terms are defined in applicable federal and-or state laws excluding audio and video recordings, or my facsimile transmission of this application containing a facsimile of my signature, shall be as effective, enforceable and ...
# failed to format Unknown string format: three
# failed to format time data 'three' does not match format '%m/%d/%Y'
# successfully tagged entities: {'entities': [{'entity_id': '1b5062cc-9ec8-4c68-ac1a-1dba7cdc3383', 'text': 'Yellowstone', 'entity_score': 0.9010781645774841, 'entity_type': 'ORGANIZATION', 'word_id': 'word_4_1', 'bounding_box': [1140, 81, 1330, 106], 'confidence': 0.91}, {'entity_id': '1b5062cc-9ec8-4c68-ac1a-1dba7cdc3383', 'text': 'Bank', 'entity_score': 0.9010781645774841, 'entity_type': 'ORGANIZATION', 'word_id': 'word_4_2', 'bounding_box': [1342, 81, 1421, 106], 'confidence': 0.9}, {'entity_id': '1b5062cc-9ec8-4c68-ac1a-1dba7cdc3383', 'text': 'LOAN', 'entity_score': 0.9010781645774841, 'entity_type': 'ORGANIZATION', 'word_id': 'word_4_3', 'bounding_box': [2135, 121, 2224, 147], 'confidence': 0.9}, {'entity_id': 'a90e5785-ee80-4568-a49d-525d60b22b01', 'text': '1180303', 'entity_score': 0.7577444911003113, 'entity_type': 'OTHER', 'word_id': 'word_4_5', 'bounding_box': [2275, 121, 2401, 147], 'confidence': 0.96}, {'entity_id': 'ad4cb37b-85cd-4e10-bae2-fe07f9074fd0', 'text': '500.00', 'entity_score': 0.994083821773529, 'entity_type': 'QUANTITY', 'word_id': 'word_4_37', 'bounding_box': [958, 250, 1045, 272], 'confidence': 0.93}, {'entity_id': 'a9f48376-01d5-4610-8ec1-0f9328f4c806', 'text': 'U.S.', 'entity_score': 0.9447214603424072, 'entity_type': 'LOCATION', 'word_id': 'word_4_122', 'bounding_box': [1236, 625, 1287, 648], 'confidence': 0.75}, {'entity_id': '5990f71e-ce5b-4a38-9481-416514d87c00', 'text': '164.700.00', 'entity_score': 0.9954314231872559, 'entity_type': 'QUANTITY', 'word_id': 'word_4_128', 'bounding_box': [899, 672, 1042, 735], 'confidence': 0.64}, {'entity_id': 'b8db942f-fc7d-4cce-b81c-04fe7def0e1b', 'text': '¥', 'entity_score': 0.7077738046646118, 'entity_type': 'QUANTITY', 'word_id': 'word_4_159', 'bounding_box': [2077, 714, 2128, 750], 'confidence': 0.0}, {'entity_id': 'f755dc8d-55fd-4de2-a710-bf11cfdc5729', 'text': 'three', 'entity_score': 0.43088197708129883, 'entity_type': 'DATE', 'word_id': 'word_4_181', 'bounding_box': [1876, 805, 1941, 827], 'confidence': 0.92}, {'entity_id': '0aa8aae9-78dd-44dc-8f48-f76fe7841403', 'text': 'years?', 'entity_score': 0.46118301153182983, 'entity_type': 'QUANTITY', 'word_id': 'word_4_182', 'bounding_box': [1950, 805, 2035, 833], 'confidence': 0.91}, {'entity_id': '22f3d534-4076-4bfb-b295-d3cfb69b4b9f', 'text': '¥', 'entity_score': 0.9555363655090332, 'entity_type': 'QUANTITY', 'word_id': 'word_4_184', 'bounding_box': [2252, 793, 2302, 829], 'confidence': 0.0}, {'entity_id': 'e6a5c135-a4c9-427d-92db-b310753a2fbf', 'text': '164,700.00', 'entity_score': 0.9083118438720703, 'entity_type': 'QUANTITY', 'word_id': 'word_4_194', 'bounding_box': [899, 832, 1042, 888], 'confidence': 0.91}, {'entity_id': 'eb8f9d4d-0157-452a-8e51-c958be404139', 'text': '85,620.36', 'entity_score': 0.8240308165550232, 'entity_type': 'QUANTITY', 'word_id': 'word_4_212', 'bounding_box': [914, 885, 1042, 925], 'confidence': 0.92}, {'entity_id': 'eb8f9d4d-0157-452a-8e51-c958be404139', 'text': 'home', 'entity_score': 0.8240308165550232, 'entity_type': 'QUANTITY', 'word_id': 'word_4_213', 'bounding_box': [1153, 888, 1224, 910], 'confidence': 0.92}, {'entity_id': '65f0ec3c-fcd0-47db-ba21-52718f0bfbf7', 'text': 'S,', 'entity_score': 0.8456611037254333, 'entity_type': 'PERSON', 'word_id': 'word_4_241', 'bounding_box': [1757, 937, 1799, 965], 'confidence': 0.89}, {'entity_id': 'f79a5ed2-1347-4fec-b2e1-e9a950a83ece', 'text': 'Each', 'entity_score': 0.8178529143333435, 'entity_type': 'QUANTITY', 'word_id': 'word_4_263', 'bounding_box': [154, 1153, 217, 1174], 'confidence': 0.91}, {'entity_id': 'b2a14a7d-1f7a-44c8-ac01-0e09203f85d1', 'text': 'Lender', 'entity_score': 0.4817068576812744, 'entity_type': 'PERSON', 'word_id': 'word_4_270', 'bounding_box': [784, 1153, 872, 1174], 'confidence': 0.91}, {'entity_id': '53908861-e9aa-44c3-9c20-46504dc1e414', 'text': 'Lender’s', 'entity_score': 0.7020429372787476, 'entity_type': 'PERSON', 'word_id': 'word_4_273', 'bounding_box': [964, 1153, 1071, 1175], 'confidence': 0.84}, {' ...
# Yellowstone Bank LOAN #: 1180303 Continuation Sheet-Residential Loan Application Use this continuation sheet if you need more space to complete the Residential Loan Application. Borrower: Daniel M Johnson Agency Case Number: Co-Borrower: Victoria Smith Johnson Lender Case Number: 1180303 VI. ASSETS AND LIABILITIES Cash or Market Borrower B, Co-Borrower C, Joint J Monthly Payment & Assets Value Liabilities Months Left to Pay Unpaid Balance Name and address of Bank, S&L, or Credit Union Name and address of Company B $ Payment-Months | $ JD Bank TRANSFINANCIAL COMPANI *0.00 *1,015.00 Kinder, LA 0 Acct. No. 50504844 $ 800.00| Acct. No. TFC11000050003609085 Name and address of Bank, S&L, or Credit Union Name and address of Company C $ Payment-Months | $ CHASE CARD *25.00 *931.00 38 Acct. No. $ Acct. No. 414740012406 Name and address of Bank, S&L, or Credit Union Name and address of Company C $ Payment-Months | $ CITI *25.00 *92.00 4 800-633-7367 Acct. No. $ Acct. No. 542418122127 Name and address of Bank, S&L, or Credit Union Name and address of Company J $ Payment-Months | $ SYNCB-OLDNAVYDC *25.00 *49.00 2 PO BOX 981400 EL PASO, TX 79998 Acct. No. $ Acct. No. 447995168969 Name and address of Bank, S&L, or Credit Union Name and address of Company C $ Payment-Months | $ SYNCB-AMAZON 10.00 10.00 1 Acct. No. $ Acct. No. 6045781100860062 Name and address of Bank, S&L, or Credit Union Name and address of Company $ Payment-Months | $ Acct. No. $ Acct. No. Name and address of Bank, S&L, or Credit Union Name and address of Company $ Payment-Months | $ Acct. No. Acct. No. I-We fully understand that it is a Federal crime punishable by fine or imprisonment, or both, to knowingly make any false statements concerning any of the above facts as applicable under the provisions of Title 18, United States Code, Section 1001, et seq. Borrower’s Signature: DocuSigned by: x—DML M olunson Date 3-19-2018 | 09:23:25 PD Co-Borrower’s Signature: DocuSigned by: Tx[_um Swille Juwsow. Date 3-19-2018 | 09:30:08 PDT 6B9D07AB97C44DD. Uniform Residential Loan Application Freddie Mac Form 65 7-05 rev.6-09 Ellie Mae, Inc. BAB738431E56453 Page 5 of 5 Fannie Mae Form 1003 7-05 rev.6-09 GURLAOQO9AL_S 0817 GURLA09S POD 03-19-2018 07:59 AM PST
# successfully tagged entities: {'entities': [{'entity_id': '851f0bf0-69d8-49f0-a82a-1d7fb1226a40', 'text': 'Yellowstone', 'entity_score': 0.9028798341751099, 'entity_type': 'ORGANIZATION', 'word_id': 'word_5_1', 'bounding_box': [1145, 89, 1335, 114], 'confidence': 0.92}, {'entity_id': '851f0bf0-69d8-49f0-a82a-1d7fb1226a40', 'text': 'Bank', 'entity_score': 0.9028798341751099, 'entity_type': 'ORGANIZATION', 'word_id': 'word_5_2', 'bounding_box': [1347, 89, 1426, 114], 'confidence': 0.9}, {'entity_id': '851f0bf0-69d8-49f0-a82a-1d7fb1226a40', 'text': 'LOAN', 'entity_score': 0.9028798341751099, 'entity_type': 'ORGANIZATION', 'word_id': 'word_5_3', 'bounding_box': [2140, 124, 2229, 149], 'confidence': 0.92}, {'entity_id': '156d1e39-1594-4c92-ab44-2ad321617804', 'text': '1180303', 'entity_score': 0.965457558631897, 'entity_type': 'OTHER', 'word_id': 'word_5_5', 'bounding_box': [2280, 124, 2401, 149], 'confidence': 0.96}, {'entity_id': '934c54ec-7677-4088-9a5d-b3ac10ddf11f', 'text': 'Daniel', 'entity_score': 0.9928919672966003, 'entity_type': 'PERSON', 'word_id': 'word_5_30', 'bounding_box': [720, 279, 817, 304], 'confidence': 0.9}, {'entity_id': '934c54ec-7677-4088-9a5d-b3ac10ddf11f', 'text': 'M', 'entity_score': 0.9928919672966003, 'entity_type': 'PERSON', 'word_id': 'word_5_31', 'bounding_box': [829, 279, 853, 304], 'confidence': 0.92}, {'entity_id': '934c54ec-7677-4088-9a5d-b3ac10ddf11f', 'text': 'Johnson', 'entity_score': 0.9928919672966003, 'entity_type': 'PERSON', 'word_id': 'word_5_32', 'bounding_box': [865, 279, 1002, 304], 'confidence': 0.9}, {'entity_id': '744bb0c4-fb96-4df8-a01b-7a5474163da1', 'text': 'Victoria', 'entity_score': 0.9353666305541992, 'entity_type': 'PERSON', 'word_id': 'word_5_39', 'bounding_box': [718, 388, 839, 414], 'confidence': 0.92}, {'entity_id': '744bb0c4-fb96-4df8-a01b-7a5474163da1', 'text': 'Smith', 'entity_score': 0.9353666305541992, 'entity_type': 'PERSON', 'word_id': 'word_5_40', 'bounding_box': [851, 388, 940, 414], 'confidence': 0.89}, {'entity_id': '744bb0c4-fb96-4df8-a01b-7a5474163da1', 'text': 'Johnson', 'entity_score': 0.9353666305541992, 'entity_type': 'PERSON', 'word_id': 'word_5_41', 'bounding_box': [952, 388, 1089, 414], 'confidence': 0.91}, {'entity_id': '461f7dd7-3364-4430-b869-417c5381ee6c', 'text': '1180303', 'entity_score': 0.9870337247848511, 'entity_type': 'OTHER', 'word_id': 'word_5_46', 'bounding_box': [1770, 388, 1896, 414], 'confidence': 0.96}, {'entity_id': '1cfb96ba-53cd-4fc3-85d5-dc532d445ea8', 'text': 'ASSETS', 'entity_score': 0.5536984801292419, 'entity_type': 'ORGANIZATION', 'word_id': 'word_5_49', 'bounding_box': [1095, 460, 1226, 486], 'confidence': 0.89}, {'entity_id': '4d1fa681-5f76-4088-bd01-e6c19511860f', 'text': 'Joint', 'entity_score': 0.5163435935974121, 'entity_type': 'ORGANIZATION', 'word_id': 'word_5_61', 'bounding_box': [1680, 507, 1732, 526], 'confidence': 0.91}, {'entity_id': '4d1fa681-5f76-4088-bd01-e6c19511860f', 'text': 'J', 'entity_score': 0.5163435935974121, 'entity_type': 'ORGANIZATION', 'word_id': 'word_5_62', 'bounding_box': [1741, 507, 1768, 531], 'confidence': 0.92}, {'entity_id': '60fbded7-6cf9-44b6-bcf8-acc78bfc9917', 'text': '$', 'entity_score': 0.8104838132858276, 'entity_type': 'ORGANIZATION', 'word_id': 'word_5_106', 'bounding_box': [2116, 609, 2132, 638], 'confidence': 0.75}, {'entity_id': '60fbded7-6cf9-44b6-bcf8-acc78bfc9917', 'text': 'JD', 'entity_score': 0.8104838132858276, 'entity_type': 'ORGANIZATION', 'word_id': 'word_5_107', 'bounding_box': [156, 657, 197, 682], 'confidence': 0.9}, {'entity_id': '60fbded7-6cf9-44b6-bcf8-acc78bfc9917', 'text': 'Bank', 'entity_score': 0.8104838132858276, 'entity_type': 'ORGANIZATION', 'word_id': 'word_5_108', 'bounding_box': [209, 657, 288, 682], 'confidence': 0.92}, {'entity_id': 'f6000b6a-028f-49b4-98f5-db9dba22def1', 'text': 'Kinder,', 'entity_score': 0.4691143035888672, 'entity_type': 'LOCATION', 'word_id': 'word_5_113', 'bounding_box': [158, 694, 266, 724], 'confidence': 0.9}, {'entity_id': 'fd ...
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/dateutil/parser/_parser.py:1218: UnknownTimezoneWarning: tzname PD identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)

# %%
jaffa
# Out:
# "Yellowstone Bank Uniform Residential Loan Application This application is designed to be completed by the applicants with the Lender’s assistance. Applicants should complete this form as “Borrower” or “Co-Borrower,” as applicable. Co-Borrower information must also be provided and the appropriate box checked when the income or assets of a person other than the Borrower including the Borrower’s spouse will be used as a basis for loan qualification or the income or assets of the Borrower’s spouse or other person who has community property rights pursuant to state law will not be used as a basis for loan qualification, but his or her liabilities must be considered because the spouse or other person has community property rights pursuant to applicable law and Borrower resides in a community property state, the security property is located in a community property state, or the Borrower is relying on other property LOAN #: 1180303 located in a community property state as a basis for repayment of the loan. If this is an application for joint credit, Borrower and Co-Borrower each agree that we intend to apg_ly for joint credit sign below: DocuSigned by: DocuSigned by —thu'tl M Jolunson. 31912018 | 09:23:25 pDT | \\VAddoria Switly Jelunson, 3-19-2018 | 09:30:08 PDT Borfgeperes7c4400 Co-BbFewER: | I. TYPE OF MORTGAGE AND TERMS OF LOAN Mortgage [_JVA [¥]Conventional Other explain: Agency Case Number Lender Case Number Applied for: [_JFHA USDA-Rural Housing Service 1180303 Amount Interest Rate No. of Months | Amortization [X] Fixed Rate [ ] Other explain: $ 164,700.00 4375 % | 360 Type: CaPm CJARM type: I Il. PROPERTY INFORMATION AND PURPOSE OF LOAN Subject Property Address street, city, state, & ZIP No. of Units 29 Laptop Loop, Roberts, MT 59070 County: Carbon 1 Legal Description of Subject Property attach description if necessary Year Built 2017 Purpose of Loan [X] Purchase ] Construction [ other explain: Property will be: [1 Refinance  Construction-Permanent Primary  Secondary  Investment Residence Residence Complete this line if construction or construction-permanent loan. Year Lot Acquired | Original Cost Amount Existing Liens | a Present Value of Lot | b Cost of Improvements | Total a + b $ $ $ $ $ Complete this line if this is a refinance loan. Year Acquired Original Cost Amount Existing Liens | Purpose of Refinance Describe Improvements [ made [ to be made $ $ Cost: $ Title will be held in what Names Daniel M Johnson, Victoria Smith Johnson Manner in which Title will be held Joint tenants Source of Down Payment, Settlement Charges, and-or Subordinate Financing explain Equity On Pending Sale Estate will be held in: Fee Simple Leasehold show expiration date Borrower Ill. BORROWER INFORMATION Co-Borrower Borrower’s Name include Jr. or Sr. if applicable Daniel M Johnson Co-Borrower’s Name include Jr. or Sr. if applicable Victoria Smith Johnson Social Security Number Home Phone incl. area code 434-06-8836 337-998-1279 DOB mm-dd-yyyy | Yrs. School 04-12-1967 14 ISocial Security Number Home Phone incl. area code 438-39-1513 337-936-1975 DOB mm-dd-yyyy 09-15-1970 Yrs. School 14 [X] Married  Unmarried include single, | Dependents not listed by Co-Borrower divorced, widowed [X] married  Unmarried include single, divorced, widowed Dependents not listed by Borrower [ Separated no.1 ages 5 [ Separated no.o ages Present Address street, city, state, ZIP [¥]Own Rent No.Yrs. |PresentAddress street, city, state, ZIP [¥]Own [JRent No.Yrs. 2803 lkes Rd 18Y OM | 2803 Ikes Rd 18Y OM Kinder, LA 70648 Kinder, LA 70648 Mailing Address, if different from Present Address Mailing Address, if different from Present Address 2803 lkes Rd 2803 lkes Rd Kinder, LA 70648 Kinder, LA 70648 If residing at present address for less than two years, complete the following: Former Address street, city, state, ZIP [CJown [CJRent No.Yrs. |FormerAddress street, city, state, ZIP [Jown [CJRent No.Yrs. Borrower IV. EMPLOYMENT INFORMATION Co-Borrower Name & Address of Employer [¥ ...

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp(jaffa.replace("\\",""))

# document level
ents = [(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents]
print(ents)

# token level
ent_san = [doc[0].text, doc[0].ent_iob_, doc[0].ent_type_]
ent_francisco = [doc[1].text, doc[1].ent_iob_, doc[1].ent_type_]
print(ent_san)
print()# ['San', 'B', 'GPE']
print(ent_francisco)  # ['Francisco', 'I', 'GPE']
# Out:
# [('Yellowstone Bank Uniform Residential Loan Application', 0, 53, 'ORG'), ('Co-Borrower', 202, 213, 'WORK_OF_ART'), ('Co-Borrower', 231, 242, 'PERSON'), ('Borrower', 385, 393, 'ORG'), ('Borrower', 481, 489, 'ORG'), ('Borrower', 884, 892, 'ORG'), ('#', 927, 928, 'CARDINAL'), ('1180303', 930, 937, 'CARDINAL'), ('Co-Borrower', 1071, 1082, 'PERSON'), ('DocuSigned', 1148, 1158, 'PRODUCT'), ('3', 1249, 1250, 'CARDINAL'), ('JVA', 1355, 1358, 'PERSON'), ('JFHA USDA-Rural Housing Service 1180303', 1443, 1482, 'ORG'), ('Months', 1511, 1517, 'DATE'), ('$ 164,700.00 4375', 1567, 1584, 'MONEY'), ('360', 1589, 1592, 'CARDINAL'), ('29', 1728, 1730, 'CARDINAL'), ('Laptop Loop', 1731, 1742, 'PERSON'), ('Roberts', 1744, 1751, 'PERSON'), ('MT', 1753, 1755, 'ORG'), ('59070', 1756, 1761, 'DATE'), ('Year Built', 1849, 1859, 'EVENT'), ('1', 1945, 1946, 'CARDINAL'), ('Year Lot', 2099, 2107, 'PERSON'), ('$ $ $ $ $', 2219, 2228, 'MONEY'), ('$ $', 2392, 2395, 'MONEY'), ('$', 2402, 2403, 'PRODUCT'), ('Title', 2404, 2409, 'ORG'), ('Daniel M Johnson', 2437, 2453, 'PERSON'), ('Victoria Smith Johnson Manner', 2455, 2484, 'PERSON'), ('Title', 2494, 2499, 'ORG'), ('Fee Simple Leasehold', 2655, 2675, 'ORG'), ('Sr', 2775, 2777, 'ORG'), ('Daniel M Johnson Co-Borrower', 2793, 2821, 'PERSON'), ('Sr', 2844, 2846, 'ORG'), ('Victoria Smith', 2862, 2876, 'PERSON'), ('Social Security Number Home', 2885, 2912, 'ORG'), ('434', 2935, 2938, 'CARDINAL'), ('DOB mm-dd-yyyy', 2960, 2974, 'PERSON'), ('Yrs', 2977, 2980, 'PERSON'), ('ISocial Security Number Home', 3003, 3031, 'ORG'), ('438', 3054, 3057, 'CARDINAL'), ('09-15-1970', 3094, 3104, 'PRODUCT'), ('Yrs', 3105, 3108, 'PERSON'), ('Co-Borrower', 3186, 3197, 'PERSON'), ('Borrower', 3298, 3306, 'PERSON'), ('5', 3329, 3330, 'CARDINAL'), ('ZIP', 3390, 3393, 'ORG'), ('Yrs', 3409, 3412, 'PERSON'), ('ZIP', 3451, 3454, 'ORG'), ('Yrs', 3472, 3475, 'PERSON'), ('2803', 3477, 3481, 'DATE'), ('Rd 18Y OM', 3487, 3496, 'WORK_OF_ART'), ('LA', 3527, 3529, 'GPE'), ('Kinder', 3536, 3542, 'PERSON'), ('LA', 3544, 3546, 'GPE'), ('2803', 3655, 3659, 'ORDINAL'), ('2803', 3668, 3672, 'DATE'), ('Rd Kinder', 3678, 3687, 'PERSON'), ('LA', 3689, 3691, 'GPE'), ('Kinder', 3698, 3704, 'PERSON'), ('LA', 3706, 3708, 'ORG'), ('less than two years', 3750, 3769, 'DATE'), ('ZIP', 3831, 3834, 'ORG'), ('CJown', 3836, 3841, 'ORG'), ('Yrs', 3853, 3856, 'PERSON'), ('ZIP', 3894, 3897, 'ORG'), ('Jown', 3899, 3903, 'PRODUCT'), ('Yrs', 3915, 3918, 'PERSON'), ('Borrower IV', 3920, 3931, 'PERSON'), ('Employed | Yrs', 4004, 4018, 'PRODUCT'), ('Employed | Yrs', 4068, 4082, 'WORK_OF_ART'), ('Daniel Johnson Trucking', 4096, 4119, 'PERSON'), ('LLC 24Y OM -', 4121, 4133, 'ORG'), ('Yrs', 4153, 4156, 'PERSON'), ('30', 4228, 4230, 'CARDINAL'), ('Business Sole Owner Business Phone', 4254, 4288, 'ORG'), ('less than two years', 4404, 4423, 'DATE'), ('more than one', 4452, 4465, 'CARDINAL'), ('Uniform Residential Loan Application Freddie Mac', 4500, 4548, 'ORG'), ('Ellie Mae', 4571, 4580, 'ORG'), ('1', 4592, 4593, 'CARDINAL'), ('5', 4597, 4598, 'CARDINAL'), ('Fannie Mae', 4608, 4618, 'ORG'), ('1003 7-05', 4624, 4633, 'DATE'), ('07:59 AM', 4674, 4682, 'TIME')]
# ['Yellowstone', 'B', 'ORG']
#
# ['Bank', 'I', 'ORG']

# %%
doc[965].text
# Out:
# 'PST'

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp(text_test)

for ent in doc.ents:
    print(ent.text,ent.label_)
# Out:
# Yellowstone Bank Uniform Residential Loan Application ORG
# Co-Borrower WORK_OF_ART
# Co-Borrower PERSON
# Borrower ORG
# Borrower ORG
# Borrower ORG
# # CARDINAL
# 1180303 CARDINAL
# Co-Borrower PERSON
# DocuSigned PRODUCT
# \VAddoria Switly Jelunson PERSON
# 3-19-2018 DATE
# JVA PERSON
# JFHA USDA-Rural Housing Service ORG
# 1180303 DATE
# $ 164,700.00 Interest Rate MONEY
# 4375 % PERCENT
# Months 360 DATE
# CaPm PRODUCT
# 29 CARDINAL
# Laptop Loop PERSON
# Roberts PERSON
# MT ORG
# 59070 County PERCENT
# 1 1 CARDINAL
# Subject Property ORG
# Year Built EVENT
# 1 CARDINAL
# Year Lot PERSON
# $ $ $ $ $ MONEY
# $ $ MONEY
# $ PRODUCT
# Title ORG
# Daniel M Johnson PERSON
# Victoria Smith Johnson Manner PERSON
# Title ORG
# Fee Simple Leasehold ORG
# Borrower Ill. PERSON
# Sr ORG
# Daniel M Johnson Co-Borrower PERSON
# Sr ORG
# Victoria Smith PERSON
# Social Security ORG
# 434 CARDINAL
# area code 337-998-1279 LAW
# DOB ORG
# ISocial Security Number ORG
# 438 CARDINAL
# 337 CARDINAL
# 09-15-1970 DATE
# Yrs PERSON
# Co-Borrower PERSON
# Borrower PERSON
# 5 CARDINAL
# ZIP ORG
# Yrs PERSON
# ZIP ORG
# Yrs PERSON
# 2803 DATE
# Rd 18Y OM WORK_OF_ART
# LA GPE
# Kinder PERSON
# LA GPE
# 2803 ORDINAL
# 2803 DATE
# Rd Kinder PERSON
# LA GPE
# Kinder PERSON
# LA ORG
# less than two years DATE
# ZIP ORG
# CJown ORG
# Yrs PERSON
# ZIP ORG
# Jown PRODUCT
# Yrs PERSON
# Daniel Johnson Trucking PERSON
# LLC ORG
# Employed | years LAW
# 24Y OM | Name & Address ORG
# Employed | Yrs WORK_OF_ART
# Yrs GPE
# 30 CARDINAL
# Business Sole Owner Business Phone ORG
# less than two years DATE
# more than one CARDINAL
# Uniform Residential Loan Application Freddie Mac ORG
# Ellie Mae ORG
# 1 CARDINAL
# 5 CARDINAL
# Fannie Mae ORG
# 1003 7-05 DATE
# 07:59 AM TIME

# %%
spacy_compare_df = pd.DataFrame(data=list(zip(spacy_text_list,spacy_tag_list)),columns=["Spacy_text","Spacy_tag"])

# %%
jaffa = "Yellowstone Bank Uniform Residential Loan Application This application is designed to be completed by the applicants with the Lender’s assistance. Applicants should complete this form as “Borrower” or “Co-Borrower,” as applicable. Co-Borrower information must also be provided and the appropriate box checked when the income or assets of a person other than the Borrower including the Borrower’s spouse will be used as a basis for loan qualification or the income or assets of the Borrower’s spouse or other person who has community property rights pursuant to state law will not be used as a basis for loan qualification, but his or her liabilities must be considered because the spouse or other person has community property rights pursuant to applicable law and Borrower resides in a community property state, the security property is located in a community property state, or the Borrower is relying on other property LOAN #: 1180303 located in a community property state as a basis for repayment of the loan. If this is an application for joint credit, Borrower and Co-Borrower each agree that we intend to apg_ly for joint credit sign below: DocuSigned by: DocuSigned by —thu'tl M Jolunson. 31912018 | 09:23:25 pDT | \VAddoria Switly Jelunson, 3-19-2018 | 09:30:08 PDT Borfgeperes7c4400 Co-BbFewER: | I. TYPE OF MORTGAGE AND TERMS OF LOAN Mortgage [_JVA [¥]Conventional Other explain: Agency Case Number Lender Case Number Applied for: [_JFHA USDA-Rural Housing Service 1180303 Amount Interest Rate No. of Months | Amortization [X] Fixed Rate [ ] Other explain: $ 164,700.00 4375 % | 360 Type: CaPm CJARM type: I Il. PROPERTY INFORMATION AND PURPOSE OF LOAN Subject Property Address street, city, state, & ZIP No. of Units 29 Laptop Loop, Roberts, MT 59070 County: Carbon 1 Legal Description of Subject Property attach description if necessary Year Built 2017 Purpose of Loan [X] Purchase ] Construction [ other explain: Property will be: [1 Refinance  Construction-Permanent Primary  Secondary  Investment Residence Residence Complete this line if construction or construction-permanent loan. Year Lot Acquired | Original Cost Amount Existing Liens | a Present Value of Lot | b Cost of Improvements | Total a + b $ $ $ $ $ Complete this line if this is a refinance loan. Year Acquired Original Cost Amount Existing Liens | Purpose of Refinance Describe Improvements [ made [ to be made $ $ Cost: $ Title will be held in what Names Daniel M Johnson, Victoria Smith Johnson Manner in which Title will be held Joint tenants Source of Down Payment, Settlement Charges, and-or Subordinate Financing explain Equity On Pending Sale Estate will be held in: Fee Simple Leasehold show expiration date Borrower Ill. BORROWER INFORMATION Co-Borrower Borrower’s Name include Jr. or Sr. if applicable Daniel M Johnson Co-Borrower’s Name include Jr. or Sr. if applicable Victoria Smith Johnson Social Security Number Home Phone incl. area code 434-06-8836 337-998-1279 DOB mm-dd-yyyy | Yrs. School 04-12-1967 14 ISocial Security Number Home Phone incl. area code 438-39-1513 337-936-1975 DOB mm-dd-yyyy 09-15-1970 Yrs. School 14 [X] Married  Unmarried include single, | Dependents not listed by Co-Borrower divorced, widowed [X] married  Unmarried include single, divorced, widowed Dependents not listed by Borrower [ Separated no.1 ages 5 [ Separated no.o ages Present Address street, city, state, ZIP [¥]Own Rent No.Yrs. |PresentAddress street, city, state, ZIP [¥]Own [JRent No.Yrs. 2803 lkes Rd 18Y OM | 2803 Ikes Rd 18Y OM Kinder, LA 70648 Kinder, LA 70648 Mailing Address, if different from Present Address Mailing Address, if different from Present Address 2803 lkes Rd 2803 lkes Rd Kinder, LA 70648 Kinder, LA 70648 If residing at present address for less than two years, complete the following: Former Address street, city, state, ZIP [CJown [CJRent No.Yrs. |FormerAddress street, city, state, ZIP [Jown [CJRent No.Yrs. Borrower IV. EMPLOYMENT INFORMATION Co-Borrower Name & Address of Employer [¥] self Employed | Yrs. on this job | Name & Address of Employer [ self Employed | Yrs. on this job Daniel Johnson Trucking, LLC 24Y OM - o Yrs. employed in Yrs. employed in this line of this line of work-profession work-profession 30 Position-Title-Type of Business Sole Owner Business Phone incl. area code Position-Title-Type of Business Business Phone incl. area code If employed in current position for less than two years or if currently employed in more than one position, complete the following: Uniform Residential Loan Application Freddie Mac Form 65 7-05 rev.6-09 Ellie Mae, Inc. Page 1 of 5 03-19-20 Fannie Mae Form 1003 7-05 rev.6-09 GURLA09_S 0817 GURLA09S POD 18 07:59 AM PST"

# %%
sner_tagger.tag(word_tokenize(jaffa))
# Out:
# [('Yellowstone', 'ORGANIZATION'),
#  ('Bank', 'ORGANIZATION'),
#  ('Uniform', 'ORGANIZATION'),
#  ('Residential', 'ORGANIZATION'),
#  ('Loan', 'ORGANIZATION'),
#  ('Application', 'ORGANIZATION'),
#  ('This', 'O'),
#  ('application', 'O'),
#  ('is', 'O'),
#  ('designed', 'O'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('completed', 'O'),
#  ('by', 'O'),
#  ('the', 'O'),
#  ('applicants', 'O'),
#  ('with', 'O'),
#  ('the', 'O'),
#  ('Lender', 'O'),
#  ('’', 'O'),
#  ('s', 'O'),
#  ('assistance', 'O'),
#  ('.', 'O'),
#  ('Applicants', 'O'),
#  ('should', 'O'),
#  ('complete', 'O'),
#  ('this', 'O'),
#  ('form', 'O'),
#  ('as', 'O'),
#  ('“', 'O'),
#  ('Borrower', 'O'),
#  ('”', 'O'),
#  ('or', 'O'),
#  ('“', 'O'),
#  ('Co-Borrower', 'O'),
#  (',', 'O'),
#  ('”', 'O'),
#  ('as', 'O'),
#  ('applicable', 'O'),
#  ('.', 'O'),
#  ('Co-Borrower', 'O'),
#  ('information', 'O'),
#  ('must', 'O'),
#  ('also', 'O'),
#  ('be', 'O'),
#  ('provided', 'O'),
#  ('and', 'O'),
#  ('the', 'O'),
#  ('appropriate', 'O'),
#  ('box', 'O'),
#  ('checked', 'O'),
#  ('when', 'O'),
#  ('the', 'O'),
#  ('income', 'O'),
#  ('or', 'O'),
#  ('assets', 'O'),
#  ('of', 'O'),
#  ('a', 'O'),
#  ('person', 'O'),
#  ('other', 'O'),
#  ('than', 'O'),
#  ('the', 'O'),
#  ('Borrower', 'O'),
#  ('including', 'O'),
#  ('the', 'O'),
#  ('Borrower', 'O'),
#  ('’', 'O'),
#  ('s', 'O'),
#  ('spouse', 'O'),
#  ('will', 'O'),
#  ('be', 'O'),
#  ('used', 'O'),
#  ('as', 'O'),
#  ('a', 'O'),
#  ('basis', 'O'),
#  ('for', 'O'),
#  ('loan', 'O'),
#  ('qualification', 'O'),
#  ('or', 'O'),
#  ('the', 'O'),
#  ('income', 'O'),
#  ('or', 'O'),
#  ('assets', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('Borrower', 'O'),
#  ('’', 'O'),
#  ('s', 'O'),
#  ('spouse', 'O'),
#  ('or', 'O'),
#  ('other', 'O'),
#  ('person', 'O'),
#  ('who', 'O'),
#  ('has', 'O'),
#  ('community', 'O'),
#  ('property', 'O'),
#  ('rights', 'O'),
#  ('pursuant', 'O'),
#  ('to', 'O'),
#  ('state', 'O'),
#  ('law', 'O'),
#  ('will', 'O'),
#  ('not', 'O'),
#  ('be', 'O'),
#  ('used', 'O'),
#  ('as', 'O'),
#  ('a', 'O'),
#  ('basis', 'O'),
#  ('for', 'O'),
#  ('loan', 'O'),
#  ('qualification', 'O'),
#  (',', 'O'),
#  ('but', 'O'),
#  ('his', 'O'),
#  ('or', 'O'),
#  ('her', 'O'),
#  ('liabilities', 'O'),
#  ('must', 'O'),
#  ('be', 'O'),
#  ('considered', 'O'),
#  ('because', 'O'),
#  ('the', 'O'),
#  ('spouse', 'O'),
#  ('or', 'O'),
#  ('other', 'O'),
#  ('person', 'O'),
#  ('has', 'O'),
#  ('community', 'O'),
#  ('property', 'O'),
#  ('rights', 'O'),
#  ('pursuant', 'O'),
#  ('to', 'O'),
#  ('applicable', 'O'),
#  ('law', 'O'),
#  ('and', 'O'),
#  ('Borrower', 'PERSON'),
#  ('resides', 'O'),
#  ('in', 'O'),
#  ('a', 'O'),
#  ('community', 'O'),
#  ('property', 'O'),
#  ('state', 'O'),
#  (',', 'O'),
#  ('the', 'O'),
#  ('security', 'O'),
#  ('property', 'O'),
#  ('is', 'O'),
#  ('located', 'O'),
#  ('in', 'O'),
#  ('a', 'O'),
#  ('community', 'O'),
#  ('property', 'O'),
#  ('state', 'O'),
#  (',', 'O'),
#  ('or', 'O'),
#  ('the', 'O'),
#  ('Borrower', 'O'),
#  ('is', 'O'),
#  ('relying', 'O'),
#  ('on', 'O'),
#  ('other', 'O'),
#  ('property', 'O'),
#  ('LOAN', 'O'),
#  ('#', 'O'),
#  (':', 'O'),
#  ('1180303', 'O'),
#  ('located', 'O'),
#  ('in', 'O'),
#  ('a', 'O'),
#  ('community', 'O'),
#  ('property', 'O'),
#  ('state', 'O'),
#  ('as', 'O'),
#  ('a', 'O'),
#  ('basis', 'O'),
#  ('for', 'O'),
#  ('repayment', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('loan', 'O'),
#  ('.', 'O'),
#  ('If', 'O'),
#  ('this', 'O'),
#  ('is', 'O'),
#  ('an', 'O'),
#  ('application', 'O'),
#  ('for', 'O'),
#  ('joint', 'O'),
#  ('credit', 'O'),
#  (',', 'O'),
#  ('Borrower', 'ORGANIZATION'),
#  ('and', 'O'),
#  ('Co-Borrower', 'O'),
#  ('each', 'O'),
#  ('agree', 'O'),
#  ('that', 'O'),
#  ('we', 'O'),
#  ('intend', 'O'),
#  ('to', 'O'),
#  ('apg_ly', 'O'),
#  ('for', 'O'),
#  ('joint', 'O'),
#  ('credit', 'O'),
#  ('sign', 'O'),
#  ('below', 'O'),
#  (':', 'O'),
#  ('DocuSigned', 'O'),
#  ('by', 'O'),
#  (':', 'O'),
#  ('DocuSigned', 'O'),
#  ('by', 'O'),
#  ("—thu'tl", 'O'),
#  ('M', 'O'),
#  ('Jolunson', 'PERSON'),
#  ('.', 'O'),
#  ('31912018', 'O'),
#  ('|', 'O'),
#  ('09:23:25', 'O'),
#  ('pDT', 'O'),
#  ('|', 'O'),
#  ('\\VAddoria', 'O'),
#  ('Switly', 'O'),
#  ('Jelunson', 'O'),
#  (',', 'O'),
#  ('3-19-2018', 'O'),
#  ('|', 'O'),
#  ('09:30:08', 'O'),
#  ('PDT', 'O'),
#  ('Borfgeperes7c4400', 'O'),
#  ('Co-BbFewER', 'O'),
#  (':', 'O'),
#  ('|', 'O'),
#  ('I', 'O'),
#  ('.', 'O'),
#  ('TYPE', 'O'),
#  ('OF', 'O'),
#  ('MORTGAGE', 'O'),
#  ('AND', 'O'),
#  ('TERMS', 'O'),
#  ('OF', 'O'),
#  ('LOAN', 'O'),
#  ('Mortgage', 'O'),
#  ('[', 'O'),
#  ('_JVA', 'O'),
#  ('[', 'O'),
#  ('¥', 'O'),
#  (']', 'O'),
#  ('Conventional', 'O'),
#  ('Other', 'O'),
#  ('explain', 'O'),
#  (':', 'O'),
#  ('Agency', 'O'),
#  ('Case', 'O'),
#  ('Number', 'O'),
#  ('Lender', 'O'),
#  ('Case', 'O'),
#  ('Number', 'O'),
#  ('Applied', 'O'),
#  ('for', 'O'),
#  (':', 'O'),
#  ('[', 'O'),
#  ('_JFHA', 'O'),
#  ('USDA-Rural', 'ORGANIZATION'),
#  ('Housing', 'ORGANIZATION'),
#  ('Service', 'ORGANIZATION'),
#  ('1180303', 'O'),
#  ('Amount', 'O'),
#  ('Interest', 'O'),
#  ('Rate', 'O'),
#  ('No', 'O'),
#  ('.', 'O'),
#  ('of', 'O'),
#  ('Months', 'O'),
#  ('|', 'O'),
#  ('Amortization', 'O'),
#  ('[', 'O'),
#  ('X', 'O'),
#  (']', 'O'),
#  ('Fixed', 'O'),
#  ('Rate', 'O'),
#  ('[', 'O'),
#  (']', 'O'),
#  ('Other', 'O'),
#  ('explain', 'O'),
#  (':', 'O'),
#  ('$', 'O'),
#  ('164,700.00', 'O'),
#  ('4375', 'O'),
#  ('%', 'O'),
#  ('|', 'O'),
#  ('360', 'O'),
#  ('Type', 'O'),
#  (':', 'O'),
#  ('CaPm', 'O'),
#  ('CJARM', 'O'),
#  ('type', 'O'),
#  (':', 'O'),
#  ('I', 'O'),
#  ('Il', 'O'),
#  ('.', 'O'),
#  ('PROPERTY', 'O'),
#  ('INFORMATION', 'O'),
#  ('AND', 'O'),
#  ('PURPOSE', 'O'),
#  ('OF', 'O'),
#  ('LOAN', 'O'),
#  ('Subject', 'O'),
#  ('Property', 'O'),
#  ('Address', 'O'),
#  ('street', 'O'),
#  (',', 'O'),
#  ('city', 'O'),
#  (',', 'O'),
#  ('state', 'O'),
#  (',', 'O'),
#  ('&', 'O'),
#  ('ZIP', 'O'),
#  ('No', 'O'),
#  ('.', 'O'),
#  ('of', 'O'),
#  ('Units', 'O'),
#  ('29', 'O'),
#  ('Laptop', 'O'),
#  ('Loop', 'O'),
#  (',', 'O'),
#  ('Roberts', 'PERSON'),
#  (',', 'O'),
#  ('MT', 'O'),
#  ('59070', 'O'),
#  ('County', 'O'),
#  (':', 'O'),
#  ('Carbon', 'ORGANIZATION'),
#  ('1', 'O'),
#  ('Legal', 'O'),
#  ('Description', 'O'),
#  ('of', 'O'),
#  ('Subject', 'O'),
#  ('Property', 'O'),
#  ('attach', 'O'),
#  ('description', 'O'),
#  ('if', 'O'),
#  ('necessary', 'O'),
#  ('Year', 'O'),
#  ('Built', 'O'),
#  ('2017', 'O'),
#  ('Purpose', 'O'),
#  ('of', 'O'),
#  ('Loan', 'O'),
#  ('[', 'O'),
#  ('X', 'O'),
#  (']', 'O'),
#  ('Purchase', 'O'),
#  (']', 'O'),
#  ('Construction', 'O'),
#  ('[', 'O'),
#  ('other', 'O'),
#  ('explain', 'O'),
#  (':', 'O'),
#  ('Property', 'O'),
#  ('will', 'O'),
#  ('be', 'O'),
#  (':', 'O'),
#  ('[', 'O'),
#  ('1', 'O'),
#  ('Refinance', 'ORGANIZATION'),
#  ('Construction-Permanent', 'ORGANIZATION'),
#  ('Primary', 'ORGANIZATION'),
#  ('Secondary', 'ORGANIZATION'),
#  ('Investment', 'ORGANIZATION'),
#  ('Residence', 'ORGANIZATION'),
#  ('Residence', 'ORGANIZATION'),
#  ('Complete', 'ORGANIZATION'),
#  ('this', 'O'),
#  ('line', 'O'),
#  ('if', 'O'),
#  ('construction', 'O'),
#  ('or', 'O'),
#  ('construction-permanent', 'O'),
#  ('loan', 'O'),
#  ('.', 'O'),
#  ('Year', 'O'),
#  ('Lot', 'O'),
#  ('Acquired', 'O'),
#  ('|', 'O'),
#  ('Original', 'O'),
#  ('Cost', 'O'),
#  ('Amount', 'O'),
#  ('Existing', 'O'),
#  ('Liens', 'O'),
#  ('|', 'O'),
#  ('a', 'O'),
#  ('Present', 'O'),
#  ('Value', 'O'),
#  ('of', 'O'),
#  ('Lot', 'O'),
#  ('|', 'O'),
#  ('b', 'O'),
#  ('Cost', 'O'),
#  ('of', 'O'),
#  ('Improvements', 'O'),
#  ('|', 'O'),
#  ('Total', 'O'),
#  ('a', 'O'),
#  ('+', 'O'),
#  ('b', 'O'),
#  ('$', 'O'),
#  ('$', 'O'),
#  ('$', 'O'),
#  ('$', 'O'),
#  ('$', 'O'),
#  ('Complete', 'O'),
#  ('this', 'O'),
#  ('line', 'O'),
#  ('if', 'O'),
#  ('this', 'O'),
#  ('is', 'O'),
#  ('a', 'O'),
#  ('refinance', 'O'),
#  ('loan', 'O'),
#  ('.', 'O'),
#  ('Year', 'O'),
#  ('Acquired', 'O'),
#  ('Original', 'O'),
#  ('Cost', 'O'),
#  ('Amount', 'O'),
#  ('Existing', 'O'),
#  ('Liens', 'O'),
#  ('|', 'O'),
#  ('Purpose', 'O'),
#  ('of', 'O'),
#  ('Refinance', 'O'),
#  ('Describe', 'O'),
#  ('Improvements', 'O'),
#  ('[', 'O'),
#  ('made', 'O'),
#  ('[', 'O'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('made', 'O'),
#  ('$', 'O'),
#  ('$', 'O'),
#  ('Cost', 'O'),
#  (':', 'O'),
#  ('$', 'O'),
#  ('Title', 'O'),
#  ('will', 'O'),
#  ('be', 'O'),
#  ('held', 'O'),
#  ('in', 'O'),
#  ('what', 'O'),
#  ('Names', 'O'),
#  ('Daniel', 'PERSON'),
#  ('M', 'PERSON'),
#  ('Johnson', 'PERSON'),
#  (',', 'O'),
#  ('Victoria', 'ORGANIZATION'),
#  ('Smith', 'ORGANIZATION'),
#  ('Johnson', 'ORGANIZATION'),
#  ('Manner', 'ORGANIZATION'),
#  ('in', 'O'),
#  ('which', 'O'),
#  ('Title', 'O'),
#  ('will', 'O'),
#  ('be', 'O'),
#  ('held', 'O'),
#  ('Joint', 'O'),
#  ('tenants', 'O'),
#  ('Source', 'O'),
#  ('of', 'O'),
#  ('Down', 'O'),
#  ('Payment', 'O'),
#  (',', 'O'),
#  ('Settlement', 'O'),
#  ('Charges', 'O'),
#  (',', 'O'),
#  ('and-or', 'O'),
#  ('Subordinate', 'O'),
#  ('Financing', 'O'),
#  ('explain', 'O'),
#  ('Equity', 'O'),
#  ('On', 'O'),
#  ('Pending', 'O'),
#  ('Sale', 'O'),
#  ('Estate', 'O'),
#  ('will', 'O'),
#  ('be', 'O'),
#  ('held', 'O'),
#  ('in', 'O'),
#  (':', 'O'),
#  ('Fee', 'O'),
#  ('Simple', 'O'),
#  ('Leasehold', 'O'),
#  ('show', 'O'),
#  ('expiration', 'O'),
#  ('date', 'O'),
#  ('Borrower', 'O'),
#  ('Ill.', 'O'),
#  ('BORROWER', 'O'),
#  ('INFORMATION', 'O'),
#  ('Co-Borrower', 'PERSON'),
#  ('Borrower', 'PERSON'),
#  ('’', 'O'),
#  ('s', 'O'),
#  ('Name', 'O'),
#  ('include', 'O'),
#  ('Jr.', 'O'),
#  ('or', 'O'),
#  ('Sr.', 'O'),
#  ('if', 'O'),
#  ('applicable', 'O'),
#  ('Daniel', 'PERSON'),
#  ('M', 'PERSON'),
#  ('Johnson', 'PERSON'),
#  ('Co-Borrower', 'O'),
#  ('’', 'O'),
#  ('s', 'O'),
#  ('Name', 'O'),
#  ('include', 'O'),
#  ('Jr.', 'O'),
#  ('or', 'O'),
#  ('Sr.', 'O'),
#  ('if', 'O'),
#  ('applicable', 'O'),
#  ('Victoria', 'ORGANIZATION'),
#  ('Smith', 'ORGANIZATION'),
#  ('Johnson', 'ORGANIZATION'),
#  ('Social', 'ORGANIZATION'),
#  ('Security', 'ORGANIZATION'),
#  ('Number', 'ORGANIZATION'),
#  ('Home', 'ORGANIZATION'),
#  ('Phone', 'ORGANIZATION'),
#  ('incl', 'O'),
#  ('.', 'O'),
#  ('area', 'O'),
#  ('code', 'O'),
#  ('434-06-8836', 'O'),
#  ('337-998-1279', 'O'),
#  ('DOB', 'O'),
#  ('mm-dd-yyyy', 'O'),
#  ('|', 'O'),
#  ('Yrs', 'O'),
#  ('.', 'O'),
#  ('School', 'O'),
#  ('04-12-1967', 'O'),
#  ('14', 'O'),
#  ('ISocial', 'O'),
#  ('Security', 'O'),
#  ('Number', 'O'),
#  ('Home', 'O'),
#  ('Phone', 'O'),
#  ('incl', 'O'),
#  ('.', 'O'),
#  ('area', 'O'),
#  ('code', 'O'),
#  ('438-39-1513', 'O'),
#  ('337-936-1975', 'O'),
#  ('DOB', 'O'),
#  ('mm-dd-yyyy', 'O'),
#  ('09-15-1970', 'O'),
#  ('Yrs', 'O'),
#  ('.', 'O'),
#  ('School', 'O'),
#  ('14', 'O'),
#  ('[', 'O'),
#  ('X', 'O'),
#  (']', 'O'),
#  ('Married', 'O'),
#  ('Unmarried', 'O'),
#  ('include', 'O'),
#  ('single', 'O'),
#  (',', 'O'),
#  ('|', 'O'),
#  ('Dependents', 'O'),
#  ('not', 'O'),
#  ('listed', 'O'),
#  ('by', 'O'),
#  ('Co-Borrower', 'PERSON'),
#  ('divorced', 'O'),
#  (',', 'O'),
#  ('widowed', 'O'),
#  ('[', 'O'),
#  ('X', 'O'),
#  (']', 'O'),
#  ('married', 'O'),
#  ('Unmarried', 'O'),
#  ('include', 'O'),
#  ('single', 'O'),
#  (',', 'O'),
#  ('divorced', 'O'),
#  (',', 'O'),
#  ('widowed', 'O'),
#  ('Dependents', 'O'),
#  ('not', 'O'),
#  ('listed', 'O'),
#  ('by', 'O'),
#  ('Borrower', 'O'),
#  ('[', 'O'),
#  ('Separated', 'O'),
#  ('no.1', 'O'),
#  ('ages', 'O'),
#  ('5', 'O'),
#  ('[', 'O'),
#  ('Separated', 'O'),
#  ('no.o', 'O'),
#  ('ages', 'O'),
#  ('Present', 'O'),
#  ('Address', 'O'),
#  ('street', 'O'),
#  (',', 'O'),
#  ('city', 'O'),
#  (',', 'O'),
#  ('state', 'O'),
#  (',', 'O'),
#  ('ZIP', 'O'),
#  ('[', 'O'),
#  ('¥', 'O'),
#  (']', 'O'),
#  ('Own', 'O'),
#  ('Rent', 'O'),
#  ('No.Yrs', 'O'),
#  ('.', 'O'),
#  ('|PresentAddress', 'O'),
#  ('street', 'O'),
#  (',', 'O'),
#  ('city', 'O'),
#  (',', 'O'),
#  ('state', 'O'),
#  (',', 'O'),
#  ('ZIP', 'O'),
#  ('[', 'O'),
#  ('¥', 'O'),
#  (']', 'O'),
#  ('Own', 'O'),
#  ('[', 'O'),
#  ('JRent', 'O'),
#  ('No.Yrs', 'O'),
#  ('.', 'O'),
#  ('2803', 'O'),
#  ('lkes', 'O'),
#  ('Rd', 'O'),
#  ('18Y', 'O'),
#  ('OM', 'O'),
#  ('|', 'O'),
#  ('2803', 'O'),
#  ('Ikes', 'O'),
#  ('Rd', 'O'),
#  ('18Y', 'O'),
#  ('OM', 'O'),
#  ('Kinder', 'O'),
#  (',', 'O'),
#  ('LA', 'LOCATION'),
#  ('70648', 'O'),
#  ('Kinder', 'O'),
#  (',', 'O'),
#  ('LA', 'LOCATION'),
#  ('70648', 'O'),
#  ('Mailing', 'O'),
#  ('Address', 'O'),
#  (',', 'O'),
#  ('if', 'O'),
#  ('different', 'O'),
#  ('from', 'O'),
#  ('Present', 'O'),
#  ('Address', 'O'),
#  ('Mailing', 'O'),
#  ('Address', 'O'),
#  (',', 'O'),
#  ('if', 'O'),
#  ('different', 'O'),
#  ('from', 'O'),
#  ('Present', 'O'),
#  ('Address', 'O'),
#  ('2803', 'O'),
#  ('lkes', 'O'),
#  ('Rd', 'O'),
#  ('2803', 'O'),
#  ('lkes', 'O'),
#  ('Rd', 'O'),
#  ('Kinder', 'O'),
#  (',', 'O'),
#  ('LA', 'LOCATION'),
#  ('70648', 'O'),
#  ('Kinder', 'O'),
#  (',', 'O'),
#  ('LA', 'O'),
#  ('70648', 'O'),
#  ('If', 'O'),
#  ('residing', 'O'),
#  ('at', 'O'),
#  ('present', 'O'),
#  ('address', 'O'),
#  ('for', 'O'),
#  ('less', 'O'),
#  ('than', 'O'),
#  ('two', 'O'),
#  ('years', 'O'),
#  (',', 'O'),
#  ('complete', 'O'),
#  ('the', 'O'),
#  ('following', 'O'),
#  (':', 'O'),
#  ('Former', 'O'),
#  ('Address', 'O'),
#  ('street', 'O'),
#  (',', 'O'),
#  ('city', 'O'),
#  (',', 'O'),
#  ('state', 'O'),
#  (',', 'O'),
#  ('ZIP', 'O'),
#  ('[', 'O'),
#  ('CJown', 'O'),
#  ('[', 'O'),
#  ('CJRent', 'O'),
#  ('No.Yrs', 'O'),
#  ('.', 'O'),
#  ('|FormerAddress', 'O'),
#  ('street', 'O'),
#  (',', 'O'),
#  ('city', 'O'),
#  (',', 'O'),
#  ('state', 'O'),
#  (',', 'O'),
#  ('ZIP', 'O'),
#  ('[', 'O'),
#  ('Jown', 'O'),
#  ('[', 'O'),
#  ('CJRent', 'O'),
#  ('No.Yrs', 'O'),
#  ('.', 'O'),
#  ('Borrower', 'O'),
#  ('IV', 'O'),
#  ('.', 'O'),
#  ('EMPLOYMENT', 'O'),
#  ('INFORMATION', 'O'),
#  ('Co-Borrower', 'O'),
#  ('Name', 'O'),
#  ('&', 'O'),
#  ('Address', 'O'),
#  ('of', 'O'),
#  ('Employer', 'O'),
#  ('[', 'O'),
#  ('¥', 'O'),
#  (']', 'O'),
#  ('self', 'O'),
#  ('Employed', 'O'),
#  ('|', 'O'),
#  ('Yrs', 'O'),
#  ('.', 'O'),
#  ('on', 'O'),
#  ('this', 'O'),
#  ('job', 'O'),
#  ('|', 'O'),
#  ('Name', 'O'),
#  ('&', 'O'),
#  ('Address', 'O'),
#  ('of', 'O'),
#  ('Employer', 'O'),
#  ('[', 'O'),
#  ('self', 'O'),
#  ('Employed', 'O'),
#  ('|', 'O'),
#  ('Yrs', 'O'),
#  ('.', 'O'),
#  ('on', 'O'),
#  ('this', 'O'),
#  ('job', 'O'),
#  ('Daniel', 'PERSON'),
#  ('Johnson', 'PERSON'),
#  ('Trucking', 'PERSON'),
#  (',', 'O'),
#  ('LLC', 'O'),
#  ('24Y', 'O'),
#  ('OM', 'ORGANIZATION'),
#  ('-', 'O'),
#  ('o', 'O'),
#  ('Yrs', 'O'),
#  ('.', 'O'),
#  ('employed', 'O'),
#  ('in', 'O'),
#  ('Yrs', 'O'),
#  ('.', 'O'),
#  ('employed', 'O'),
#  ('in', 'O'),
#  ('this', 'O'),
#  ('line', 'O'),
#  ('of', 'O'),
#  ('this', 'O'),
#  ('line', 'O'),
#  ('of', 'O'),
#  ('work-profession', 'O'),
#  ('work-profession', 'O'),
#  ('30', 'O'),
#  ('Position-Title-Type', 'O'),
#  ('of', 'O'),
#  ('Business', 'O'),
#  ('Sole', 'O'),
#  ('Owner', 'O'),
#  ('Business', 'O'),
#  ('Phone', 'O'),
#  ('incl', 'O'),
#  ('.', 'O'),
#  ('area', 'O'),
#  ('code', 'O'),
#  ('Position-Title-Type', 'O'),
#  ('of', 'O'),
#  ('Business', 'O'),
#  ('Business', 'O'),
#  ('Phone', 'O'),
#  ('incl', 'O'),
#  ('.', 'O'),
#  ('area', 'O'),
#  ('code', 'O'),
#  ('If', 'O'),
#  ('employed', 'O'),
#  ('in', 'O'),
#  ('current', 'O'),
#  ('position', 'O'),
#  ('for', 'O'),
#  ('less', 'O'),
#  ('than', 'O'),
#  ('two', 'O'),
#  ('years', 'O'),
#  ('or', 'O'),
#  ('if', 'O'),
#  ('currently', 'O'),
#  ('employed', 'O'),
#  ('in', 'O'),
#  ('more', 'O'),
#  ('than', 'O'),
#  ('one', 'O'),
#  ('position', 'O'),
#  (',', 'O'),
#  ('complete', 'O'),
#  ('the', 'O'),
#  ('following', 'O'),
#  (':', 'O'),
#  ('Uniform', 'ORGANIZATION'),
#  ('Residential', 'ORGANIZATION'),
#  ('Loan', 'ORGANIZATION'),
#  ('Application', 'ORGANIZATION'),
#  ('Freddie', 'ORGANIZATION'),
#  ('Mac', 'ORGANIZATION'),
#  ('Form', 'ORGANIZATION'),
#  ('65', 'O'),
#  ('7-05', 'O'),
#  ('rev.6-09', 'O'),
#  ('Ellie', 'PERSON'),
#  ('Mae', 'PERSON'),
#  (',', 'O'),
#  ('Inc', 'O'),
#  ('.', 'O'),
#  ('Page', 'O'),
#  ('1', 'O'),
#  ('of', 'O'),
#  ('5', 'O'),
#  ('03-19-20', 'O'),
#  ('Fannie', 'ORGANIZATION'),
#  ('Mae', 'ORGANIZATION'),
#  ('Form', 'O'),
#  ('1003', 'O'),
#  ('7-05', 'O'),
#  ('rev.6-09', 'O'),
#  ('GURLA09_S', 'O'),
#  ('0817', 'O'),
#  ('GURLA09S', 'O'),
#  ('POD', 'O'),
#  ('18', 'O'),
#  ('07:59', 'O'),
#  ('AM', 'O'),
#  ('PST', 'O')]

# %%
sner_tagger.tag(word_tokenize(text_test))
# Out:
# [('Yellowstone', 'ORGANIZATION'),
#  ('Bank', 'ORGANIZATION'),
#  ('Uniform', 'ORGANIZATION'),
#  ('Residential', 'ORGANIZATION'),
#  ('Loan', 'ORGANIZATION'),
#  ('Application', 'ORGANIZATION'),
#  ('This', 'O'),
#  ('application', 'O'),
#  ('is', 'O'),
#  ('designed', 'O'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('completed', 'O'),
#  ('by', 'O'),
#  ('the', 'O'),
#  ('applicants', 'O'),
#  ('with', 'O'),
#  ('the', 'O'),
#  ('Lender', 'O'),
#  ('’', 'O'),
#  ('s', 'O'),
#  ('assistance', 'O'),
#  ('.', 'O'),
#  ('Applicants', 'O'),
#  ('should', 'O'),
#  ('complete', 'O'),
#  ('this', 'O'),
#  ('form', 'O'),
#  ('as', 'O'),
#  ('“', 'O'),
#  ('Borrower', 'O'),
#  ('”', 'O'),
#  ('or', 'O'),
#  ('“', 'O'),
#  ('Co-Borrower', 'O'),
#  (',', 'O'),
#  ('”', 'O'),
#  ('as', 'O'),
#  ('applicable', 'O'),
#  ('.', 'O'),
#  ('Co-Borrower', 'O'),
#  ('information', 'O'),
#  ('must', 'O'),
#  ('also', 'O'),
#  ('be', 'O'),
#  ('provided', 'O'),
#  ('and', 'O'),
#  ('the', 'O'),
#  ('appropriate', 'O'),
#  ('box', 'O'),
#  ('checked', 'O'),
#  ('when', 'O'),
#  ('the', 'O'),
#  ('income', 'O'),
#  ('or', 'O'),
#  ('assets', 'O'),
#  ('of', 'O'),
#  ('a', 'O'),
#  ('person', 'O'),
#  ('other', 'O'),
#  ('than', 'O'),
#  ('the', 'O'),
#  ('Borrower', 'O'),
#  ('including', 'O'),
#  ('the', 'O'),
#  ('Borrower', 'O'),
#  ('’', 'O'),
#  ('s', 'O'),
#  ('spouse', 'O'),
#  ('will', 'O'),
#  ('be', 'O'),
#  ('used', 'O'),
#  ('as', 'O'),
#  ('a', 'O'),
#  ('basis', 'O'),
#  ('for', 'O'),
#  ('loan', 'O'),
#  ('qualification', 'O'),
#  ('or', 'O'),
#  ('the', 'O'),
#  ('income', 'O'),
#  ('or', 'O'),
#  ('assets', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('Borrower', 'O'),
#  ('’', 'O'),
#  ('s', 'O'),
#  ('spouse', 'O'),
#  ('or', 'O'),
#  ('other', 'O'),
#  ('person', 'O'),
#  ('who', 'O'),
#  ('has', 'O'),
#  ('community', 'O'),
#  ('property', 'O'),
#  ('rights', 'O'),
#  ('pursuant', 'O'),
#  ('to', 'O'),
#  ('state', 'O'),
#  ('law', 'O'),
#  ('will', 'O'),
#  ('not', 'O'),
#  ('be', 'O'),
#  ('used', 'O'),
#  ('as', 'O'),
#  ('a', 'O'),
#  ('basis', 'O'),
#  ('for', 'O'),
#  ('loan', 'O'),
#  ('qualification', 'O'),
#  (',', 'O'),
#  ('but', 'O'),
#  ('his', 'O'),
#  ('or', 'O'),
#  ('her', 'O'),
#  ('liabilities', 'O'),
#  ('must', 'O'),
#  ('be', 'O'),
#  ('considered', 'O'),
#  ('because', 'O'),
#  ('the', 'O'),
#  ('spouse', 'O'),
#  ('or', 'O'),
#  ('other', 'O'),
#  ('person', 'O'),
#  ('has', 'O'),
#  ('community', 'O'),
#  ('property', 'O'),
#  ('rights', 'O'),
#  ('pursuant', 'O'),
#  ('to', 'O'),
#  ('applicable', 'O'),
#  ('law', 'O'),
#  ('and', 'O'),
#  ('Borrower', 'PERSON'),
#  ('resides', 'O'),
#  ('in', 'O'),
#  ('a', 'O'),
#  ('community', 'O'),
#  ('property', 'O'),
#  ('state', 'O'),
#  (',', 'O'),
#  ('the', 'O'),
#  ('security', 'O'),
#  ('property', 'O'),
#  ('is', 'O'),
#  ('located', 'O'),
#  ('in', 'O'),
#  ('a', 'O'),
#  ('community', 'O'),
#  ('property', 'O'),
#  ('state', 'O'),
#  (',', 'O'),
#  ('or', 'O'),
#  ('the', 'O'),
#  ('Borrower', 'O'),
#  ('is', 'O'),
#  ('relying', 'O'),
#  ('on', 'O'),
#  ('other', 'O'),
#  ('property', 'O'),
#  ('LOAN', 'O'),
#  ('#', 'O'),
#  (':', 'O'),
#  ('1180303', 'O'),
#  ('located', 'O'),
#  ('in', 'O'),
#  ('a', 'O'),
#  ('community', 'O'),
#  ('property', 'O'),
#  ('state', 'O'),
#  ('as', 'O'),
#  ('a', 'O'),
#  ('basis', 'O'),
#  ('for', 'O'),
#  ('repayment', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('loan', 'O'),
#  ('.', 'O'),
#  ('If', 'O'),
#  ('this', 'O'),
#  ('is', 'O'),
#  ('an', 'O'),
#  ('application', 'O'),
#  ('for', 'O'),
#  ('joint', 'O'),
#  ('credit', 'O'),
#  (',', 'O'),
#  ('Borrower', 'ORGANIZATION'),
#  ('and', 'O'),
#  ('Co-Borrower', 'O'),
#  ('each', 'O'),
#  ('agree', 'O'),
#  ('that', 'O'),
#  ('we', 'O'),
#  ('intend', 'O'),
#  ('to', 'O'),
#  ('apg_ly', 'O'),
#  ('for', 'O'),
#  ('joint', 'O'),
#  ('credit', 'O'),
#  ('sign', 'O'),
#  ('below', 'O'),
#  (':', 'O'),
#  ('DocuSigned', 'O'),
#  ('by', 'O'),
#  (':', 'O'),
#  ('DocuSigned', 'O'),
#  ('by', 'O'),
#  ("—thu'tl", 'O'),
#  ('M', 'O'),
#  ('Jolunson', 'PERSON'),
#  ('.', 'O'),
#  ('31912018', 'O'),
#  ('|', 'O'),
#  ('09:23:25', 'O'),
#  ('pDT', 'O'),
#  ('|', 'O'),
#  ('\\VAddoria', 'O'),
#  ('Switly', 'O'),
#  ('Jelunson', 'O'),
#  (',', 'O'),
#  ('3-19-2018', 'O'),
#  ('|', 'O'),
#  ('09:30:08', 'O'),
#  ('PDT', 'O'),
#  ('Borfgeperes7c4400', 'O'),
#  ('Co-BbFewER', 'O'),
#  (':', 'O'),
#  ('|', 'O'),
#  ('I', 'O'),
#  ('.', 'O'),
#  ('TYPE', 'O'),
#  ('OF', 'O'),
#  ('MORTGAGE', 'O'),
#  ('AND', 'O'),
#  ('TERMS', 'O'),
#  ('OF', 'O'),
#  ('LOAN', 'O'),
#  ('Mortgage', 'O'),
#  ('[', 'O'),
#  ('_JVA', 'O'),
#  ('[', 'O'),
#  ('¥', 'O'),
#  (']', 'O'),
#  ('Conventional', 'O'),
#  ('Other', 'O'),
#  ('explain', 'O'),
#  (':', 'O'),
#  ('Agency', 'O'),
#  ('Case', 'O'),
#  ('Number', 'O'),
#  ('Lender', 'O'),
#  ('Case', 'O'),
#  ('Number', 'O'),
#  ('Applied', 'O'),
#  ('for', 'O'),
#  (':', 'O'),
#  ('[', 'O'),
#  ('_JFHA', 'O'),
#  ('USDA-Rural', 'ORGANIZATION'),
#  ('Housing', 'ORGANIZATION'),
#  ('Service', 'ORGANIZATION'),
#  ('1180303', 'O'),
#  ('Amount', 'O'),
#  (':', 'O'),
#  ('$', 'O'),
#  ('164,700.00', 'O'),
#  ('Interest', 'O'),
#  ('Rate', 'O'),
#  ('4375', 'O'),
#  ('%', 'O'),
#  ('No', 'O'),
#  ('.', 'O'),
#  ('of', 'O'),
#  ('Months', 'O'),
#  ('360', 'O'),
#  ('|', 'O'),
#  ('Amortization', 'O'),
#  ('[', 'O'),
#  ('X', 'O'),
#  (']', 'O'),
#  ('Fixed', 'O'),
#  ('Rate', 'O'),
#  ('[', 'O'),
#  (']', 'O'),
#  ('Other', 'O'),
#  ('explain', 'O'),
#  (':', 'O'),
#  ('|', 'O'),
#  ('Type', 'O'),
#  (':', 'O'),
#  ('CaPm', 'O'),
#  ('CJARM', 'O'),
#  ('type', 'O'),
#  (':', 'O'),
#  ('I', 'O'),
#  ('Il', 'O'),
#  ('.', 'O'),
#  ('PROPERTY', 'O'),
#  ('INFORMATION', 'O'),
#  ('AND', 'O'),
#  ('PURPOSE', 'O'),
#  ('OF', 'O'),
#  ('LOAN', 'O'),
#  ('Subject', 'O'),
#  ('Property', 'O'),
#  ('Address', 'O'),
#  ('street', 'O'),
#  (',', 'O'),
#  ('city', 'O'),
#  (',', 'O'),
#  ('state', 'O'),
#  (',', 'O'),
#  ('&', 'O'),
#  ('ZIP', 'O'),
#  ('29', 'O'),
#  ('Laptop', 'O'),
#  ('Loop', 'O'),
#  (',', 'O'),
#  ('Roberts', 'PERSON'),
#  (',', 'O'),
#  ('MT', 'O'),
#  ('59070', 'O'),
#  ('County', 'O'),
#  (':', 'O'),
#  ('Carbon', 'O'),
#  ('No', 'O'),
#  ('.', 'O'),
#  ('of', 'O'),
#  ('Units', 'O'),
#  ('1', 'O'),
#  ('1', 'O'),
#  ('Legal', 'O'),
#  ('Description', 'O'),
#  ('of', 'O'),
#  ('Subject', 'O'),
#  ('Property', 'O'),
#  ('attach', 'O'),
#  ('description', 'O'),
#  ('if', 'O'),
#  ('necessary', 'O'),
#  ('Year', 'O'),
#  ('Built', 'O'),
#  ('2017', 'O'),
#  ('Purpose', 'O'),
#  ('of', 'O'),
#  ('Loan', 'O'),
#  ('[', 'O'),
#  ('X', 'O'),
#  (']', 'O'),
#  ('Purchase', 'O'),
#  (']', 'O'),
#  ('Construction', 'O'),
#  ('[', 'O'),
#  ('other', 'O'),
#  ('explain', 'O'),
#  (':', 'O'),
#  ('Property', 'O'),
#  ('will', 'O'),
#  ('be', 'O'),
#  (':', 'O'),
#  ('[', 'O'),
#  ('1', 'O'),
#  ('Refinance', 'ORGANIZATION'),
#  ('Construction-Permanent', 'ORGANIZATION'),
#  ('Primary', 'ORGANIZATION'),
#  ('Secondary', 'ORGANIZATION'),
#  ('Investment', 'ORGANIZATION'),
#  ('Residence', 'ORGANIZATION'),
#  ('Residence', 'ORGANIZATION'),
#  ('Complete', 'ORGANIZATION'),
#  ('this', 'O'),
#  ('line', 'O'),
#  ('if', 'O'),
#  ('construction', 'O'),
#  ('or', 'O'),
#  ('construction-permanent', 'O'),
#  ('loan', 'O'),
#  ('.', 'O'),
#  ('Year', 'O'),
#  ('Lot', 'O'),
#  ('Acquired', 'O'),
#  ('|', 'O'),
#  ('Original', 'O'),
#  ('Cost', 'O'),
#  ('Amount', 'O'),
#  ('Existing', 'O'),
#  ('Liens', 'O'),
#  ('|', 'O'),
#  ('a', 'O'),
#  ('Present', 'O'),
#  ('Value', 'O'),
#  ('of', 'O'),
#  ('Lot', 'O'),
#  ('|', 'O'),
#  ('b', 'O'),
#  ('Cost', 'O'),
#  ('of', 'O'),
#  ('Improvements', 'O'),
#  ('|', 'O'),
#  ('Total', 'O'),
#  ('a', 'O'),
#  ('+', 'O'),
#  ('b', 'O'),
#  ('$', 'O'),
#  ('$', 'O'),
#  ('$', 'O'),
#  ('$', 'O'),
#  ('$', 'O'),
#  ('Complete', 'O'),
#  ('this', 'O'),
#  ('line', 'O'),
#  ('if', 'O'),
#  ('this', 'O'),
#  ('is', 'O'),
#  ('a', 'O'),
#  ('refinance', 'O'),
#  ('loan', 'O'),
#  ('.', 'O'),
#  ('Year', 'O'),
#  ('Acquired', 'O'),
#  ('Original', 'O'),
#  ('Cost', 'O'),
#  ('Amount', 'O'),
#  ('Existing', 'O'),
#  ('Liens', 'O'),
#  ('|', 'O'),
#  ('Purpose', 'O'),
#  ('of', 'O'),
#  ('Refinance', 'O'),
#  ('Describe', 'O'),
#  ('Improvements', 'O'),
#  ('[', 'O'),
#  ('made', 'O'),
#  ('[', 'O'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('made', 'O'),
#  ('$', 'O'),
#  ('$', 'O'),
#  ('Cost', 'O'),
#  (':', 'O'),
#  ('$', 'O'),
#  ('Title', 'O'),
#  ('will', 'O'),
#  ('be', 'O'),
#  ('held', 'O'),
#  ('in', 'O'),
#  ('what', 'O'),
#  ('Names', 'O'),
#  ('Daniel', 'PERSON'),
#  ('M', 'PERSON'),
#  ('Johnson', 'PERSON'),
#  (',', 'O'),
#  ('Victoria', 'ORGANIZATION'),
#  ('Smith', 'ORGANIZATION'),
#  ('Johnson', 'ORGANIZATION'),
#  ('Manner', 'ORGANIZATION'),
#  ('in', 'O'),
#  ('which', 'O'),
#  ('Title', 'O'),
#  ('will', 'O'),
#  ('be', 'O'),
#  ('held', 'O'),
#  ('Joint', 'O'),
#  ('tenants', 'O'),
#  ('Source', 'O'),
#  ('of', 'O'),
#  ('Down', 'O'),
#  ('Payment', 'O'),
#  (',', 'O'),
#  ('Settlement', 'O'),
#  ('Charges', 'O'),
#  (',', 'O'),
#  ('and-or', 'O'),
#  ('Subordinate', 'O'),
#  ('Financing', 'O'),
#  ('explain', 'O'),
#  ('Equity', 'O'),
#  ('On', 'O'),
#  ('Pending', 'O'),
#  ('Sale', 'O'),
#  ('Estate', 'O'),
#  ('will', 'O'),
#  ('be', 'O'),
#  ('held', 'O'),
#  ('in', 'O'),
#  (':', 'O'),
#  ('Fee', 'O'),
#  ('Simple', 'O'),
#  ('Leasehold', 'O'),
#  ('show', 'O'),
#  ('expiration', 'O'),
#  ('date', 'O'),
#  ('Borrower', 'O'),
#  ('Ill.', 'O'),
#  ('BORROWER', 'O'),
#  ('INFORMATION', 'O'),
#  ('Co-Borrower', 'PERSON'),
#  ('Borrower', 'PERSON'),
#  ('’', 'O'),
#  ('s', 'O'),
#  ('Name', 'O'),
#  ('include', 'O'),
#  ('Jr.', 'O'),
#  ('or', 'O'),
#  ('Sr.', 'O'),
#  ('if', 'O'),
#  ('applicable', 'O'),
#  ('Daniel', 'PERSON'),
#  ('M', 'PERSON'),
#  ('Johnson', 'PERSON'),
#  ('Co-Borrower', 'O'),
#  ('’', 'O'),
#  ('s', 'O'),
#  ('Name', 'O'),
#  ('include', 'O'),
#  ('Jr.', 'O'),
#  ('or', 'O'),
#  ('Sr.', 'O'),
#  ('if', 'O'),
#  ('applicable', 'O'),
#  ('Victoria', 'ORGANIZATION'),
#  ('Smith', 'ORGANIZATION'),
#  ('Johnson', 'ORGANIZATION'),
#  ('Social', 'ORGANIZATION'),
#  ('Security', 'ORGANIZATION'),
#  ('Number', 'ORGANIZATION'),
#  ('434-06-8836', 'O'),
#  ('Home', 'O'),
#  ('Phone', 'O'),
#  ('incl', 'O'),
#  ('.', 'O'),
#  ('area', 'O'),
#  ('code', 'O'),
#  ('337-998-1279', 'O'),
#  ('DOB', 'O'),
#  ('mm-dd-yyyy', 'O'),
#  ('|', 'O'),
#  ('04-12-1967', 'O'),
#  ('Yrs', 'O'),
#  ('.', 'O'),
#  ('School', 'O'),
#  ('14', 'O'),
#  ('ISocial', 'O'),
#  ('Security', 'O'),
#  ('Number', 'O'),
#  ('438-39-1513', 'O'),
#  ('Home', 'O'),
#  ('Phone', 'O'),
#  ('incl', 'O'),
#  ('.', 'O'),
#  ('area', 'O'),
#  ('code', 'O'),
#  ('337-936-1975', 'O'),
#  ('DOB', 'O'),
#  ('mm-dd-yyyy', 'O'),
#  ('09-15-1970', 'O'),
#  ('Yrs', 'O'),
#  ('.', 'O'),
#  ('School', 'O'),
#  ('14', 'O'),
#  ('[', 'O'),
#  ('X', 'O'),
#  (']', 'O'),
#  ('Married', 'O'),
#  ('Unmarried', 'O'),
#  ('include', 'O'),
#  ('single', 'O'),
#  (',', 'O'),
#  ('|', 'O'),
#  ('Dependents', 'O'),
#  ('not', 'O'),
#  ('listed', 'O'),
#  ('by', 'O'),
#  ('Co-Borrower', 'PERSON'),
#  ('divorced', 'O'),
#  (',', 'O'),
#  ('widowed', 'O'),
#  ('[', 'O'),
#  ('X', 'O'),
#  (']', 'O'),
#  ('married', 'O'),
#  ('Unmarried', 'O'),
#  ('include', 'O'),
#  ('single', 'O'),
#  (',', 'O'),
#  ('divorced', 'O'),
#  (',', 'O'),
#  ('widowed', 'O'),
#  ('Dependents', 'O'),
#  ('not', 'O'),
#  ('listed', 'O'),
#  ('by', 'O'),
#  ('Borrower', 'O'),
#  ('[', 'O'),
#  ('Separated', 'O'),
#  ('no.1', 'O'),
#  ('ages', 'O'),
#  ('5', 'O'),
#  ('[', 'O'),
#  ('Separated', 'O'),
#  ('no.o', 'O'),
#  ('ages', 'O'),
#  ('Present', 'O'),
#  ('Address', 'O'),
#  ('street', 'O'),
#  (',', 'O'),
#  ('city', 'O'),
#  (',', 'O'),
#  ('state', 'O'),
#  (',', 'O'),
#  ('ZIP', 'O'),
#  ('[', 'O'),
#  ('¥', 'O'),
#  (']', 'O'),
#  ('Own', 'O'),
#  ('Rent', 'O'),
#  ('No.Yrs', 'O'),
#  ('.', 'O'),
#  ('|PresentAddress', 'O'),
#  ('street', 'O'),
#  (',', 'O'),
#  ('city', 'O'),
#  (',', 'O'),
#  ('state', 'O'),
#  (',', 'O'),
#  ('ZIP', 'O'),
#  ('[', 'O'),
#  ('¥', 'O'),
#  (']', 'O'),
#  ('Own', 'O'),
#  ('[', 'O'),
#  ('JRent', 'O'),
#  ('No.Yrs', 'O'),
#  ('.', 'O'),
#  ('2803', 'O'),
#  ('lkes', 'O'),
#  ('Rd', 'O'),
#  ('18Y', 'O'),
#  ('OM', 'O'),
#  ('|', 'O'),
#  ('2803', 'O'),
#  ('Ikes', 'O'),
#  ('Rd', 'O'),
#  ('18Y', 'O'),
#  ('OM', 'O'),
#  ('Kinder', 'O'),
#  (',', 'O'),
#  ('LA', 'LOCATION'),
#  ('70648', 'O'),
#  ('Kinder', 'O'),
#  (',', 'O'),
#  ('LA', 'LOCATION'),
#  ('70648', 'O'),
#  ('Mailing', 'O'),
#  ('Address', 'O'),
#  (',', 'O'),
#  ('if', 'O'),
#  ('different', 'O'),
#  ('from', 'O'),
#  ('Present', 'O'),
#  ('Address', 'O'),
#  ('Mailing', 'O'),
#  ('Address', 'O'),
#  (',', 'O'),
#  ('if', 'O'),
#  ('different', 'O'),
#  ('from', 'O'),
#  ('Present', 'O'),
#  ('Address', 'O'),
#  ('2803', 'O'),
#  ('lkes', 'O'),
#  ('Rd', 'O'),
#  ('2803', 'O'),
#  ('lkes', 'O'),
#  ('Rd', 'O'),
#  ('Kinder', 'O'),
#  (',', 'O'),
#  ('LA', 'LOCATION'),
#  ('70648', 'O'),
#  ('Kinder', 'O'),
#  (',', 'O'),
#  ('LA', 'O'),
#  ('70648', 'O'),
#  ('If', 'O'),
#  ('residing', 'O'),
#  ('at', 'O'),
#  ('present', 'O'),
#  ('address', 'O'),
#  ('for', 'O'),
#  ('less', 'O'),
#  ('than', 'O'),
#  ('two', 'O'),
#  ('years', 'O'),
#  (',', 'O'),
#  ('complete', 'O'),
#  ('the', 'O'),
#  ('following', 'O'),
#  (':', 'O'),
#  ('Former', 'O'),
#  ('Address', 'O'),
#  ('street', 'O'),
#  (',', 'O'),
#  ('city', 'O'),
#  (',', 'O'),
#  ('state', 'O'),
#  (',', 'O'),
#  ('ZIP', 'O'),
#  ('[', 'O'),
#  ('CJown', 'O'),
#  ('[', 'O'),
#  ('CJRent', 'O'),
#  ('No.Yrs', 'O'),
#  ('.', 'O'),
#  ('|FormerAddress', 'O'),
#  ('street', 'O'),
#  (',', 'O'),
#  ('city', 'O'),
#  (',', 'O'),
#  ('state', 'O'),
#  (',', 'O'),
#  ('ZIP', 'O'),
#  ('[', 'O'),
#  ('Jown', 'O'),
#  ('[', 'O'),
#  ('CJRent', 'O'),
#  ('No.Yrs', 'O'),
#  ('.', 'O'),
#  ('Borrower', 'O'),
#  ('IV', 'O'),
#  ('.', 'O'),
#  ('EMPLOYMENT', 'O'),
#  ('INFORMATION', 'O'),
#  ('Co-Borrower', 'O'),
#  ('Name', 'O'),
#  ('&', 'O'),
#  ('Address', 'O'),
#  ('of', 'O'),
#  ('Employer', 'O'),
#  ('Daniel', 'PERSON'),
#  ('Johnson', 'PERSON'),
#  ('Trucking', 'PERSON'),
#  (',', 'O'),
#  ('LLC', 'O'),
#  ('[', 'O'),
#  ('¥', 'O'),
#  (']', 'O'),
#  ('self', 'O'),
#  ('Employed', 'O'),
#  ('|', 'O'),
#  ('years', 'O'),
#  ('on', 'O'),
#  ('this', 'O'),
#  ('job', 'O'),
#  ('24Y', 'O'),
#  ('OM', 'O'),
#  ('|', 'O'),
#  ('Name', 'O'),
#  ('&', 'O'),
#  ('Address', 'O'),
#  ('of', 'O'),
#  ('Employer', 'O'),
#  ('[', 'O'),
#  ('self', 'O'),
#  ('Employed', 'O'),
#  ('|', 'O'),
#  ('Yrs', 'O'),
#  ('.', 'O'),
#  ('on', 'O'),
#  ('this', 'O'),
#  ('job', 'O'),
#  ('-', 'O'),
#  ('o', 'O'),
#  ('Yrs', 'O'),
#  ('.', 'O'),
#  ('employed', 'O'),
#  ('in', 'O'),
#  ('Yrs', 'O'),
#  ('.', 'O'),
#  ('employed', 'O'),
#  ('in', 'O'),
#  ('this', 'O'),
#  ('line', 'O'),
#  ('of', 'O'),
#  ('this', 'O'),
#  ('line', 'O'),
#  ('of', 'O'),
#  ('work-profession', 'O'),
#  ('work-profession', 'O'),
#  ('30', 'O'),
#  ('Position-Title-Type', 'O'),
#  ('of', 'O'),
#  ('Business', 'O'),
#  ('Sole', 'O'),
#  ('Owner', 'O'),
#  ('Business', 'O'),
#  ('Phone', 'O'),
#  ('incl', 'O'),
#  ('.', 'O'),
#  ('area', 'O'),
#  ('code', 'O'),
#  ('Position-Title-Type', 'O'),
#  ('of', 'O'),
#  ('Business', 'O'),
#  ('Business', 'O'),
#  ('Phone', 'O'),
#  ('incl', 'O'),
#  ('.', 'O'),
#  ('area', 'O'),
#  ('code', 'O'),
#  ('If', 'O'),
#  ('employed', 'O'),
#  ('in', 'O'),
#  ('current', 'O'),
#  ('position', 'O'),
#  ('for', 'O'),
#  ('less', 'O'),
#  ('than', 'O'),
#  ('two', 'O'),
#  ('years', 'O'),
#  ('or', 'O'),
#  ('if', 'O'),
#  ('currently', 'O'),
#  ('employed', 'O'),
#  ('in', 'O'),
#  ('more', 'O'),
#  ('than', 'O'),
#  ('one', 'O'),
#  ('position', 'O'),
#  (',', 'O'),
#  ('complete', 'O'),
#  ('the', 'O'),
#  ('following', 'O'),
#  (':', 'O'),
#  ('Uniform', 'ORGANIZATION'),
#  ('Residential', 'ORGANIZATION'),
#  ('Loan', 'ORGANIZATION'),
#  ('Application', 'ORGANIZATION'),
#  ('Freddie', 'ORGANIZATION'),
#  ('Mac', 'ORGANIZATION'),
#  ('Form', 'ORGANIZATION'),
#  ('65', 'O'),
#  ('7-05', 'O'),
#  ('rev.6-09', 'O'),
#  ('Ellie', 'PERSON'),
#  ('Mae', 'PERSON'),
#  (',', 'O'),
#  ('Inc', 'O'),
#  ('.', 'O'),
#  ('Page', 'O'),
#  ('1', 'O'),
#  ('of', 'O'),
#  ('5', 'O'),
#  ('03-19-20', 'O'),
#  ('Fannie', 'ORGANIZATION'),
#  ('Mae', 'ORGANIZATION'),
#  ('Form', 'O'),
#  ('1003', 'O'),
#  ('7-05', 'O'),
#  ('rev.6-09', 'O'),
#  ('GURLA09_S', 'O'),
#  ('0817', 'O'),
#  ('GURLA09S', 'O'),
#  ('POD', 'O'),
#  ('18', 'O'),
#  ('07:59', 'O'),
#  ('AM', 'O'),
#  ('PST', 'O')]

# %%
ner_tagged_sentences = [sn.tag(sent.split()) for sent in text_test]

# extract all named entities
named_entities = []
for sentence in ner_tagged_sentences:
    temp_entity_name = ''
    temp_named_entity = None
    for term, tag in sentence:
        if tag != 'O':
            temp_entity_name = ' '.join([temp_entity_name, term]).strip()
            temp_named_entity = (temp_entity_name, tag)
        else:
            if temp_named_entity:
                named_entities.append(temp_named_entity)
                temp_entity_name = ''
                temp_named_entity = None

#named_entities = list(set(named_entities))
entity_frame = pd.DataFrame(named_entities, 
                            columns=['Entity Name', 'Entity Type'])
                            

# view top entities and types
top_entities = (entity_frame.groupby(by=['Entity Name', 'Entity Type'])
                           .size()
                           .sort_values(ascending=False)
                           .reset_index().rename(columns={0 : 'Frequency'}))
top_entities.head(15)


# view top entity types
top_entities = (entity_frame.groupby(by=['Entity Type'])
                           .size()
                           .sort_values(ascending=False)
                           .reset_index().rename(columns={0 : 'Frequency'}))
top_entities.head()

# %%
top_entities
